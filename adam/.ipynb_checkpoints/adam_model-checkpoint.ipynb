# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-4
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/optimizers/adam/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    #prob_1=tf.placeholder(tf.float32)
    #prob_2=tf.placeholder(tf.float32)
    #phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [3072, 512], initializer=tf.contrib.layers.xavier_initializer()),
    'wc9': tf.get_variable(name = "w9",shape = [512, 256], initializer=tf.contrib.layers.xavier_initializer()),
    'wc10': tf.get_variable(name = "w10",shape = [256, 10], initializer=tf.contrib.layers.xavier_initializer()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
    'bc10': tf.Variable(tf.constant(0.1, shape=[10]), name = "b10"),
}
    
x_image = tf.reshape(x,[-1,32,32,3])
#x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_image, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc1']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_1_relu = tf.nn.relu(hidden_1)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc2']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_2_relu = tf.nn.relu(hidden_2)
#hidden_2_do=tf.nn.dropout(hidden_2_relu, keep_prob=prob_1)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc3']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_3_relu = tf.nn.relu(hidden_3)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc4']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_4_relu = tf.nn.relu(hidden_4)
#hidden_4_do=tf.nn.dropout(hidden_4_relu, keep_prob=prob_1)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc5']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_5_relu = tf.nn.relu(hidden_5)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc6']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_6_relu = tf.nn.relu(hidden_6)
#hidden_6_do=tf.nn.dropout(hidden_6_relu, keep_prob=prob_1)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
hidden_7_relu = tf.nn.relu(hidden_7)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_relu), weights['wc8']) + biases['bc8']
hidden_8_relu = tf.nn.relu(hidden_8)
#hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_relu, weights['wc9']) + biases['bc9']
hidden_9_relu = tf.nn.relu(hidden_9)
#hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_relu, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl})
                    c += sess.run(cost, feed_dict={x: img, y: lbl})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 512)
# (?, 256)
# WARNING:tensorflow:From <ipython-input-10-c0c7b3c1968c>:159 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-c0c7b3c1968c>:160 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-c0c7b3c1968c>:167 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.288
# j =  160
# batch_train_accuracy =  0.32
# j =  240
# batch_train_accuracy =  0.392
# j =  320
# batch_train_accuracy =  0.424
# lost =  1.80655102313
# train_cumulative_accuracy :  0.343319999669
# duree :  93.0138309002
# lost =  1.54031219482
# test_cumulative_accuracy :  0.441699986756
# epoch :  1
# j =  0
# batch_train_accuracy =  0.48
# j =  80
# batch_train_accuracy =  0.52
# j =  160
# batch_train_accuracy =  0.424
# j =  240
# batch_train_accuracy =  0.576
# j =  320
# batch_train_accuracy =  0.608
# lost =  1.40957807243
# train_cumulative_accuracy :  0.49229999654
# duree :  195.025406837
# lost =  1.37553517103
# test_cumulative_accuracy :  0.513499976397
# epoch :  2
# j =  0
# batch_train_accuracy =  0.576
# j =  80
# batch_train_accuracy =  0.592
# j =  160
# batch_train_accuracy =  0.472
# j =  240
# batch_train_accuracy =  0.576
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.2365212968
# train_cumulative_accuracy :  0.556819996908
# duree :  296.746873856
# lost =  1.25897883356
# test_cumulative_accuracy :  0.561199969947
# epoch :  3
# j =  0
# batch_train_accuracy =  0.616
# j =  80
# batch_train_accuracy =  0.656
# j =  160
# batch_train_accuracy =  0.528
# j =  240
# batch_train_accuracy =  0.592
# j =  320
# batch_train_accuracy =  0.656
# lost =  1.10085691229
# train_cumulative_accuracy :  0.608539997339
# duree :  398.750733852
# lost =  1.12949678898
# test_cumulative_accuracy :  0.599599969685
# epoch :  4
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.624
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.72
# lost =  0.982754274458
# train_cumulative_accuracy :  0.655919994563
# duree :  500.700417995
# lost =  1.04486917317
# test_cumulative_accuracy :  0.625299967527
# epoch :  5
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.648
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.752
# lost =  0.890729512572
# train_cumulative_accuracy :  0.689739999622
# duree :  602.703491926
# lost =  1.02400492489
# test_cumulative_accuracy :  0.632399971485
# epoch :  6
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.664
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.768
# lost =  0.810668334961
# train_cumulative_accuracy :  0.719000002593
# duree :  705.013010979
# lost =  0.96778180778
# test_cumulative_accuracy :  0.656699971557
# epoch :  7
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.784
# lost =  0.734156985432
# train_cumulative_accuracy :  0.74834000662
# duree :  807.063646793
# lost =  0.909756874442
# test_cumulative_accuracy :  0.681199965477
# epoch :  8
# j =  0
# batch_train_accuracy =  0.776
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.8
# lost =  0.666527981907
# train_cumulative_accuracy :  0.773860010803
# duree :  909.129064798
# lost =  0.892277716398
# test_cumulative_accuracy :  0.689899961948
# epoch :  9
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.601356115937
# train_cumulative_accuracy :  0.796800009906
# duree :  1010.55860186
# lost =  0.931656265855
# test_cumulative_accuracy :  0.683799969554
# epoch :  10
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.538813934103
# train_cumulative_accuracy :  0.818860018104
# duree :  1110.48985291
# lost =  0.956948719025
# test_cumulative_accuracy :  0.685499966145
# epoch :  11
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.477665292248
# train_cumulative_accuracy :  0.843120018244
# duree :  1208.40971494
# lost =  0.960666228533
# test_cumulative_accuracy :  0.69099996388
# epoch :  12
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.848
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.42892250102
# train_cumulative_accuracy :  0.860820023715
# duree :  1304.91025686
# lost =  0.985971567035
# test_cumulative_accuracy :  0.696399968266
# epoch :  13
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.375890410952
# train_cumulative_accuracy :  0.881020027101
# duree :  1401.40330195
# lost =  1.05476554811
# test_cumulative_accuracy :  0.693899964094
# epoch :  14
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.326750935465
# train_cumulative_accuracy :  0.899640029371
# duree :  1497.93515682
# lost =  1.05633716583
# test_cumulative_accuracy :  0.70259996891
# epoch :  15
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.864
# lost =  0.283860096633
# train_cumulative_accuracy :  0.91462003231
# duree :  1594.61382294
# lost =  1.11154340088
# test_cumulative_accuracy :  0.701999973655
# epoch :  16
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.245085656811
# train_cumulative_accuracy :  0.927140029967
# duree :  1691.09196281
# lost =  1.18933849454
# test_cumulative_accuracy :  0.695799969435
# epoch :  17
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.207189400271
# train_cumulative_accuracy :  0.94066003263
# duree :  1787.58460689
# lost =  1.27470311344
# test_cumulative_accuracy :  0.695199965239
# epoch :  18
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.180573259443
# train_cumulative_accuracy :  0.949480035007
# duree :  1884.07977891
# lost =  1.33982842803
# test_cumulative_accuracy :  0.691999970078
# epoch :  19
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.161153038573
# train_cumulative_accuracy :  0.956220032871
# duree :  1988.26084185
# lost =  1.49552344441
# test_cumulative_accuracy :  0.673199967742
# epoch :  20
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.14110004941
# train_cumulative_accuracy :  0.962420033365
# duree :  2086.81664085
# lost =  1.52897401214
# test_cumulative_accuracy :  0.674799963236
# epoch :  21
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.109656623546
# train_cumulative_accuracy :  0.973160030842
# duree :  2183.58004999
# lost =  1.6712711215
# test_cumulative_accuracy :  0.672099968791
# epoch :  22
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0934962035809
# train_cumulative_accuracy :  0.978620024323
# duree :  2282.02441692
# lost =  1.51188501179
# test_cumulative_accuracy :  0.691499972939
# epoch :  23
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0857116413489
# train_cumulative_accuracy :  0.980020020902
# duree :  2379.36310101
# lost =  1.68513834119
# test_cumulative_accuracy :  0.661199969053
# epoch :  24
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0626405303087
# train_cumulative_accuracy :  0.987340013087
# duree :  2475.90976596
# lost =  1.94199542046
# test_cumulative_accuracy :  0.645899964571
# epoch :  25
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0436592484429
# train_cumulative_accuracy :  0.992900006473
# duree :  2572.42760396
# lost =  1.86460559607
# test_cumulative_accuracy :  0.675399968624
# epoch :  26
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0341403575893
# train_cumulative_accuracy :  0.995000003725
# duree :  2668.96896982
# lost =  1.96315874577
# test_cumulative_accuracy :  0.683799970746
# epoch :  27
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0304453369509
# train_cumulative_accuracy :  0.995680002123
# duree :  2765.49998784
# lost =  1.9613333118
# test_cumulative_accuracy :  0.688499968052
# epoch :  28
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0252923109266
# train_cumulative_accuracy :  0.99686000213
# duree :  2862.03741097
# lost =  1.88965317726
# test_cumulative_accuracy :  0.699199966788
# epoch :  29
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0203002081451
# train_cumulative_accuracy :  0.997720001638
# duree :  2958.58753395
# lost =  1.9426238066
# test_cumulative_accuracy :  0.694699967504
# epoch :  30
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0168865374336
# train_cumulative_accuracy :  0.998380000293
# duree :  3055.18805981
# lost =  1.97522009969
# test_cumulative_accuracy :  0.699199969172
# epoch :  31
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0144252129097
# train_cumulative_accuracy :  0.998580000401
# duree :  3151.72967482
# lost =  2.04503311813
# test_cumulative_accuracy :  0.702399966121
# epoch :  32
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0147175968473
# train_cumulative_accuracy :  0.998560001552
# duree :  3248.27164578
# lost =  2.15131399274
# test_cumulative_accuracy :  0.69319996655
# epoch :  33
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0137233320985
# train_cumulative_accuracy :  0.998819999993
# duree :  3344.85299897
# lost =  2.07007879257
# test_cumulative_accuracy :  0.701099966168
# epoch :  34
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0117042355298
# train_cumulative_accuracy :  0.999179999977
# duree :  3441.39722586
# lost =  2.13808020234
# test_cumulative_accuracy :  0.701199972034
# epoch :  35
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0105047971141
# train_cumulative_accuracy :  0.999300000072
# duree :  3537.90848494
# lost =  2.29449715495
# test_cumulative_accuracy :  0.689299966097
# epoch :  36
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0103399460576
# train_cumulative_accuracy :  0.999179999828
# duree :  3635.54991794
# lost =  2.24712210774
# test_cumulative_accuracy :  0.696499968767
# epoch :  37
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0101607332838
# train_cumulative_accuracy :  0.99921999976
# duree :  3733.17015886
# lost =  2.2009066689
# test_cumulative_accuracy :  0.699099957943
# epoch :  38
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0083379488549
# train_cumulative_accuracy :  0.999520000219
# duree :  3830.19422698
# lost =  2.25759294987
# test_cumulative_accuracy :  0.70359996736
# epoch :  39
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00803651753464
# train_cumulative_accuracy :  0.999320000708
# duree :  3926.96106386
# lost =  2.23252441168
# test_cumulative_accuracy :  0.701299966574
# epoch :  40
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00773114861775
# train_cumulative_accuracy :  0.999399999976
# duree :  4023.87803483
# lost =  2.26588590503
# test_cumulative_accuracy :  0.700699967742
# epoch :  41
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00679752907366
# train_cumulative_accuracy :  0.999579999894
# duree :  4123.1189158
# lost =  2.30766090631
# test_cumulative_accuracy :  0.700399973989
# epoch :  42
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00578574281943
# train_cumulative_accuracy :  0.999759999961
# duree :  4221.94037986
# lost =  2.35609036326
# test_cumulative_accuracy :  0.698399972916
# epoch :  43
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00557175615075
# train_cumulative_accuracy :  0.999799999893
# duree :  4320.69683599
# lost =  2.37290407598
# test_cumulative_accuracy :  0.696699969172
# epoch :  44
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c0c7b3c1968c> in <module>()
#     192                     c += sess.run(cost, feed_dict={x: img, y: lbl})
#     193
# --> 194                     batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl})
#     195
#     196                     train_accuracy += batch_train_accuracy
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
