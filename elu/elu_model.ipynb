# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/elu/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    #prob_3=tf.placeholder(tf.float32)
    #phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [3072, 512], initializer=tf.contrib.layers.xavier_initializer()),
    'wc9': tf.get_variable(name = "w9",shape = [512, 256], initializer=tf.contrib.layers.xavier_initializer()),
    'wc10': tf.get_variable(name = "w10",shape = [256, 10], initializer=tf.contrib.layers.xavier_initializer()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
    'bc10': tf.Variable(tf.constant(0.1, shape=[10]), name = "b10"),
}
    
total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
#x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)
#x_image_do=tf.nn.dropout(x_image, keep_prob=prob_3)

hidden_1 = tf.nn.conv2d(x_image, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc1']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc2']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_1)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc3']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc4']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_1)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc5']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc6']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
hidden_7_relu = tf.nn.elu(hidden_7)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_do), weights['wc8']) + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_do, weights['wc9']) + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_do, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1.})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1.})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1.})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1.})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1.})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1.})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (3072, 512)
# 2
# 3072
# 512
# 1572864
# (512, 256)
# 2
# 512
# 256
# 131072
# (256, 10)
# 2
# 256
# 10
# 2560
# (48,)
# 1
# 48
# 48
# (48,)
# 1
# 48
# 48
# (96,)
# 1
# 96
# 96
# (96,)
# 1
# 96
# 96
# (192,)
# 1
# 192
# 192
# (192,)
# 1
# 192
# 192
# (192,)
# 1
# 192
# 192
# (512,)
# 1
# 512
# 512
# (256,)
# 1
# 256
# 256
# (10,)
# 1
# 10
# 10
# total_parameters :  2389114
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 512)
# (?, 256)
# WARNING:tensorflow:From <ipython-input-10-b70411a1ad36>:176 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-b70411a1ad36>:177 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-b70411a1ad36>:184 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.112
# j =  80
# batch_train_accuracy =  0.408
# j =  160
# batch_train_accuracy =  0.416
# j =  240
# batch_train_accuracy =  0.528
# j =  320
# batch_train_accuracy =  0.56
# lost =  1.57127083942
# train_cumulative_accuracy :  0.436919996943
# duree :  96.3804979324
# lost =  1.26273486972
# test_cumulative_accuracy :  0.548699968159
# epoch :  1
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.616
# j =  160
# batch_train_accuracy =  0.512
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.05354502603
# train_cumulative_accuracy :  0.624779991806
# duree :  197.113767862
# lost =  1.02929707706
# test_cumulative_accuracy :  0.637999972403
# epoch :  2
# j =  0
# batch_train_accuracy =  0.712
# j =  80
# batch_train_accuracy =  0.704
# j =  160
# batch_train_accuracy =  0.672
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.728
# lost =  0.860833113492
# train_cumulative_accuracy :  0.696740000099
# duree :  298.556563854
# lost =  0.926193147302
# test_cumulative_accuracy :  0.686699968576
# epoch :  3
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.696
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.776
# lost =  0.74709344767
# train_cumulative_accuracy :  0.735660005808
# duree :  401.912154913
# lost =  0.812753424644
# test_cumulative_accuracy :  0.713899969459
# epoch :  4
# j =  0
# batch_train_accuracy =  0.816
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.768
# lost =  0.663569396883
# train_cumulative_accuracy :  0.765700009018
# duree :  503.030088902
# lost =  0.757666628361
# test_cumulative_accuracy :  0.741699970961
# epoch :  5
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.603050153479
# train_cumulative_accuracy :  0.786480012238
# duree :  603.616940022
# lost =  0.703399631679
# test_cumulative_accuracy :  0.765199978948
# epoch :  6
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.556152445972
# train_cumulative_accuracy :  0.804880013019
# duree :  704.398936987
# lost =  0.699638970792
# test_cumulative_accuracy :  0.764399979115
# epoch :  7
# j =  0
# batch_train_accuracy =  0.856
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.872
# lost =  0.513505581617
# train_cumulative_accuracy :  0.819680016488
# duree :  806.884790897
# lost =  0.652541943789
# test_cumulative_accuracy :  0.783499974012
# epoch :  8
# j =  0
# batch_train_accuracy =  0.872
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.816
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.486276548505
# train_cumulative_accuracy :  0.82996001929
# duree :  908.109043837
# lost =  0.64167568177
# test_cumulative_accuracy :  0.782199975848
# epoch :  9
# j =  0
# batch_train_accuracy =  0.856
# j =  80
# batch_train_accuracy =  0.864
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.467636873797
# train_cumulative_accuracy :  0.836500019133
# duree :  1009.20907998
# lost =  0.683449102938
# test_cumulative_accuracy :  0.782199977636
# epoch :  10
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.872
# lost =  0.442951650694
# train_cumulative_accuracy :  0.846200018823
# duree :  1110.417068
# lost =  0.628583309352
# test_cumulative_accuracy :  0.793699977398
# epoch :  11
# j =  0
# batch_train_accuracy =  0.864
# j =  80
# batch_train_accuracy =  0.856
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.424332455397
# train_cumulative_accuracy :  0.852480023354
# duree :  1211.62455487
# lost =  0.622054649591
# test_cumulative_accuracy :  0.792899979353
# epoch :  12
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.848
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.405499079004
# train_cumulative_accuracy :  0.858640022129
# duree :  1312.29067183
# lost =  0.686155048013
# test_cumulative_accuracy :  0.776999979019
# epoch :  13
# j =  0
# batch_train_accuracy =  0.904
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.38955012992
# train_cumulative_accuracy :  0.866220024526
# duree :  1412.96115279
# lost =  0.602261174321
# test_cumulative_accuracy :  0.80269998312
# epoch :  14
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.872
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.376723411568
# train_cumulative_accuracy :  0.87026002273
# duree :  1513.26395988
# lost =  0.615591974854
# test_cumulative_accuracy :  0.803499982953
# epoch :  15
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.365744848177
# train_cumulative_accuracy :  0.873580025136
# duree :  1613.67902398
# lost =  0.5956197384
# test_cumulative_accuracy :  0.812499980927
# epoch :  16
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.816
# j =  320
# batch_train_accuracy =  0.864
# lost =  0.359013630822
# train_cumulative_accuracy :  0.876380025893
# duree :  1715.70122194
# lost =  0.598149438202
# test_cumulative_accuracy :  0.809499976039
# epoch :  17
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.856
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.34392071493
# train_cumulative_accuracy :  0.881500025541
# duree :  1819.06502581
# lost =  0.631245952845
# test_cumulative_accuracy :  0.800999978185
# epoch :  18
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.335497858785
# train_cumulative_accuracy :  0.884100025594
# duree :  1923.70840883
# lost =  0.607434000373
# test_cumulative_accuracy :  0.811899982095
# epoch :  19
# j =  0
# batch_train_accuracy =  0.904
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.324983657897
# train_cumulative_accuracy :  0.889840026647
# duree :  2027.15672398
# lost =  0.6110744977
# test_cumulative_accuracy :  0.811099979281
# epoch :  20
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.313629235774
# train_cumulative_accuracy :  0.893620026112
# duree :  2131.84934902
# lost =  0.587163317204
# test_cumulative_accuracy :  0.818299983144
# epoch :  21
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.872
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.313358823769
# train_cumulative_accuracy :  0.893500026464
# duree :  2234.19323587
# lost =  0.593720732629
# test_cumulative_accuracy :  0.817399976254
# epoch :  22
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.295609824471
# train_cumulative_accuracy :  0.899960027933
# duree :  2338.59956288
# lost =  0.574448815286
# test_cumulative_accuracy :  0.821399978995
# epoch :  23
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.288231115788
# train_cumulative_accuracy :  0.901700029522
# duree :  2441.80371594
# lost =  0.602980958521
# test_cumulative_accuracy :  0.822599976063
# epoch :  24
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.290898094773
# train_cumulative_accuracy :  0.900140028298
# duree :  2542.68934584
# lost =  0.597312550545
# test_cumulative_accuracy :  0.816899978518
# epoch :  25
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.282995531745
# train_cumulative_accuracy :  0.904000029117
# duree :  2643.63088799
# lost =  0.596597924531
# test_cumulative_accuracy :  0.820399973989
# epoch :  26
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.279857908189
# train_cumulative_accuracy :  0.90504002884
# duree :  2744.77058291
# lost =  0.591392469704
# test_cumulative_accuracy :  0.819799979329
# epoch :  27
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.276016348079
# train_cumulative_accuracy :  0.907500026971
# duree :  2845.86927485
# lost =  0.59781653583
# test_cumulative_accuracy :  0.814699980021
# epoch :  28
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.267268845513
# train_cumulative_accuracy :  0.909200030565
# duree :  2946.27216983
# lost =  0.561158759296
# test_cumulative_accuracy :  0.821299980879
# epoch :  29
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.259865926057
# train_cumulative_accuracy :  0.910380028784
# duree :  3047.33716798
# lost =  0.591732034981
# test_cumulative_accuracy :  0.826899983883
# epoch :  30
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.257998992763
# train_cumulative_accuracy :  0.914500032067
# duree :  3149.31532383
# lost =  0.640822921097
# test_cumulative_accuracy :  0.806799978018
# epoch :  31
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.258347306885
# train_cumulative_accuracy :  0.912940030992
# duree :  3250.27893901
# lost =  0.589502485394
# test_cumulative_accuracy :  0.820899982452
# epoch :  32
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.251966928728
# train_cumulative_accuracy :  0.91438002944
# duree :  3351.662503
# lost =  0.597556454241
# test_cumulative_accuracy :  0.82059998095
# epoch :  33
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.241027668677
# train_cumulative_accuracy :  0.918480031788
# duree :  3453.23904586
# lost =  0.555623233914
# test_cumulative_accuracy :  0.832399981022
# epoch :  34
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.239869870022
# train_cumulative_accuracy :  0.917920028269
# duree :  3553.95893097
# lost =  0.599731780589
# test_cumulative_accuracy :  0.819899982214
# epoch :  35
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.235908143986
# train_cumulative_accuracy :  0.920360030532
# duree :  3655.31934595
# lost =  0.596013497263
# test_cumulative_accuracy :  0.82679997921
# epoch :  36
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.232046244871
# train_cumulative_accuracy :  0.922740029842
# duree :  3757.57737398
# lost =  0.618511070311
# test_cumulative_accuracy :  0.810399975777
# epoch :  37
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.233756486848
# train_cumulative_accuracy :  0.921260029674
# duree :  3859.90441298
# lost =  0.602465754151
# test_cumulative_accuracy :  0.823799979091
# epoch :  38
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.228492326476
# train_cumulative_accuracy :  0.923260032982
# duree :  3960.74940801
# lost =  0.59375294596
# test_cumulative_accuracy :  0.82739998579
# epoch :  39
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.226746678464
# train_cumulative_accuracy :  0.923260032684
# duree :  4063.09395194
# lost =  0.588023448288
# test_cumulative_accuracy :  0.829899985194
# epoch :  40
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.220983553138
# train_cumulative_accuracy :  0.925440029204
# duree :  4164.38980389
# lost =  0.649165884554
# test_cumulative_accuracy :  0.817899984121
# epoch :  41
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.217013429794
# train_cumulative_accuracy :  0.925720032454
# duree :  4268.50721002
# lost =  0.623546021283
# test_cumulative_accuracy :  0.827999978065
# epoch :  42
# j =  0
# batch_train_accuracy =  0.952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b70411a1ad36> in <module>()
#     206                     #print("j = ",j)
#     207                     img, lbl = gen_batch.next()
# --> 208                     optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5})
#     209                     c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1.})
#     210
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1447         none, the default session will be used.
#    1448     """
# -> 1449     _run_using_default_session(self, feed_dict, self.graph, session)
#    1450
#    1451
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3666                        "the operation's graph is different from the session's "
#    3667                        "graph.")
# -> 3668   session.run(operation, feed_dict)
#    3669
#    3670
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
