# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-4
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/truncated/adam/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    #keep_prob_input = tf.placeholder(tf.float32)
    #keep_prob_layers=tf.placeholder(tf.float32)
    #phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {
       
    'wc1': tf.Variable(tf.truncated_normal([3, 3, 3, 48]), name = "w1"),
    'wc2': tf.Variable(tf.truncated_normal([3, 3, 48, 48]), name = "w2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.Variable(tf.truncated_normal([3, 3, 48, 96]), name = "w3"),
    'wc4': tf.Variable(tf.truncated_normal([3, 3, 96, 96]), name = "w4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'wc5': tf.Variable(tf.truncated_normal([3, 3, 96, 192]), name = "w5"),
    'wc6': tf.Variable(tf.truncated_normal([3, 3, 192, 192]), name = "w6"),
    'wc7': tf.Variable(tf.truncated_normal([1, 1, 192, 192]), name = "w7"),
    'wc8': tf.Variable(tf.truncated_normal([3072, 512]), name = "w8"),
    'wc9': tf.Variable(tf.truncated_normal([512, 256]), name = "w9"),
    'wc10': tf.Variable(tf.truncated_normal([256, 10]), name = "w10"),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
    'bc10': tf.Variable(tf.truncated_normal([10], stddev=0.1), name = "b10"),
}
    
    # Create model
    #x_image = tf.reshape(x,[-1,28,28,1])
x_image = tf.reshape(x,[-1,32,32,3])
#x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_image, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc1']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_1_relu = tf.nn.relu(hidden_1)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc2']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_2_relu = tf.nn.relu(hidden_2)
#hidden_2_do=tf.nn.dropout(hidden_2_relu, keep_prob=prob_1)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc3']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_3_relu = tf.nn.relu(hidden_3)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc4']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_4_relu = tf.nn.relu(hidden_4)
#hidden_4_do=tf.nn.dropout(hidden_4_relu, keep_prob=prob_1)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc5']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_5_relu = tf.nn.relu(hidden_5)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc6']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_6_relu = tf.nn.relu(hidden_6)
#hidden_6_do=tf.nn.dropout(hidden_6_relu, keep_prob=prob_1)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
hidden_7_relu = tf.nn.relu(hidden_7)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_relu), weights['wc8']) + biases['bc8']
hidden_8_relu = tf.nn.relu(hidden_8)
#hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_relu, weights['wc9']) + biases['bc9']
hidden_9_relu = tf.nn.relu(hidden_9)
#hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_relu, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl})
                    c += sess.run(cost, feed_dict={x: img, y: lbl})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 512)
# (?, 256)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-10-76c1c73a0e2f>:165 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-76c1c73a0e2f>:166 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-76c1c73a0e2f>:173 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.1
# j =  50
# batch_train_accuracy =  0.24
# j =  100
# batch_train_accuracy =  0.3
# j =  150
# batch_train_accuracy =  0.235
# j =  200
# batch_train_accuracy =  0.345
# lost =  5.8829660511
# train_cumulative_accuracy :  0.26465998897
# duree :  85.5206308365
# lost =  2.59875669003
# test_cumulative_accuracy :  0.327199990302
# epoch :  1
# j =  0
# batch_train_accuracy =  0.32
# j =  50
# batch_train_accuracy =  0.39
# j =  100
# batch_train_accuracy =  0.305
# j =  150
# batch_train_accuracy =  0.315
# j =  200
# batch_train_accuracy =  0.385
# lost =  2.20153023481
# train_cumulative_accuracy :  0.362299989223
# duree :  181.451954842
# lost =  2.13431933641
# test_cumulative_accuracy :  0.358599989712
# epoch :  2
# j =  0
# batch_train_accuracy =  0.375
# j =  50
# batch_train_accuracy =  0.44
# j =  100
# batch_train_accuracy =  0.38
# j =  150
# batch_train_accuracy =  0.395
# j =  200
# batch_train_accuracy =  0.455
# lost =  1.81028270769
# train_cumulative_accuracy :  0.419879984736
# duree :  276.994699001
# lost =  1.88521468043
# test_cumulative_accuracy :  0.394999988079
# epoch :  3
# j =  0
# batch_train_accuracy =  0.43
# j =  50
# batch_train_accuracy =  0.445
# j =  100
# batch_train_accuracy =  0.41
# j =  150
# batch_train_accuracy =  0.46
# j =  200
# batch_train_accuracy =  0.51
# lost =  1.61543152046
# train_cumulative_accuracy :  0.460619980931
# duree :  372.535194874
# lost =  1.7447646451
# test_cumulative_accuracy :  0.415599987209
# epoch :  4
# j =  0
# batch_train_accuracy =  0.455
# j =  50
# batch_train_accuracy =  0.505
# j =  100
# batch_train_accuracy =  0.47
# j =  150
# batch_train_accuracy =  0.465
# j =  200
# batch_train_accuracy =  0.52
# lost =  1.48580684519
# train_cumulative_accuracy :  0.494739975572
# duree :  468.066180944
# lost =  1.6254021132
# test_cumulative_accuracy :  0.447199985087
# epoch :  5
# j =  0
# batch_train_accuracy =  0.495
# j =  50
# batch_train_accuracy =  0.5
# j =  100
# batch_train_accuracy =  0.505
# j =  150
# batch_train_accuracy =  0.505
# j =  200
# batch_train_accuracy =  0.555
# lost =  1.38705341005
# train_cumulative_accuracy :  0.523079977036
# duree :  563.580456972
# lost =  1.57007969618
# test_cumulative_accuracy :  0.4628999874
# epoch :  6
# j =  0
# batch_train_accuracy =  0.545
# j =  50
# batch_train_accuracy =  0.535
# j =  100
# batch_train_accuracy =  0.525
# j =  150
# batch_train_accuracy =  0.52
# j =  200
# batch_train_accuracy =  0.55
# lost =  1.30507715988
# train_cumulative_accuracy :  0.54761997664
# duree :  659.110675812
# lost =  1.50636354566
# test_cumulative_accuracy :  0.482299980521
# epoch :  7
# j =  0
# batch_train_accuracy =  0.57
# j =  50
# batch_train_accuracy =  0.56
# j =  100
# batch_train_accuracy =  0.565
# j =  150
# batch_train_accuracy =  0.58
# j =  200
# batch_train_accuracy =  0.575
# lost =  1.23379692316
# train_cumulative_accuracy :  0.570419977784
# duree :  754.639897823
# lost =  1.43819771767
# test_cumulative_accuracy :  0.505599976182
# epoch :  8
# j =  0
# batch_train_accuracy =  0.555
# j =  50
# batch_train_accuracy =  0.58
# j =  100
# batch_train_accuracy =  0.58
# j =  150
# batch_train_accuracy =  0.575
# j =  200
# batch_train_accuracy =  0.635
# lost =  1.17301227093
# train_cumulative_accuracy :  0.590139983296
# duree :  850.227253914
# lost =  1.41600746393
# test_cumulative_accuracy :  0.514999972582
# epoch :  9
# j =  0
# batch_train_accuracy =  0.575
# j =  50
# batch_train_accuracy =  0.61
# j =  100
# batch_train_accuracy =  0.58
# j =  150
# batch_train_accuracy =  0.615
# j =  200
# batch_train_accuracy =  0.66
# lost =  1.11559463358
# train_cumulative_accuracy :  0.609699982405
# duree :  945.75917387
# lost =  1.37312543392
# test_cumulative_accuracy :  0.529799966812
# epoch :  10
# j =  0
# batch_train_accuracy =  0.62
# j =  50
# batch_train_accuracy =  0.62
# j =  100
# batch_train_accuracy =  0.605
# j =  150
# batch_train_accuracy =  0.62
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.06334340763
# train_cumulative_accuracy :  0.626819980383
# duree :  1041.2803328
# lost =  1.35074967265
# test_cumulative_accuracy :  0.538799968362
# epoch :  11
# j =  0
# batch_train_accuracy =  0.64
# j =  50
# batch_train_accuracy =  0.65
# j =  100
# batch_train_accuracy =  0.62
# j =  150
# batch_train_accuracy =  0.625
# j =  200
# batch_train_accuracy =  0.695
# lost =  1.01518734908
# train_cumulative_accuracy :  0.644319982529
# duree :  1136.81895399
# lost =  1.32977379322
# test_cumulative_accuracy :  0.547399963439
# epoch :  12
# j =  0
# batch_train_accuracy =  0.655
# j =  50
# batch_train_accuracy =  0.665
# j =  100
# batch_train_accuracy =  0.625
# j =  150
# batch_train_accuracy =  0.64
# j =  200
# batch_train_accuracy =  0.7
# lost =  0.97240064168
# train_cumulative_accuracy :  0.660279987812
# duree :  1232.35686898
# lost =  1.30013870955
# test_cumulative_accuracy :  0.556199965477
# epoch :  13
# j =  0
# batch_train_accuracy =  0.665
# j =  50
# batch_train_accuracy =  0.685
# j =  100
# batch_train_accuracy =  0.645
# j =  150
# batch_train_accuracy =  0.65
# j =  200
# batch_train_accuracy =  0.7
# lost =  0.934306875467
# train_cumulative_accuracy :  0.673619988918
# duree :  1327.88914299
# lost =  1.25661779106
# test_cumulative_accuracy :  0.57259996444
# epoch :  14
# j =  0
# batch_train_accuracy =  0.72
# j =  50
# batch_train_accuracy =  0.705
# j =  100
# batch_train_accuracy =  0.645
# j =  150
# batch_train_accuracy =  0.655
# j =  200
# batch_train_accuracy =  0.725
# lost =  0.902169711828
# train_cumulative_accuracy :  0.685819994211
# duree :  1423.421489
# lost =  1.24013674378
# test_cumulative_accuracy :  0.576299971044
# epoch :  15
# j =  0
# batch_train_accuracy =  0.735
# j =  50
# batch_train_accuracy =  0.715
# j =  100
# batch_train_accuracy =  0.665
# j =  150
# batch_train_accuracy =  0.665
# j =  200
# batch_train_accuracy =  0.73
# lost =  0.866721503258
# train_cumulative_accuracy :  0.698239990711
# duree :  1518.93167186
# lost =  1.2227917856
# test_cumulative_accuracy :  0.588199967742
# epoch :  16
# j =  0
# batch_train_accuracy =  0.715
# j =  50
# batch_train_accuracy =  0.74
# j =  100
# batch_train_accuracy =  0.72
# j =  150
# batch_train_accuracy =  0.69
# j =  200
# batch_train_accuracy =  0.735
# lost =  0.820507727146
# train_cumulative_accuracy :  0.716219995022
# duree :  1614.4555428
# lost =  1.18232528031
# test_cumulative_accuracy :  0.602499968112
# epoch :  17
# j =  0
# batch_train_accuracy =  0.71
# j =  50
# batch_train_accuracy =  0.745
# j =  100
# batch_train_accuracy =  0.74
# j =  150
# batch_train_accuracy =  0.705
# j =  200
# batch_train_accuracy =  0.76
# lost =  0.777713384867
# train_cumulative_accuracy :  0.732079997063
# duree :  1710.01780295
# lost =  1.16344086111
# test_cumulative_accuracy :  0.60759996891
# epoch :  18
# j =  0
# batch_train_accuracy =  0.745
# j =  50
# batch_train_accuracy =  0.77
# j =  100
# batch_train_accuracy =  0.77
# j =  150
# batch_train_accuracy =  0.73
# j =  200
# batch_train_accuracy =  0.775
# lost =  0.732986678839
# train_cumulative_accuracy :  0.749519993782
# duree :  1805.54578781
# lost =  1.14885368943
# test_cumulative_accuracy :  0.616699970365
# epoch :  19
# j =  0
# batch_train_accuracy =  0.78
# j =  50
# batch_train_accuracy =  0.785
# j =  100
# batch_train_accuracy =  0.78
# j =  150
# batch_train_accuracy =  0.76
# j =  200
# batch_train_accuracy =  0.785
# lost =  0.690112020016
# train_cumulative_accuracy :  0.765219990253
# duree :  1901.06457496
# lost =  1.15284286261
# test_cumulative_accuracy :  0.619499969482
# epoch :  20
# j =  0
# batch_train_accuracy =  0.785
# j =  50
# batch_train_accuracy =  0.795
# j =  100
# batch_train_accuracy =  0.795
# j =  150
# batch_train_accuracy =  0.75
# j =  200
# batch_train_accuracy =  0.79
# lost =  0.651831749678
# train_cumulative_accuracy :  0.778979990005
# duree :  1996.57380199
# lost =  1.14244980335
# test_cumulative_accuracy :  0.625499970317
# epoch :  21
# j =  0
# batch_train_accuracy =  0.815
# j =  50
# batch_train_accuracy =  0.8
# j =  100
# batch_train_accuracy =  0.815
# j =  150
# batch_train_accuracy =  0.755
# j =  200
# batch_train_accuracy =  0.79
# lost =  0.614230267406
# train_cumulative_accuracy :  0.793799984932
# duree :  2092.10558987
# lost =  1.14416729569
# test_cumulative_accuracy :  0.627399964631
# epoch :  22
# j =  0
# batch_train_accuracy =  0.825
# j =  50
# batch_train_accuracy =  0.835
# j =  100
# batch_train_accuracy =  0.805
# j =  150
# batch_train_accuracy =  0.775
# j =  200
# batch_train_accuracy =  0.795
# lost =  0.582947134495
# train_cumulative_accuracy :  0.805499986887
# duree :  2187.74584699
# lost =  1.18334867239
# test_cumulative_accuracy :  0.622599967122
# epoch :  23
# j =  0
# batch_train_accuracy =  0.85
# j =  50
# batch_train_accuracy =  0.84
# j =  100
# batch_train_accuracy =  0.8
# j =  150
# batch_train_accuracy =  0.81
# j =  200
# batch_train_accuracy =  0.815
# lost =  0.561131751776
# train_cumulative_accuracy :  0.81235999012
# duree :  2283.27046585
# lost =  1.25593318105
# test_cumulative_accuracy :  0.607699971199
# epoch :  24
# j =  0
# batch_train_accuracy =  0.83
# j =  50
# batch_train_accuracy =  0.86
# j =  100
# batch_train_accuracy =  0.815
# j =  150
# batch_train_accuracy =  0.825
# j =  200
# batch_train_accuracy =  0.845
# lost =  0.546813030362
# train_cumulative_accuracy :  0.8175999856
# duree :  2378.80039001
# lost =  1.4006932044
# test_cumulative_accuracy :  0.575199968219
# epoch :  25
# j =  0
# batch_train_accuracy =  0.815
# j =  50
# batch_train_accuracy =  0.855
# j =  100
# batch_train_accuracy =  0.82
# j =  150
# batch_train_accuracy =  0.815
# j =  200
# batch_train_accuracy =  0.87
# lost =  0.53235759151
# train_cumulative_accuracy :  0.821639986038
# duree :  2474.31213999
# lost =  1.36346222043
# test_cumulative_accuracy :  0.589099965096
# epoch :  26
# j =  0
# batch_train_accuracy =  0.825
# j =  50
# batch_train_accuracy =  0.85
# j =  100
# batch_train_accuracy =  0.855
# j =  150
# batch_train_accuracy =  0.835
# j =  200
# batch_train_accuracy =  0.885
# lost =  0.492661454916
# train_cumulative_accuracy :  0.837339991093
# duree :  2569.83194995
# lost =  1.30219656289
# test_cumulative_accuracy :  0.60079996556
# epoch :  27
# j =  0
# batch_train_accuracy =  0.825
# j =  50
# batch_train_accuracy =  0.84
# j =  100
# batch_train_accuracy =  0.86
# j =  150
# batch_train_accuracy =  0.865
# j =  200
# batch_train_accuracy =  0.89
# lost =  0.449070437074
# train_cumulative_accuracy :  0.852199994564
# duree :  2665.35610795
# lost =  1.32240596235
# test_cumulative_accuracy :  0.601599967182
# epoch :  28
# j =  0
# batch_train_accuracy =  0.81
# j =  50
# batch_train_accuracy =  0.845
# j =  100
# batch_train_accuracy =  0.865
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  0.875
# lost =  0.416525126815
# train_cumulative_accuracy :  0.86473999548
# duree :  2760.88421082
# lost =  1.30434885204
# test_cumulative_accuracy :  0.607299968004
# epoch :  29
# j =  0
# batch_train_accuracy =  0.845
# j =  50
# batch_train_accuracy =  0.84
# j =  100
# batch_train_accuracy =  0.865
# j =  150
# batch_train_accuracy =  0.875
# j =  200
# batch_train_accuracy =  0.895
# lost =  0.391687677622
# train_cumulative_accuracy :  0.87371999073
# duree :  2856.396626
# lost =  1.28971516311
# test_cumulative_accuracy :  0.62009996593
# epoch :  30
# j =  0
# batch_train_accuracy =  0.85
# j =  50
# batch_train_accuracy =  0.87
# j =  100
# batch_train_accuracy =  0.89
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  0.945
# lost =  0.379960774779
# train_cumulative_accuracy :  0.878119987488
# duree :  2951.9052279
# lost =  1.40062269151
# test_cumulative_accuracy :  0.600999969542
# epoch :  31
# j =  0
# batch_train_accuracy =  0.87
# j =  50
# batch_train_accuracy =  0.905
# j =  100
# batch_train_accuracy =  0.89
# j =  150
# batch_train_accuracy =  0.865
# j =  200
# batch_train_accuracy =  0.945
# lost =  0.365771304667
# train_cumulative_accuracy :  0.882859983206
# duree :  3047.4273169
# lost =  1.46493132114
# test_cumulative_accuracy :  0.597999967635
# epoch :  32
# j =  0
# batch_train_accuracy =  0.84
# j =  50
# batch_train_accuracy =  0.925
# j =  100
# batch_train_accuracy =  0.92
# j =  150
# batch_train_accuracy =  0.88
# j =  200
# batch_train_accuracy =  0.935
# lost =  0.338178032279
# train_cumulative_accuracy :  0.89299997735
# duree :  3142.95009685
# lost =  1.43640904307
# test_cumulative_accuracy :  0.606299968958
# epoch :  33
# j =  0
# batch_train_accuracy =  0.9
# j =  50
# batch_train_accuracy =  0.935
# j =  100
# batch_train_accuracy =  0.885
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  0.88
# lost =  0.317043271959
# train_cumulative_accuracy :  0.900759973288
# duree :  3238.47091985
# lost =  1.42113243341
# test_cumulative_accuracy :  0.613699972928
# epoch :  34
# j =  0
# batch_train_accuracy =  0.9
# j =  50
# batch_train_accuracy =  0.94
# j =  100
# batch_train_accuracy =  0.88
# j =  150
# batch_train_accuracy =  0.88
# j =  200
# batch_train_accuracy =  0.895
# lost =  0.292800969005
# train_cumulative_accuracy :  0.909479967117
# duree :  3333.98428988
# lost =  1.39182292044
# test_cumulative_accuracy :  0.624699973762
# epoch :  35
# j =  0
# batch_train_accuracy =  0.91
# j =  50
# batch_train_accuracy =  0.955
# j =  100
# batch_train_accuracy =  0.935
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  0.935
# lost =  0.271749049962
# train_cumulative_accuracy :  0.91665996027
# duree :  3429.49109197
# lost =  1.38409657896
# test_cumulative_accuracy :  0.622099972069
# epoch :  36
# j =  0
# batch_train_accuracy =  0.935
# j =  50
# batch_train_accuracy =  0.945
# j =  100
# batch_train_accuracy =  0.96
# j =  150
# batch_train_accuracy =  0.905
# j =  200
# batch_train_accuracy =  0.94
# lost =  0.24971189028
# train_cumulative_accuracy :  0.92445995307
# duree :  3525.01480484
# lost =  1.42378331482
# test_cumulative_accuracy :  0.623599970043
# epoch :  37
# j =  0
# batch_train_accuracy =  0.94
# j =  50
# batch_train_accuracy =  0.96
# j =  100
# batch_train_accuracy =  0.965
# j =  150
# batch_train_accuracy =  0.92
# j =  200
# batch_train_accuracy =  0.965
# lost =  0.222805142164
# train_cumulative_accuracy :  0.935279943228
# duree :  3620.56901193
# lost =  1.46961883128
# test_cumulative_accuracy :  0.617699971199
# epoch :  38
# j =  0
# batch_train_accuracy =  0.965
# j =  50
# batch_train_accuracy =  0.94
# j =  100
# batch_train_accuracy =  0.96
# j =  150
# batch_train_accuracy =  0.94
# j =  200
# batch_train_accuracy =  0.96
# lost =  0.193992065936
# train_cumulative_accuracy :  0.946239932299
# duree :  3716.17914486
# lost =  1.60384323537
# test_cumulative_accuracy :  0.609299967587
# epoch :  39
# j =  0
# batch_train_accuracy =  0.96
# j =  50
# batch_train_accuracy =  0.935
# j =  100
# batch_train_accuracy =  0.975
# j =  150
# batch_train_accuracy =  0.945
# j =  200
# batch_train_accuracy =  0.98
# lost =  0.180444849759
# train_cumulative_accuracy :  0.950999927759
# duree :  3811.78931499
# lost =  1.6341210413
# test_cumulative_accuracy :  0.610299968421
# epoch :  40
# j =  0
# batch_train_accuracy =  0.955
# j =  50
# batch_train_accuracy =  0.96
# j =  100
# batch_train_accuracy =  0.96
# j =  150
# batch_train_accuracy =  0.94
# j =  200
# batch_train_accuracy =  0.92
# lost =  0.183598052859
# train_cumulative_accuracy :  0.947919931173
# duree :  3907.42828584
# lost =  1.60079123199
# test_cumulative_accuracy :  0.611099972129
# epoch :  41
# j =  0
# batch_train_accuracy =  0.975
# j =  50
# batch_train_accuracy =  0.945
# j =  100
# batch_train_accuracy =  0.955
# j =  150
# batch_train_accuracy =  0.925
# j =  200
# batch_train_accuracy =  0.925
# lost =  0.179250649482
# train_cumulative_accuracy :  0.947119932652
# duree :  4003.02570796
# lost =  1.46492207825
# test_cumulative_accuracy :  0.640599973202
# epoch :  42
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.945
# j =  100
# batch_train_accuracy =  0.985
# j =  150
# batch_train_accuracy =  0.97
# j =  200
# batch_train_accuracy =  0.93
# lost =  0.149099012852
# train_cumulative_accuracy :  0.958719922304
# duree :  4098.62591887
# lost =  1.51904891133
# test_cumulative_accuracy :  0.645699971914
# epoch :  43
# j =  0
# batch_train_accuracy =  0.975
# j =  50
# batch_train_accuracy =  0.965
# j =  100
# batch_train_accuracy =  0.99
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  0.945
# lost =  0.124096713066
# train_cumulative_accuracy :  0.969719910622
# duree :  4194.23152494
# lost =  1.52603513181
# test_cumulative_accuracy :  0.650099972486
# epoch :  44
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.965
# j =  100
# batch_train_accuracy =  0.99
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  0.96
# lost =  0.113656515136
# train_cumulative_accuracy :  0.972399909496
# duree :  4289.83573484
# lost =  1.59413196206
# test_cumulative_accuracy :  0.644499971271
# epoch :  45
# j =  0
# batch_train_accuracy =  0.985
# j =  50
# batch_train_accuracy =  0.945
# j =  100
# batch_train_accuracy =  0.985
# j =  150
# batch_train_accuracy =  0.975
# j =  200
# batch_train_accuracy =  0.975
# lost =  0.0974974687397
# train_cumulative_accuracy :  0.977959902763
# duree :  4385.42705679
# lost =  1.63737573266
# test_cumulative_accuracy :  0.64919996798
# epoch :  46
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.985
# j =  100
# batch_train_accuracy =  0.98
# j =  150
# batch_train_accuracy =  0.985
# j =  200
# batch_train_accuracy =  0.985
# lost =  0.0729213370532
# train_cumulative_accuracy :  0.986219893932
# duree :  4481.03416085
# lost =  1.7054294908
# test_cumulative_accuracy :  0.648299974799
# epoch :  47
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.985
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  0.98
# lost =  0.0606036072746
# train_cumulative_accuracy :  0.990619891644
# duree :  4576.63572884
# lost =  1.78945662975
# test_cumulative_accuracy :  0.644199972749
# epoch :  48
# j =  0
# batch_train_accuracy =  0.985
# j =  50
# batch_train_accuracy =  0.97
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.995
# lost =  0.0536525218114
# train_cumulative_accuracy :  0.991779891014
# duree :  4672.22798085
# lost =  1.87086414933
# test_cumulative_accuracy :  0.637199972868
# epoch :  49
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.99
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-76c1c73a0e2f> in <module>()
#     212                         print("batch_train_accuracy = ",batch_train_accuracy)
#     213
# --> 214                     train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], feed_dict={x: img, y: lbl})
#     215                     writer.add_summary(train_acc_summ,epoch * 250 + j)
#     216                     writer.add_summary(train_lost_summ,epoch * 250 + j)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
