# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-4
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/truncated/nag/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    #keep_prob_input = tf.placeholder(tf.float32)
    #keep_prob_layers=tf.placeholder(tf.float32)
    #phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {
       
    'wc1': tf.Variable(tf.truncated_normal([3, 3, 3, 48]), name = "w1"),
    'wc2': tf.Variable(tf.truncated_normal([3, 3, 48, 48]), name = "w2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.Variable(tf.truncated_normal([3, 3, 48, 96]), name = "w3"),
    'wc4': tf.Variable(tf.truncated_normal([3, 3, 96, 96]), name = "w4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'wc5': tf.Variable(tf.truncated_normal([3, 3, 96, 192]), name = "w5"),
    'wc6': tf.Variable(tf.truncated_normal([3, 3, 192, 192]), name = "w6"),
    'wc7': tf.Variable(tf.truncated_normal([1, 1, 192, 192]), name = "w7"),
    'wc8': tf.Variable(tf.truncated_normal([3072, 512]), name = "w8"),
    'wc9': tf.Variable(tf.truncated_normal([512, 256]), name = "w9"),
    'wc10': tf.Variable(tf.truncated_normal([256, 10]), name = "w10"),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
    'bc10': tf.Variable(tf.truncated_normal([10], stddev=0.1), name = "b10"),
}
    
    # Create model
    #x_image = tf.reshape(x,[-1,28,28,1])
x_image = tf.reshape(x,[-1,32,32,3])
#x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_image, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc1']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_1_relu = tf.nn.relu(hidden_1)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc2']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_2_relu = tf.nn.relu(hidden_2)
#hidden_2_do=tf.nn.dropout(hidden_2_relu, keep_prob=prob_1)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc3']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_3_relu = tf.nn.relu(hidden_3)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc4']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_4_relu = tf.nn.relu(hidden_4)
#hidden_4_do=tf.nn.dropout(hidden_4_relu, keep_prob=prob_1)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc5']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_5_relu = tf.nn.relu(hidden_5)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc6']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_6_relu = tf.nn.relu(hidden_6)
#hidden_6_do=tf.nn.dropout(hidden_6_relu, keep_prob=prob_1)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
hidden_7_relu = tf.nn.relu(hidden_7)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_relu), weights['wc8']) + biases['bc8']
hidden_8_relu = tf.nn.relu(hidden_8)
#hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_relu, weights['wc9']) + biases['bc9']
hidden_9_relu = tf.nn.relu(hidden_9)
#hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_relu, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov=True).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl})
                    c += sess.run(cost, feed_dict={x: img, y: lbl})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 512)
# (?, 256)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-10-42e3345a7d9e>:165 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-42e3345a7d9e>:166 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-42e3345a7d9e>:173 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.1
# j =  50
# batch_train_accuracy =  0.285
# j =  100
# batch_train_accuracy =  0.305
# j =  150
# batch_train_accuracy =  0.29
# j =  200
# batch_train_accuracy =  0.345
# lost =  3.45295894432
# train_cumulative_accuracy :  0.295939989924
# duree :  86.9360301495
# lost =  1.84416522026
# test_cumulative_accuracy :  0.346599987745
# epoch :  1
# j =  0
# batch_train_accuracy =  0.325
# j =  50
# batch_train_accuracy =  0.405
# j =  100
# batch_train_accuracy =  0.395
# j =  150
# batch_train_accuracy =  0.355
# j =  200
# batch_train_accuracy =  0.475
# lost =  1.69662200308
# train_cumulative_accuracy :  0.39639998734
# duree :  183.012816191
# lost =  1.69509625435
# test_cumulative_accuracy :  0.397999986708
# epoch :  2
# j =  0
# batch_train_accuracy =  0.385
# j =  50
# batch_train_accuracy =  0.42
# j =  100
# batch_train_accuracy =  0.44
# j =  150
# batch_train_accuracy =  0.4
# j =  200
# batch_train_accuracy =  0.48
# lost =  1.58890920925
# train_cumulative_accuracy :  0.431759984136
# duree :  279.998088121
# lost =  1.61735025048
# test_cumulative_accuracy :  0.427199986577
# epoch :  3
# j =  0
# batch_train_accuracy =  0.43
# j =  50
# batch_train_accuracy =  0.47
# j =  100
# batch_train_accuracy =  0.445
# j =  150
# batch_train_accuracy =  0.405
# j =  200
# batch_train_accuracy =  0.52
# lost =  1.52486755657
# train_cumulative_accuracy :  0.454499981523
# duree :  378.59334898
# lost =  1.55847474694
# test_cumulative_accuracy :  0.445799987912
# epoch :  4
# j =  0
# batch_train_accuracy =  0.42
# j =  50
# batch_train_accuracy =  0.485
# j =  100
# batch_train_accuracy =  0.43
# j =  150
# batch_train_accuracy =  0.41
# j =  200
# batch_train_accuracy =  0.515
# lost =  1.47955759001
# train_cumulative_accuracy :  0.47015998137
# duree :  476.761233091
# lost =  1.52104513407
# test_cumulative_accuracy :  0.458299984634
# epoch :  5
# j =  0
# batch_train_accuracy =  0.44
# j =  50
# batch_train_accuracy =  0.485
# j =  100
# batch_train_accuracy =  0.455
# j =  150
# batch_train_accuracy =  0.43
# j =  200
# batch_train_accuracy =  0.555
# lost =  1.44486933851
# train_cumulative_accuracy :  0.482899980307
# duree :  574.572358131
# lost =  1.49225863338
# test_cumulative_accuracy :  0.468399981856
# epoch :  6
# j =  0
# batch_train_accuracy =  0.455
# j =  50
# batch_train_accuracy =  0.495
# j =  100
# batch_train_accuracy =  0.465
# j =  150
# batch_train_accuracy =  0.435
# j =  200
# batch_train_accuracy =  0.535
# lost =  1.41654682589
# train_cumulative_accuracy :  0.494419978142
# duree :  671.018272161
# lost =  1.46921507001
# test_cumulative_accuracy :  0.475699978471
# epoch :  7
# j =  0
# batch_train_accuracy =  0.47
# j =  50
# batch_train_accuracy =  0.51
# j =  100
# batch_train_accuracy =  0.48
# j =  150
# batch_train_accuracy =  0.445
# j =  200
# batch_train_accuracy =  0.56
# lost =  1.39248500872
# train_cumulative_accuracy :  0.502919976234
# duree :  768.264480114
# lost =  1.44200291276
# test_cumulative_accuracy :  0.484999981225
# epoch :  8
# j =  0
# batch_train_accuracy =  0.485
# j =  50
# batch_train_accuracy =  0.5
# j =  100
# batch_train_accuracy =  0.485
# j =  150
# batch_train_accuracy =  0.45
# j =  200
# batch_train_accuracy =  0.56
# lost =  1.37051747036
# train_cumulative_accuracy :  0.511239975929
# duree :  866.017172098
# lost =  1.42571065664
# test_cumulative_accuracy :  0.49109998107
# epoch :  9
# j =  0
# batch_train_accuracy =  0.475
# j =  50
# batch_train_accuracy =  0.525
# j =  100
# batch_train_accuracy =  0.505
# j =  150
# batch_train_accuracy =  0.45
# j =  200
# batch_train_accuracy =  0.555
# lost =  1.35125803232
# train_cumulative_accuracy :  0.518059973717
# duree :  962.280304193
# lost =  1.41146842599
# test_cumulative_accuracy :  0.498799977005
# epoch :  10
# j =  0
# batch_train_accuracy =  0.495
# j =  50
# batch_train_accuracy =  0.525
# j =  100
# batch_train_accuracy =  0.535
# j =  150
# batch_train_accuracy =  0.47
# j =  200
# batch_train_accuracy =  0.58
# lost =  1.33311472893
# train_cumulative_accuracy :  0.525999974132
# duree :  1059.56995106
# lost =  1.39524649024
# test_cumulative_accuracy :  0.502299973071
# epoch :  11
# j =  0
# batch_train_accuracy =  0.505
# j =  50
# batch_train_accuracy =  0.54
# j =  100
# batch_train_accuracy =  0.52
# j =  150
# batch_train_accuracy =  0.48
# j =  200
# batch_train_accuracy =  0.59
# lost =  1.31714301538
# train_cumulative_accuracy :  0.533819976211
# duree :  1156.89257312
# lost =  1.37588355899
# test_cumulative_accuracy :  0.509699974358
# epoch :  12
# j =  0
# batch_train_accuracy =  0.52
# j =  50
# batch_train_accuracy =  0.54
# j =  100
# batch_train_accuracy =  0.525
# j =  150
# batch_train_accuracy =  0.49
# j =  200
# batch_train_accuracy =  0.61
# lost =  1.30186706686
# train_cumulative_accuracy :  0.538379977584
# duree :  1254.72969413
# lost =  1.35970946193
# test_cumulative_accuracy :  0.514399974346
# epoch :  13
# j =  0
# batch_train_accuracy =  0.525
# j =  50
# batch_train_accuracy =  0.55
# j =  100
# batch_train_accuracy =  0.52
# j =  150
# batch_train_accuracy =  0.49
# j =  200
# batch_train_accuracy =  0.625
# lost =  1.28749892902
# train_cumulative_accuracy :  0.544159976721
# duree :  1351.93620706
# lost =  1.34739508986
# test_cumulative_accuracy :  0.516999973655
# epoch :  14
# j =  0
# batch_train_accuracy =  0.515
# j =  50
# batch_train_accuracy =  0.57
# j =  100
# batch_train_accuracy =  0.53
# j =  150
# batch_train_accuracy =  0.505
# j =  200
# batch_train_accuracy =  0.63
# lost =  1.27371959877
# train_cumulative_accuracy :  0.547939978123
# duree :  1447.30840206
# lost =  1.33505869746
# test_cumulative_accuracy :  0.522099971771
# epoch :  15
# j =  0
# batch_train_accuracy =  0.52
# j =  50
# batch_train_accuracy =  0.585
# j =  100
# batch_train_accuracy =  0.52
# j =  150
# batch_train_accuracy =  0.505
# j =  200
# batch_train_accuracy =  0.63
# lost =  1.2600843811
# train_cumulative_accuracy :  0.553059977055
# duree :  1544.5805192
# lost =  1.3225148499
# test_cumulative_accuracy :  0.52569997102
# epoch :  16
# j =  0
# batch_train_accuracy =  0.53
# j =  50
# batch_train_accuracy =  0.59
# j =  100
# batch_train_accuracy =  0.535
# j =  150
# batch_train_accuracy =  0.53
# j =  200
# batch_train_accuracy =  0.63
# lost =  1.24762096119
# train_cumulative_accuracy :  0.557819978833
# duree :  1641.21037102
# lost =  1.31260279179
# test_cumulative_accuracy :  0.528999969661
# epoch :  17
# j =  0
# batch_train_accuracy =  0.53
# j =  50
# batch_train_accuracy =  0.595
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.525
# j =  200
# batch_train_accuracy =  0.64
# lost =  1.2354624548
# train_cumulative_accuracy :  0.561739978671
# duree :  1738.31208706
# lost =  1.3039052856
# test_cumulative_accuracy :  0.533099968135
# epoch :  18
# j =  0
# batch_train_accuracy =  0.525
# j =  50
# batch_train_accuracy =  0.615
# j =  100
# batch_train_accuracy =  0.55
# j =  150
# batch_train_accuracy =  0.53
# j =  200
# batch_train_accuracy =  0.65
# lost =  1.22387349796
# train_cumulative_accuracy :  0.566099976659
# duree :  1835.131001
# lost =  1.29375451684
# test_cumulative_accuracy :  0.536999971271
# epoch :  19
# j =  0
# batch_train_accuracy =  0.55
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.565
# j =  150
# batch_train_accuracy =  0.53
# j =  200
# batch_train_accuracy =  0.65
# lost =  1.21306959772
# train_cumulative_accuracy :  0.569519981861
# duree :  1933.40827799
# lost =  1.28349495411
# test_cumulative_accuracy :  0.54289996773
# epoch :  20
# j =  0
# batch_train_accuracy =  0.55
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.54
# j =  200
# batch_train_accuracy =  0.645
# lost =  1.20279692507
# train_cumulative_accuracy :  0.573999980092
# duree :  2032.43649817
# lost =  1.27589033127
# test_cumulative_accuracy :  0.546199965179
# epoch :  21
# j =  0
# batch_train_accuracy =  0.56
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.55
# j =  150
# batch_train_accuracy =  0.535
# j =  200
# batch_train_accuracy =  0.66
# lost =  1.19243829489
# train_cumulative_accuracy :  0.576559982419
# duree :  2131.05583811
# lost =  1.26777908683
# test_cumulative_accuracy :  0.546099968553
# epoch :  22
# j =  0
# batch_train_accuracy =  0.56
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.555
# j =  200
# batch_train_accuracy =  0.66
# lost =  1.18241131783
# train_cumulative_accuracy :  0.581539984822
# duree :  2229.87671518
# lost =  1.25843192577
# test_cumulative_accuracy :  0.547699967027
# epoch :  23
# j =  0
# batch_train_accuracy =  0.575
# j =  50
# batch_train_accuracy =  0.595
# j =  100
# batch_train_accuracy =  0.565
# j =  150
# batch_train_accuracy =  0.555
# j =  200
# batch_train_accuracy =  0.67
# lost =  1.1726147728
# train_cumulative_accuracy :  0.585859979987
# duree :  2327.67088008
# lost =  1.25312098265
# test_cumulative_accuracy :  0.550899962485
# epoch :  24
# j =  0
# batch_train_accuracy =  0.58
# j =  50
# batch_train_accuracy =  0.595
# j =  100
# batch_train_accuracy =  0.55
# j =  150
# batch_train_accuracy =  0.545
# j =  200
# batch_train_accuracy =  0.665
# lost =  1.1631218915
# train_cumulative_accuracy :  0.588759982944
# duree :  2424.02511621
# lost =  1.24546714783
# test_cumulative_accuracy :  0.554299965203
# epoch :  25
# j =  0
# batch_train_accuracy =  0.58
# j =  50
# batch_train_accuracy =  0.595
# j =  100
# batch_train_accuracy =  0.56
# j =  150
# batch_train_accuracy =  0.55
# j =  200
# batch_train_accuracy =  0.685
# lost =  1.15420025492
# train_cumulative_accuracy :  0.592159985542
# duree :  2521.54115701
# lost =  1.23933335066
# test_cumulative_accuracy :  0.557999967933
# epoch :  26
# j =  0
# batch_train_accuracy =  0.59
# j =  50
# batch_train_accuracy =  0.6
# j =  100
# batch_train_accuracy =  0.56
# j =  150
# batch_train_accuracy =  0.565
# j =  200
# batch_train_accuracy =  0.685
# lost =  1.14554228306
# train_cumulative_accuracy :  0.595519984484
# duree :  2618.5304172
# lost =  1.23370099247
# test_cumulative_accuracy :  0.559299966693
# epoch :  27
# j =  0
# batch_train_accuracy =  0.605
# j =  50
# batch_train_accuracy =  0.6
# j =  100
# batch_train_accuracy =  0.55
# j =  150
# batch_train_accuracy =  0.57
# j =  200
# batch_train_accuracy =  0.68
# lost =  1.13688398004
# train_cumulative_accuracy :  0.598679987788
# duree :  2714.0725441
# lost =  1.22752022564
# test_cumulative_accuracy :  0.562099969983
# epoch :  28
# j =  0
# batch_train_accuracy =  0.6
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.565
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.12868730617
# train_cumulative_accuracy :  0.60241998291
# duree :  2809.96761513
# lost =  1.22363556325
# test_cumulative_accuracy :  0.563399965167
# epoch :  29
# j =  0
# batch_train_accuracy =  0.615
# j =  50
# batch_train_accuracy =  0.605
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.56
# j =  200
# batch_train_accuracy =  0.685
# lost =  1.12023754025
# train_cumulative_accuracy :  0.605599982738
# duree :  2905.82291603
# lost =  1.21599266648
# test_cumulative_accuracy :  0.568099968731
# epoch :  30
# j =  0
# batch_train_accuracy =  0.615
# j =  50
# batch_train_accuracy =  0.63
# j =  100
# batch_train_accuracy =  0.555
# j =  150
# batch_train_accuracy =  0.56
# j =  200
# batch_train_accuracy =  0.68
# lost =  1.1124026773
# train_cumulative_accuracy :  0.60817998457
# duree :  3002.93745518
# lost =  1.21052485287
# test_cumulative_accuracy :  0.570299966037
# epoch :  31
# j =  0
# batch_train_accuracy =  0.63
# j =  50
# batch_train_accuracy =  0.64
# j =  100
# batch_train_accuracy =  0.565
# j =  150
# batch_train_accuracy =  0.56
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.10410970259
# train_cumulative_accuracy :  0.610719983101
# duree :  3099.92536998
# lost =  1.20628149331
# test_cumulative_accuracy :  0.571499965787
# epoch :  32
# j =  0
# batch_train_accuracy =  0.63
# j =  50
# batch_train_accuracy =  0.64
# j =  100
# batch_train_accuracy =  0.575
# j =  150
# batch_train_accuracy =  0.56
# j =  200
# batch_train_accuracy =  0.67
# lost =  1.09653277588
# train_cumulative_accuracy :  0.614139983892
# duree :  3197.74496317
# lost =  1.19890135705
# test_cumulative_accuracy :  0.576399964094
# epoch :  33
# j =  0
# batch_train_accuracy =  0.63
# j =  50
# batch_train_accuracy =  0.64
# j =  100
# batch_train_accuracy =  0.575
# j =  150
# batch_train_accuracy =  0.58
# j =  200
# batch_train_accuracy =  0.665
# lost =  1.08906574368
# train_cumulative_accuracy :  0.617139985085
# duree :  3295.59353018
# lost =  1.19392419219
# test_cumulative_accuracy :  0.577899962068
# epoch :  34
# j =  0
# batch_train_accuracy =  0.625
# j =  50
# batch_train_accuracy =  0.63
# j =  100
# batch_train_accuracy =  0.57
# j =  150
# batch_train_accuracy =  0.57
# j =  200
# batch_train_accuracy =  0.67
# lost =  1.08131262016
# train_cumulative_accuracy :  0.618059981346
# duree :  3392.28900909
# lost =  1.18953999698
# test_cumulative_accuracy :  0.578099963367
# epoch :  35
# j =  0
# batch_train_accuracy =  0.635
# j =  50
# batch_train_accuracy =  0.625
# j =  100
# batch_train_accuracy =  0.575
# j =  150
# batch_train_accuracy =  0.58
# j =  200
# batch_train_accuracy =  0.67
# lost =  1.0740322051
# train_cumulative_accuracy :  0.621459985495
# duree :  3487.39837718
# lost =  1.18394796729
# test_cumulative_accuracy :  0.581299965084
# epoch :  36
# j =  0
# batch_train_accuracy =  0.65
# j =  50
# batch_train_accuracy =  0.63
# j =  100
# batch_train_accuracy =  0.565
# j =  150
# batch_train_accuracy =  0.605
# j =  200
# batch_train_accuracy =  0.67
# lost =  1.06668833876
# train_cumulative_accuracy :  0.624959988356
# duree :  3582.40082121
# lost =  1.17969560683
# test_cumulative_accuracy :  0.58229996413
# epoch :  37
# j =  0
# batch_train_accuracy =  0.645
# j =  50
# batch_train_accuracy =  0.635
# j =  100
# batch_train_accuracy =  0.58
# j =  150
# batch_train_accuracy =  0.605
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.06004618931
# train_cumulative_accuracy :  0.627139983416
# duree :  3677.3865571
# lost =  1.17379042447
# test_cumulative_accuracy :  0.585399964452
# epoch :  38
# j =  0
# batch_train_accuracy =  0.65
# j =  50
# batch_train_accuracy =  0.635
# j =  100
# batch_train_accuracy =  0.585
# j =  150
# batch_train_accuracy =  0.605
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.0531224525
# train_cumulative_accuracy :  0.62955998373
# duree :  3772.41456604
# lost =  1.16922976315
# test_cumulative_accuracy :  0.586399962902
# epoch :  39
# j =  0
# batch_train_accuracy =  0.65
# j =  50
# batch_train_accuracy =  0.635
# j =  100
# batch_train_accuracy =  0.585
# j =  150
# batch_train_accuracy =  0.6
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.04615471745
# train_cumulative_accuracy :  0.631679980993
# duree :  3868.78070021
# lost =  1.16412230849
# test_cumulative_accuracy :  0.587299964726
# epoch :  40
# j =  0
# batch_train_accuracy =  0.65
# j =  50
# batch_train_accuracy =  0.645
# j =  100
# batch_train_accuracy =  0.575
# j =  150
# batch_train_accuracy =  0.585
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.03953717804
# train_cumulative_accuracy :  0.634139984369
# duree :  3964.27644515
# lost =  1.16183972359
# test_cumulative_accuracy :  0.587999964654
# epoch :  41
# j =  0
# batch_train_accuracy =  0.65
# j =  50
# batch_train_accuracy =  0.65
# j =  100
# batch_train_accuracy =  0.6
# j =  150
# batch_train_accuracy =  0.595
# j =  200
# batch_train_accuracy =  0.675
# lost =  1.03301518869
# train_cumulative_accuracy :  0.636439986467
# duree :  4062.28321719
# lost =  1.15477926373
# test_cumulative_accuracy :  0.589499962032
# epoch :  42
# j =  0
# batch_train_accuracy =  0.645
# j =  50
# batch_train_accuracy =  0.64
# j =  100
# batch_train_accuracy =  0.595
# j =  150
# batch_train_accuracy =  0.59
# j =  200
# batch_train_accuracy =  0.685
# lost =  1.02663127518
# train_cumulative_accuracy :  0.639119982243
# duree :  4157.72150707
# lost =  1.15182180405
# test_cumulative_accuracy :  0.591899963319
# epoch :  43
# j =  0
# batch_train_accuracy =  0.655
# j =  50
# batch_train_accuracy =  0.665
# j =  100
# batch_train_accuracy =  0.6
# j =  150
# batch_train_accuracy =  0.6
# j =  200
# batch_train_accuracy =  0.68
# lost =  1.02051205087
# train_cumulative_accuracy :  0.641779985189
# duree :  4253.37105608
# lost =  1.14504037499
# test_cumulative_accuracy :  0.592499964535
# epoch :  44
# j =  0
# batch_train_accuracy =  0.665
# j =  50
# batch_train_accuracy =  0.68
# j =  100
# batch_train_accuracy =  0.595
# j =  150
# batch_train_accuracy =  0.615
# j =  200
# batch_train_accuracy =  0.685
# lost =  1.01402458215
# train_cumulative_accuracy :  0.643699981689
# duree :  4349.47091508
# lost =  1.14222896636
# test_cumulative_accuracy :  0.593699963689
# epoch :  45
# j =  0
# batch_train_accuracy =  0.66
# j =  50
# batch_train_accuracy =  0.675
# j =  100
# batch_train_accuracy =  0.595
# j =  150
# batch_train_accuracy =  0.6
# j =  200
# batch_train_accuracy =  0.68
# lost =  1.00799608731
# train_cumulative_accuracy :  0.646759985447
# duree :  4445.64890909
# lost =  1.13600390971
# test_cumulative_accuracy :  0.596699968278
# epoch :  46
# j =  0
# batch_train_accuracy =  0.67
# j =  50
# batch_train_accuracy =  0.67
# j =  100
# batch_train_accuracy =  0.605
# j =  150
# batch_train_accuracy =  0.58
# j =  200
# batch_train_accuracy =  0.68
# lost =  1.00197092557
# train_cumulative_accuracy :  0.648339983463
# duree :  4542.88077402
# lost =  1.13356334627
# test_cumulative_accuracy :  0.597799969316
# epoch :  47
# j =  0
# batch_train_accuracy =  0.67
# j =  50
# batch_train_accuracy =  0.68
# j =  100
# batch_train_accuracy =  0.595
# j =  150
# batch_train_accuracy =  0.595
# j =  200
# batch_train_accuracy =  0.68
# lost =  0.995982859612
# train_cumulative_accuracy :  0.650999984741
# duree :  4640.4081502
# lost =  1.12819235682
# test_cumulative_accuracy :  0.601299968362
# epoch :  48
# j =  0
# batch_train_accuracy =  0.685
# j =  50
# batch_train_accuracy =  0.67
# j =  100
# batch_train_accuracy =  0.595
# j =  150
# batch_train_accuracy =  0.595
# j =  200
# batch_train_accuracy =  0.685
# lost =  0.990331764221
# train_cumulative_accuracy :  0.65315998292
# duree :  4737.21224618
# lost =  1.12395182908
# test_cumulative_accuracy :  0.603399967849
# epoch :  49
# j =  0
# batch_train_accuracy =  0.675
# j =  50
# batch_train_accuracy =  0.67
# j =  100
# batch_train_accuracy =  0.61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-42e3345a7d9e> in <module>()
#     202                     #print("j = ",j)
#     203                     img, lbl = gen_batch.next()
# --> 204                     optimizer.run(feed_dict={x: img, y: lbl})
#     205                     c += sess.run(cost, feed_dict={x: img, y: lbl})
#     206
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1447         none, the default session will be used.
#    1448     """
# -> 1449     _run_using_default_session(self, feed_dict, self.graph, session)
#    1450
#    1451
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3666                        "the operation's graph is different from the session's "
#    3667                        "graph.")
# -> 3668   session.run(operation, feed_dict)
#    3669
#    3670
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
