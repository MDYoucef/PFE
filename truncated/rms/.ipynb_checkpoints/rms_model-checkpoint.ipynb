# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-4
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/truncated/rms/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    #keep_prob_input = tf.placeholder(tf.float32)
    #keep_prob_layers=tf.placeholder(tf.float32)
    #phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {
       
    'wc1': tf.Variable(tf.truncated_normal([3, 3, 3, 48]), name = "w1"),
    'wc2': tf.Variable(tf.truncated_normal([3, 3, 48, 48]), name = "w2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.Variable(tf.truncated_normal([3, 3, 48, 96]), name = "w3"),
    'wc4': tf.Variable(tf.truncated_normal([3, 3, 96, 96]), name = "w4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'wc5': tf.Variable(tf.truncated_normal([3, 3, 96, 192]), name = "w5"),
    'wc6': tf.Variable(tf.truncated_normal([3, 3, 192, 192]), name = "w6"),
    'wc7': tf.Variable(tf.truncated_normal([1, 1, 192, 192]), name = "w7"),
    'wc8': tf.Variable(tf.truncated_normal([3072, 512]), name = "w8"),
    'wc9': tf.Variable(tf.truncated_normal([512, 256]), name = "w9"),
    'wc10': tf.Variable(tf.truncated_normal([256, 10]), name = "w10"),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
    'bc10': tf.Variable(tf.truncated_normal([10], stddev=0.1), name = "b10"),
}
    
    # Create model
    #x_image = tf.reshape(x,[-1,28,28,1])
x_image = tf.reshape(x,[-1,32,32,3])
#x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_image, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc1']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_1_relu = tf.nn.relu(hidden_1)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc2']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_2_relu = tf.nn.relu(hidden_2)
#hidden_2_do=tf.nn.dropout(hidden_2_relu, keep_prob=prob_1)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc3']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_3_relu = tf.nn.relu(hidden_3)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc4']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_4_relu = tf.nn.relu(hidden_4)
#hidden_4_do=tf.nn.dropout(hidden_4_relu, keep_prob=prob_1)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc5']
#hidden_1_bn = batch_norm(hidden_1, 32, phase_train, convolutional = True)
hidden_5_relu = tf.nn.relu(hidden_5)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME') + biases['bc6']
#hidden_2_bn = batch_norm(hidden_2, 32, phase_train, convolutional = True)
hidden_6_relu = tf.nn.relu(hidden_6)
#hidden_6_do=tf.nn.dropout(hidden_6_relu, keep_prob=prob_1)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
hidden_7_relu = tf.nn.relu(hidden_7)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_relu), weights['wc8']) + biases['bc8']
hidden_8_relu = tf.nn.relu(hidden_8)
#hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_relu, weights['wc9']) + biases['bc9']
hidden_9_relu = tf.nn.relu(hidden_9)
#hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_relu, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl})
                    c += sess.run(cost, feed_dict={x: img, y: lbl})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 512)
# (?, 256)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-10-6f0535a672dd>:165 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-6f0535a672dd>:166 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-10-6f0535a672dd>:173 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.09
# j =  50
# batch_train_accuracy =  0.165
# j =  100
# batch_train_accuracy =  0.195
# j =  150
# batch_train_accuracy =  0.295
# j =  200
# batch_train_accuracy =  0.29
# lost =  9.21428166199
# train_cumulative_accuracy :  0.235579991698
# duree :  85.6836009026
# lost =  2.39331149101
# test_cumulative_accuracy :  0.2829999879
# epoch :  1
# j =  0
# batch_train_accuracy =  0.265
# j =  50
# batch_train_accuracy =  0.34
# j =  100
# batch_train_accuracy =  0.465
# j =  150
# batch_train_accuracy =  0.41
# j =  200
# batch_train_accuracy =  0.585
# lost =  1.62394484949
# train_cumulative_accuracy :  0.440739981532
# duree :  181.350006819
# lost =  1.66549034715
# test_cumulative_accuracy :  0.416499986649
# epoch :  2
# j =  0
# batch_train_accuracy =  0.435
# j =  50
# batch_train_accuracy =  0.575
# j =  100
# batch_train_accuracy =  0.515
# j =  150
# batch_train_accuracy =  0.54
# j =  200
# batch_train_accuracy =  0.63
# lost =  1.29339736843
# train_cumulative_accuracy :  0.547299979925
# duree :  276.644609928
# lost =  1.45733016253
# test_cumulative_accuracy :  0.486499978006
# epoch :  3
# j =  0
# batch_train_accuracy =  0.61
# j =  50
# batch_train_accuracy =  0.645
# j =  100
# batch_train_accuracy =  0.605
# j =  150
# batch_train_accuracy =  0.55
# j =  200
# batch_train_accuracy =  0.7
# lost =  1.12506936455
# train_cumulative_accuracy :  0.609099983215
# duree :  371.961305857
# lost =  1.36400343418
# test_cumulative_accuracy :  0.522799975574
# epoch :  4
# j =  0
# batch_train_accuracy =  0.665
# j =  50
# batch_train_accuracy =  0.71
# j =  100
# batch_train_accuracy =  0.69
# j =  150
# batch_train_accuracy =  0.665
# j =  200
# batch_train_accuracy =  0.72
# lost =  0.988783747911
# train_cumulative_accuracy :  0.661979986906
# duree :  467.28818202
# lost =  1.2726593411
# test_cumulative_accuracy :  0.553899966478
# epoch :  5
# j =  0
# batch_train_accuracy =  0.73
# j =  50
# batch_train_accuracy =  0.735
# j =  100
# batch_train_accuracy =  0.7
# j =  150
# batch_train_accuracy =  0.7
# j =  200
# batch_train_accuracy =  0.705
# lost =  0.87794506073
# train_cumulative_accuracy :  0.701739992142
# duree :  562.565405846
# lost =  1.24649746835
# test_cumulative_accuracy :  0.563799965978
# epoch :  6
# j =  0
# batch_train_accuracy =  0.77
# j =  50
# batch_train_accuracy =  0.79
# j =  100
# batch_train_accuracy =  0.725
# j =  150
# batch_train_accuracy =  0.68
# j =  200
# batch_train_accuracy =  0.8
# lost =  0.776043931484
# train_cumulative_accuracy :  0.738919992924
# duree :  657.864485025
# lost =  1.37308455825
# test_cumulative_accuracy :  0.546599969566
# epoch :  7
# j =  0
# batch_train_accuracy =  0.72
# j =  50
# batch_train_accuracy =  0.805
# j =  100
# batch_train_accuracy =  0.745
# j =  150
# batch_train_accuracy =  0.785
# j =  200
# batch_train_accuracy =  0.85
# lost =  0.682786448121
# train_cumulative_accuracy :  0.774959988594
# duree :  753.169984818
# lost =  1.22243997216
# test_cumulative_accuracy :  0.581799964309
# epoch :  8
# j =  0
# batch_train_accuracy =  0.81
# j =  50
# batch_train_accuracy =  0.87
# j =  100
# batch_train_accuracy =  0.725
# j =  150
# batch_train_accuracy =  0.795
# j =  200
# batch_train_accuracy =  0.88
# lost =  0.596315076947
# train_cumulative_accuracy :  0.807379988194
# duree :  848.514295816
# lost =  1.28246034026
# test_cumulative_accuracy :  0.576299968958
# epoch :  9
# j =  0
# batch_train_accuracy =  0.8
# j =  50
# batch_train_accuracy =  0.735
# j =  100
# batch_train_accuracy =  0.805
# j =  150
# batch_train_accuracy =  0.83
# j =  200
# batch_train_accuracy =  0.9
# lost =  0.521852694511
# train_cumulative_accuracy :  0.834419990778
# duree :  943.802345991
# lost =  1.21256880641
# test_cumulative_accuracy :  0.598099964857
# epoch :  10
# j =  0
# batch_train_accuracy =  0.83
# j =  50
# batch_train_accuracy =  0.885
# j =  100
# batch_train_accuracy =  0.845
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  0.94
# lost =  0.448376799941
# train_cumulative_accuracy :  0.862479984999
# duree :  1039.07703686
# lost =  1.28164573133
# test_cumulative_accuracy :  0.590099963248
# epoch :  11
# j =  0
# batch_train_accuracy =  0.845
# j =  50
# batch_train_accuracy =  0.9
# j =  100
# batch_train_accuracy =  0.88
# j =  150
# batch_train_accuracy =  0.855
# j =  200
# batch_train_accuracy =  0.91
# lost =  0.388366619349
# train_cumulative_accuracy :  0.884039975166
# duree :  1134.36093688
# lost =  1.28174599588
# test_cumulative_accuracy :  0.602099968493
# epoch :  12
# j =  0
# batch_train_accuracy =  0.91
# j =  50
# batch_train_accuracy =  0.89
# j =  100
# batch_train_accuracy =  0.875
# j =  150
# batch_train_accuracy =  0.91
# j =  200
# batch_train_accuracy =  0.93
# lost =  0.326816940546
# train_cumulative_accuracy :  0.905659963846
# duree :  1229.65393686
# lost =  1.28537674487
# test_cumulative_accuracy :  0.608099963963
# epoch :  13
# j =  0
# batch_train_accuracy =  0.915
# j =  50
# batch_train_accuracy =  0.93
# j =  100
# batch_train_accuracy =  0.94
# j =  150
# batch_train_accuracy =  0.945
# j =  200
# batch_train_accuracy =  0.97
# lost =  0.279542359859
# train_cumulative_accuracy :  0.920799954176
# duree :  1324.92847705
# lost =  1.29750742793
# test_cumulative_accuracy :  0.613499964774
# epoch :  14
# j =  0
# batch_train_accuracy =  0.95
# j =  50
# batch_train_accuracy =  0.94
# j =  100
# batch_train_accuracy =  0.935
# j =  150
# batch_train_accuracy =  0.845
# j =  200
# batch_train_accuracy =  0.97
# lost =  0.232301240593
# train_cumulative_accuracy :  0.936179939508
# duree :  1420.18928695
# lost =  1.43919369221
# test_cumulative_accuracy :  0.599399968088
# epoch :  15
# j =  0
# batch_train_accuracy =  0.955
# j =  50
# batch_train_accuracy =  0.96
# j =  100
# batch_train_accuracy =  0.84
# j =  150
# batch_train_accuracy =  0.955
# j =  200
# batch_train_accuracy =  0.985
# lost =  0.197705026597
# train_cumulative_accuracy :  0.947999927998
# duree :  1515.43276691
# lost =  1.43296033919
# test_cumulative_accuracy :  0.610599969625
# epoch :  16
# j =  0
# batch_train_accuracy =  0.985
# j =  50
# batch_train_accuracy =  0.98
# j =  100
# batch_train_accuracy =  0.92
# j =  150
# batch_train_accuracy =  0.935
# j =  200
# batch_train_accuracy =  0.99
# lost =  0.166112656996
# train_cumulative_accuracy :  0.956139922142
# duree :  1610.68863487
# lost =  1.53020458221
# test_cumulative_accuracy :  0.604799967706
# epoch :  17
# j =  0
# batch_train_accuracy =  0.975
# j =  50
# batch_train_accuracy =  0.89
# j =  100
# batch_train_accuracy =  0.9
# j =  150
# batch_train_accuracy =  0.97
# j =  200
# batch_train_accuracy =  0.98
# lost =  0.139958988637
# train_cumulative_accuracy :  0.964339913845
# duree :  1705.96825695
# lost =  1.54640140414
# test_cumulative_accuracy :  0.609599972367
# epoch :  18
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.925
# j =  100
# batch_train_accuracy =  0.945
# j =  150
# batch_train_accuracy =  0.945
# j =  200
# batch_train_accuracy =  0.955
# lost =  0.117824174732
# train_cumulative_accuracy :  0.969759909391
# duree :  1801.22929788
# lost =  1.76408095241
# test_cumulative_accuracy :  0.598999966383
# epoch :  19
# j =  0
# batch_train_accuracy =  0.945
# j =  50
# batch_train_accuracy =  0.99
# j =  100
# batch_train_accuracy =  0.925
# j =  150
# batch_train_accuracy =  0.935
# j =  200
# batch_train_accuracy =  0.965
# lost =  0.0995179446042
# train_cumulative_accuracy :  0.974539904594
# duree :  1896.47654605
# lost =  1.99717198133
# test_cumulative_accuracy :  0.568999968171
# epoch :  20
# j =  0
# batch_train_accuracy =  0.95
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  0.985
# j =  200
# batch_train_accuracy =  0.96
# lost =  0.0856638436168
# train_cumulative_accuracy :  0.977479901552
# duree :  1991.71693301
# lost =  1.66780822754
# test_cumulative_accuracy :  0.619499964118
# epoch :  21
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.985
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  0.97
# lost =  0.0714401460551
# train_cumulative_accuracy :  0.982079897165
# duree :  2086.95996404
# lost =  1.91448433757
# test_cumulative_accuracy :  0.597799969912
# epoch :  22
# j =  0
# batch_train_accuracy =  0.96
# j =  50
# batch_train_accuracy =  0.995
# j =  100
# batch_train_accuracy =  0.89
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0658532808833
# train_cumulative_accuracy :  0.982459897041
# duree :  2182.22098184
# lost =  1.88081087112
# test_cumulative_accuracy :  0.609599973261
# epoch :  23
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.98
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  0.975
# j =  200
# batch_train_accuracy =  0.955
# lost =  0.0564031233788
# train_cumulative_accuracy :  0.985259894609
# duree :  2277.54607487
# lost =  1.86223779678
# test_cumulative_accuracy :  0.622399966121
# epoch :  24
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.99
# lost =  0.0521858415473
# train_cumulative_accuracy :  0.986439893007
# duree :  2372.83048487
# lost =  2.02179041147
# test_cumulative_accuracy :  0.61309997201
# epoch :  25
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.945
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.94
# lost =  0.0471093524322
# train_cumulative_accuracy :  0.987059893131
# duree :  2468.09514785
# lost =  2.02482548594
# test_cumulative_accuracy :  0.621599968374
# epoch :  26
# j =  0
# batch_train_accuracy =  0.995
# j =  50
# batch_train_accuracy =  0.915
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.995
# lost =  0.0510426186379
# train_cumulative_accuracy :  0.986219893456
# duree :  2563.35841393
# lost =  2.13996811032
# test_cumulative_accuracy :  0.615599966943
# epoch :  27
# j =  0
# batch_train_accuracy =  0.965
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0464896172592
# train_cumulative_accuracy :  0.987419892311
# duree :  2658.6344409
# lost =  1.98609626293
# test_cumulative_accuracy :  0.634599972963
# epoch :  28
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  0.995
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0432941505937
# train_cumulative_accuracy :  0.987939891815
# duree :  2753.9113369
# lost =  2.04741915703
# test_cumulative_accuracy :  0.629599969685
# epoch :  29
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0384606967578
# train_cumulative_accuracy :  0.990559889555
# duree :  2849.18902302
# lost =  2.11007843018
# test_cumulative_accuracy :  0.628799972534
# epoch :  30
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.98
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  0.995
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0353727524038
# train_cumulative_accuracy :  0.990719889879
# duree :  2944.44744182
# lost =  2.20361998796
# test_cumulative_accuracy :  0.628399969935
# epoch :  31
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.875
# j =  150
# batch_train_accuracy =  0.885
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0388120179647
# train_cumulative_accuracy :  0.989539890528
# duree :  3039.72460604
# lost =  3.44828220367
# test_cumulative_accuracy :  0.532999972403
# epoch :  32
# j =  0
# batch_train_accuracy =  0.955
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0303153656241
# train_cumulative_accuracy :  0.992239888191
# duree :  3135.00586605
# lost =  2.188413167
# test_cumulative_accuracy :  0.635899966657
# epoch :  33
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.965
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0258610359775
# train_cumulative_accuracy :  0.992619887829
# duree :  3230.2877779
# lost =  2.26951901913
# test_cumulative_accuracy :  0.635699970722
# epoch :  34
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.93
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0273676278773
# train_cumulative_accuracy :  0.992359888077
# duree :  3325.56235003
# lost =  2.28029986262
# test_cumulative_accuracy :  0.633099974394
# epoch :  35
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0250299266328
# train_cumulative_accuracy :  0.993379887104
# duree :  3420.826226
# lost =  2.2465238297
# test_cumulative_accuracy :  0.639699968994
# epoch :  36
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.99
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  0.995
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0255411445994
# train_cumulative_accuracy :  0.993799886703
# duree :  3516.11811185
# lost =  2.35625118136
# test_cumulative_accuracy :  0.63359996438
# epoch :  37
# j =  0
# batch_train_accuracy =  0.985
# j =  50
# batch_train_accuracy =  0.98
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  0.965
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0239887765809
# train_cumulative_accuracy :  0.993819886208
# duree :  3611.41536999
# lost =  2.36468992114
# test_cumulative_accuracy :  0.639599966407
# epoch :  38
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0230097490428
# train_cumulative_accuracy :  0.993459887028
# duree :  3706.77684593
# lost =  2.52155334234
# test_cumulative_accuracy :  0.63229996562
# epoch :  39
# j =  0
# batch_train_accuracy =  0.965
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.030710864037
# train_cumulative_accuracy :  0.992259887934
# duree :  3802.1790669
# lost =  2.42314681888
# test_cumulative_accuracy :  0.635599973798
# epoch :  40
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.99
# j =  100
# batch_train_accuracy =  0.975
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0159783285921
# train_cumulative_accuracy :  0.995279885292
# duree :  3897.5390079
# lost =  2.52159376025
# test_cumulative_accuracy :  0.631899972558
# epoch :  41
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  0.975
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0183399840707
# train_cumulative_accuracy :  0.994979885578
# duree :  3992.90955782
# lost =  2.45168596506
# test_cumulative_accuracy :  0.638699968457
# epoch :  42
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.99
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0173482904027
# train_cumulative_accuracy :  0.995219885349
# duree :  4088.29473305
# lost =  2.46765270114
# test_cumulative_accuracy :  0.645699970126
# epoch :  43
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.017670397557
# train_cumulative_accuracy :  0.995319885254
# duree :  4185.23408103
# lost =  2.51693795323
# test_cumulative_accuracy :  0.642199967206
# epoch :  44
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0195871337015
# train_cumulative_accuracy :  0.994539885998
# duree :  4281.65388703
# lost =  2.52059633613
# test_cumulative_accuracy :  0.637599967718
# epoch :  45
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.9
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0162436648074
# train_cumulative_accuracy :  0.99545988512
# duree :  4379.53321886
# lost =  2.69575202823
# test_cumulative_accuracy :  0.625999965072
# epoch :  46
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  0.99
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.013759977517
# train_cumulative_accuracy :  0.996139884472
# duree :  4475.02540898
# lost =  2.76031350017
# test_cumulative_accuracy :  0.63189997077
# epoch :  47
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0161228180401
# train_cumulative_accuracy :  0.995519885063
# duree :  4570.51903296
# lost =  2.65715915561
# test_cumulative_accuracy :  0.638499968052
# epoch :  48
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.955
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  0.99
# lost =  0.0172615541007
# train_cumulative_accuracy :  0.994979885578
# duree :  4666.951442
# lost =  2.65820162058
# test_cumulative_accuracy :  0.64039996922
# epoch :  49
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  1.0
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0127775455033
# train_cumulative_accuracy :  0.996019884586
# duree :  4765.12291098
# lost =  2.77979431391
# test_cumulative_accuracy :  0.632699972987
# epoch :  50
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# j =  100
# batch_train_accuracy =  0.995
# j =  150
# batch_train_accuracy =  1.0
# j =  200
# batch_train_accuracy =  1.0
# lost =  0.0124219795306
# train_cumulative_accuracy :  0.997099883556
# duree :  4860.80400896
# lost =  2.75773128152
# test_cumulative_accuracy :  0.640999971628
# epoch :  51
# j =  0
# batch_train_accuracy =  1.0
# j =  50
# batch_train_accuracy =  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6f0535a672dd> in <module>()
#     202                     #print("j = ",j)
#     203                     img, lbl = gen_batch.next()
# --> 204                     optimizer.run(feed_dict={x: img, y: lbl})
#     205                     c += sess.run(cost, feed_dict={x: img, y: lbl})
#     206
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1447         none, the default session will be used.
#    1448     """
# -> 1449     _run_using_default_session(self, feed_dict, self.graph, session)
#    1450
#    1451
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3666                        "the operation's graph is different from the session's "
#    3667                        "graph.")
# -> 3668   session.run(operation, feed_dict)
#    3669
#    3670
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
