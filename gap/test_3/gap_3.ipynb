# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def batch_norm(x, n_out, phase_train, convolutional = False, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if convolutional:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        
        else:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
        
        ema = tf.train.ExponentialMovingAverage(decay=0.999)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/gap/test_3/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [1, 1, 192, 10], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),   
    'bc8': tf.Variable(tf.constant(0.1, shape=[10]), name = "b8"),
}

'''
'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_bn, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_2)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_2)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
#hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.nn.conv2d(hidden_7_do, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

gap = tf.nn.avg_pool(hidden_8_relu, ksize=[1, 4, 4, 1], strides=[1, 4, 4, 1], padding="VALID")
print(gap.get_shape())

out_y = tf.reshape(gap, (-1,10))
print(out_y.get_shape())
    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init, {phase_train: True})
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, phase_train: True})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (1, 1, 192, 10)
# 4
# 1
# 1
# 192
# 10
# 1920
# (192,)
# 1
# 192
# 192
# (10,)
# 1
# 10
# 10
# total_parameters :  683098
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 10)
# (?, 1, 1, 10)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-11-b6c3d204c4e9>:159 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-b6c3d204c4e9>:160 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-b6c3d204c4e9>:167 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.336
# j =  160
# batch_train_accuracy =  0.504
# j =  240
# batch_train_accuracy =  0.504
# j =  320
# batch_train_accuracy =  0.576
# lost =  1.95476638108
# train_cumulative_accuracy :  0.420219998397
# duree :  108.643174171
# lost =  2.0966158855
# test_cumulative_accuracy :  0.463199982643
# epoch :  1
# j =  0
# batch_train_accuracy =  0.472
# j =  80
# batch_train_accuracy =  0.528
# j =  160
# batch_train_accuracy =  0.496
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.552
# lost =  1.81157312363
# train_cumulative_accuracy :  0.510239997059
# duree :  228.856676102
# lost =  1.82037550211
# test_cumulative_accuracy :  0.513899973333
# epoch :  2
# j =  0
# batch_train_accuracy =  0.536
# j =  80
# batch_train_accuracy =  0.56
# j =  160
# batch_train_accuracy =  0.544
# j =  240
# batch_train_accuracy =  0.632
# j =  320
# batch_train_accuracy =  0.608
# lost =  1.57620227143
# train_cumulative_accuracy :  0.555559995919
# duree :  349.455202103
# lost =  1.41244703889
# test_cumulative_accuracy :  0.579899967015
# epoch :  3
# j =  0
# batch_train_accuracy =  0.584
# j =  80
# batch_train_accuracy =  0.6
# j =  160
# batch_train_accuracy =  0.64
# j =  240
# batch_train_accuracy =  0.664
# j =  320
# batch_train_accuracy =  0.68
# lost =  1.31305541784
# train_cumulative_accuracy :  0.616939994022
# duree :  469.891340017
# lost =  1.21809071779
# test_cumulative_accuracy :  0.645899968147
# epoch :  4
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.712
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.672
# lost =  1.14149011791
# train_cumulative_accuracy :  0.658719998598
# duree :  590.323117018
# lost =  1.06541758418
# test_cumulative_accuracy :  0.678299967647
# epoch :  5
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.696
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.696
# lost =  0.98530577518
# train_cumulative_accuracy :  0.701859998554
# duree :  710.640382051
# lost =  0.967489477396
# test_cumulative_accuracy :  0.708299970031
# epoch :  6
# j =  0
# batch_train_accuracy =  0.712
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.72
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.752
# lost =  0.831936116666
# train_cumulative_accuracy :  0.7390800035
# duree :  830.844248056
# lost =  0.838160150051
# test_cumulative_accuracy :  0.736799973845
# epoch :  7
# j =  0
# batch_train_accuracy =  0.792
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.8
# lost =  0.724321655333
# train_cumulative_accuracy :  0.765740007013
# duree :  951.355154991
# lost =  0.745324808955
# test_cumulative_accuracy :  0.766799978018
# epoch :  8
# j =  0
# batch_train_accuracy =  0.856
# j =  80
# batch_train_accuracy =  0.848
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.768
# lost =  0.675278254524
# train_cumulative_accuracy :  0.781700012535
# duree :  1071.79468417
# lost =  0.751414840221
# test_cumulative_accuracy :  0.767799980044
# epoch :  9
# j =  0
# batch_train_accuracy =  0.848
# j =  80
# batch_train_accuracy =  0.864
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.792
# lost =  0.604871756211
# train_cumulative_accuracy :  0.800140012056
# duree :  1192.05520105
# lost =  0.680798048079
# test_cumulative_accuracy :  0.78559997797
# epoch :  10
# j =  0
# batch_train_accuracy =  0.84
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.776
# lost =  0.553612739593
# train_cumulative_accuracy :  0.815640016943
# duree :  1312.50639105
# lost =  0.678911025226
# test_cumulative_accuracy :  0.783999980092
# epoch :  11
# j =  0
# batch_train_accuracy =  0.872
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.528492012471
# train_cumulative_accuracy :  0.825640018284
# duree :  1432.97260809
# lost =  0.660435210466
# test_cumulative_accuracy :  0.793899978995
# epoch :  12
# j =  0
# batch_train_accuracy =  0.88
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.792
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.483831293508
# train_cumulative_accuracy :  0.839320017844
# duree :  1553.302284
# lost =  0.588078501225
# test_cumulative_accuracy :  0.812699981928
# epoch :  13
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.832
# lost =  0.457294100113
# train_cumulative_accuracy :  0.84482001856
# duree :  1673.71900511
# lost =  0.581707050204
# test_cumulative_accuracy :  0.816399977207
# epoch :  14
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.848
# j =  320
# batch_train_accuracy =  0.848
# lost =  0.428211755753
# train_cumulative_accuracy :  0.853300020695
# duree :  1794.2366271
# lost =  0.59722443819
# test_cumulative_accuracy :  0.816099980474
# epoch :  15
# j =  0
# batch_train_accuracy =  0.88
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.824
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.401082840674
# train_cumulative_accuracy :  0.863540024012
# duree :  1914.67461014
# lost =  0.568023930192
# test_cumulative_accuracy :  0.822499985099
# epoch :  16
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.394211163372
# train_cumulative_accuracy :  0.864340022504
# duree :  2035.343328
# lost =  0.529739484638
# test_cumulative_accuracy :  0.828199984431
# epoch :  17
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.856
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.36233519379
# train_cumulative_accuracy :  0.875460024923
# duree :  2158.06047821
# lost =  0.531343578398
# test_cumulative_accuracy :  0.833799979687
# epoch :  18
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.364707412124
# train_cumulative_accuracy :  0.874980024993
# duree :  2281.56540012
# lost =  0.56191385448
# test_cumulative_accuracy :  0.827599983215
# epoch :  19
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.340058390945
# train_cumulative_accuracy :  0.883080027699
# duree :  2404.21823812
# lost =  0.498074044436
# test_cumulative_accuracy :  0.8413999933
# epoch :  20
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.872
# lost =  0.339269022271
# train_cumulative_accuracy :  0.882940028459
# duree :  2532.08656216
# lost =  0.513547915965
# test_cumulative_accuracy :  0.836299988627
# epoch :  21
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.848
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.317638757974
# train_cumulative_accuracy :  0.888940027058
# duree :  2654.95924401
# lost =  0.481661099643
# test_cumulative_accuracy :  0.845999993682
# epoch :  22
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.856
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.303412188739
# train_cumulative_accuracy :  0.894620028883
# duree :  2779.3693521
# lost =  0.547362135798
# test_cumulative_accuracy :  0.834899984598
# epoch :  23
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.288520904966
# train_cumulative_accuracy :  0.899400028437
# duree :  2901.46163917
# lost =  0.493860386908
# test_cumulative_accuracy :  0.842299987674
# epoch :  24
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.278010535426
# train_cumulative_accuracy :  0.903000027537
# duree :  3025.68916798
# lost =  0.456220149249
# test_cumulative_accuracy :  0.85560000062
# epoch :  25
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.260003168881
# train_cumulative_accuracy :  0.907560027987
# duree :  3151.68777299
# lost =  0.505678118765
# test_cumulative_accuracy :  0.842799987793
# epoch :  26
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.250832231659
# train_cumulative_accuracy :  0.912560029328
# duree :  3277.16520905
# lost =  0.441793020219
# test_cumulative_accuracy :  0.8593999964
# epoch :  27
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.237531774137
# train_cumulative_accuracy :  0.917000028789
# duree :  3405.15527916
# lost =  0.513253271282
# test_cumulative_accuracy :  0.842599986196
# epoch :  28
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.224676659722
# train_cumulative_accuracy :  0.922120031118
# duree :  3530.50834417
# lost =  0.475039684176
# test_cumulative_accuracy :  0.851599990726
# epoch :  29
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.219752044659
# train_cumulative_accuracy :  0.92322002992
# duree :  3655.54714704
# lost =  0.451712609977
# test_cumulative_accuracy :  0.858399994373
# epoch :  30
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.215264868587
# train_cumulative_accuracy :  0.924620030373
# duree :  3779.93854904
# lost =  0.467115019262
# test_cumulative_accuracy :  0.856499986649
# epoch :  31
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.20642313974
# train_cumulative_accuracy :  0.926360032558
# duree :  3907.927356
# lost =  0.466480538696
# test_cumulative_accuracy :  0.857299997211
# epoch :  32
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.207073976621
# train_cumulative_accuracy :  0.926740029007
# duree :  4034.26722813
# lost =  0.428393344283
# test_cumulative_accuracy :  0.864899995327
# epoch :  33
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.191479584305
# train_cumulative_accuracy :  0.932440029532
# duree :  4158.68292403
# lost =  0.453124864399
# test_cumulative_accuracy :  0.859299990535
# epoch :  34
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.184179007467
# train_cumulative_accuracy :  0.936120035052
# duree :  4279.3204751
# lost =  0.485290777087
# test_cumulative_accuracy :  0.851899987459
# epoch :  35
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.177035413077
# train_cumulative_accuracy :  0.93828003183
# duree :  4399.43385506
# lost =  0.462505575418
# test_cumulative_accuracy :  0.863400000334
# epoch :  36
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.167935377788
# train_cumulative_accuracy :  0.941640035063
# duree :  4519.51273608
# lost =  0.480640204251
# test_cumulative_accuracy :  0.855899995565
# epoch :  37
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.169834495671
# train_cumulative_accuracy :  0.941500033438
# duree :  4640.13445115
# lost =  0.500943834782
# test_cumulative_accuracy :  0.851599988341
# epoch :  38
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.158715476859
# train_cumulative_accuracy :  0.945400034785
# duree :  4759.9988122
# lost =  0.432269796729
# test_cumulative_accuracy :  0.870500007868
# epoch :  39
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.159400904849
# train_cumulative_accuracy :  0.944740033001
# duree :  4879.88035202
# lost =  0.496263257861
# test_cumulative_accuracy :  0.853599992394
# epoch :  40
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.146454925993
# train_cumulative_accuracy :  0.94908003673
# duree :  5001.05201817
# lost =  0.460032791048
# test_cumulative_accuracy :  0.860199995637
# epoch :  41
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.146443683971
# train_cumulative_accuracy :  0.948240033388
# duree :  5124.13573408
# lost =  0.469527544975
# test_cumulative_accuracy :  0.865699999332
# epoch :  42
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.149711867804
# train_cumulative_accuracy :  0.948180034161
# duree :  5244.66371202
# lost =  0.425486523062
# test_cumulative_accuracy :  0.870199995637
# epoch :  43
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.133354869606
# train_cumulative_accuracy :  0.953360035121
# duree :  5368.92165709
# lost =  0.494125675857
# test_cumulative_accuracy :  0.857900000215
# epoch :  44
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.132506338144
# train_cumulative_accuracy :  0.953980035782
# duree :  5490.52807713
# lost =  0.444114479721
# test_cumulative_accuracy :  0.872000003457
# epoch :  45
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.135839452036
# train_cumulative_accuracy :  0.951540038884
# duree :  5613.24802804
# lost =  0.460989821404
# test_cumulative_accuracy :  0.863699994087
# epoch :  46
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.118802449899
# train_cumulative_accuracy :  0.958560037315
# duree :  5737.11064601
# lost =  0.448137790561
# test_cumulative_accuracy :  0.869000002146
# epoch :  47
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.120040075816
# train_cumulative_accuracy :  0.957840035558
# duree :  5861.68006921
# lost =  0.465286214501
# test_cumulative_accuracy :  0.865700001121
# epoch :  48
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.115436894866
# train_cumulative_accuracy :  0.960340037942
# duree :  5983.839957
# lost =  0.447706872076
# test_cumulative_accuracy :  0.869199997187
# epoch :  49
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.106156205614
# train_cumulative_accuracy :  0.963440035582
# duree :  6103.8199811
# lost =  0.424853016734
# test_cumulative_accuracy :  0.872400006056
# epoch :  50
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.110396522535
# train_cumulative_accuracy :  0.961940037608
# duree :  6225.2472682
# lost =  0.508841878325
# test_cumulative_accuracy :  0.85169999063
# epoch :  51
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.111025608359
# train_cumulative_accuracy :  0.961300038546
# duree :  6347.28349304
# lost =  0.419870873541
# test_cumulative_accuracy :  0.877900007367
# epoch :  52
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.100375348236
# train_cumulative_accuracy :  0.965500038117
# duree :  6468.45935202
# lost =  0.484177507311
# test_cumulative_accuracy :  0.865100001693
# epoch :  53
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0976328179426
# train_cumulative_accuracy :  0.966380036175
# duree :  6590.67026806
# lost =  0.471725710183
# test_cumulative_accuracy :  0.865999991894
# epoch :  54
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.097944149184
# train_cumulative_accuracy :  0.96690003261
# duree :  6713.06577706
# lost =  0.468456829786
# test_cumulative_accuracy :  0.865899999142
# epoch :  55
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0993733967375
# train_cumulative_accuracy :  0.964480034411
# duree :  6834.47176409
# lost =  0.426348889172
# test_cumulative_accuracy :  0.875700007081
# epoch :  56
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0904971335689
# train_cumulative_accuracy :  0.969100033194
# duree :  6957.8729682
# lost =  0.475898289084
# test_cumulative_accuracy :  0.867099997997
# epoch :  57
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0756814938365
# train_cumulative_accuracy :  0.974780029953
# duree :  7081.04040313
# lost =  0.4478409262
# test_cumulative_accuracy :  0.874000009298
# epoch :  58
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0771570730419
# train_cumulative_accuracy :  0.974040030539
# duree :  7203.90709901
# lost =  0.451892069429
# test_cumulative_accuracy :  0.875500001907
# epoch :  59
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0938028034428
# train_cumulative_accuracy :  0.967120033056
# duree :  7326.15934515
# lost =  0.474637611657
# test_cumulative_accuracy :  0.86940000236
# epoch :  60
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0768692964036
# train_cumulative_accuracy :  0.974380029142
# duree :  7448.36799812
# lost =  0.496532472074
# test_cumulative_accuracy :  0.863799993992
# epoch :  61
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0791212353949
# train_cumulative_accuracy :  0.972700032741
# duree :  7571.55742812
# lost =  0.453585944027
# test_cumulative_accuracy :  0.872600001693
# epoch :  62
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0741853715153
# train_cumulative_accuracy :  0.974620028585
# duree :  7694.59370804
# lost =  0.502792915702
# test_cumulative_accuracy :  0.868299998641
# epoch :  63
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0782134849625
# train_cumulative_accuracy :  0.972620030493
# duree :  7817.49254417
# lost =  0.445661323965
# test_cumulative_accuracy :  0.871600000858
# epoch :  64
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.06286027594
# train_cumulative_accuracy :  0.979580028355
# duree :  7940.7052412
# lost =  0.45708669588
# test_cumulative_accuracy :  0.874500002265
# epoch :  65
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0602305210754
# train_cumulative_accuracy :  0.979940025061
# duree :  8061.36910319
# lost =  0.455800661743
# test_cumulative_accuracy :  0.874800007939
# epoch :  66
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0639905532426
# train_cumulative_accuracy :  0.979420024455
# duree :  8181.59228301
# lost =  0.476626024842
# test_cumulative_accuracy :  0.869600003958
# epoch :  67
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0606284070783
# train_cumulative_accuracy :  0.980300026834
# duree :  8302.07449698
# lost =  0.540985512733
# test_cumulative_accuracy :  0.865899999142
# epoch :  68
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0612622675835
# train_cumulative_accuracy :  0.979380025864
# duree :  8422.32287407
# lost =  0.45271693185
# test_cumulative_accuracy :  0.877800001502
# epoch :  69
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.062377372093
# train_cumulative_accuracy :  0.978920027912
# duree :  8542.75715017
# lost =  0.523140324354
# test_cumulative_accuracy :  0.86099999845
# epoch :  70
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0644998928322
# train_cumulative_accuracy :  0.978680026084
# duree :  8663.0526402
# lost =  0.446177072078
# test_cumulative_accuracy :  0.87720000267
# epoch :  71
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0592968415236
# train_cumulative_accuracy :  0.980760022104
# duree :  8783.967417
# lost =  0.465951192528
# test_cumulative_accuracy :  0.870700004697
# epoch :  72
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0615974036558
# train_cumulative_accuracy :  0.979880024642
# duree :  8905.8573792
# lost =  0.463504451513
# test_cumulative_accuracy :  0.874100009203
# epoch :  73
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0545232516597
# train_cumulative_accuracy :  0.982240025103
# duree :  9030.38207221
# lost =  0.482880658507
# test_cumulative_accuracy :  0.872300001383
# epoch :  74
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0570995059889
# train_cumulative_accuracy :  0.981080025285
# duree :  9152.43764806
# lost =  0.477228343785
# test_cumulative_accuracy :  0.872600005865
# epoch :  75
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0504428729578
# train_cumulative_accuracy :  0.983000022769
# duree :  9274.57427311
# lost =  0.454263540059
# test_cumulative_accuracy :  0.87620000422
# epoch :  76
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0500213501882
# train_cumulative_accuracy :  0.983660019785
# duree :  9395.5627861
# lost =  0.486215751767
# test_cumulative_accuracy :  0.873599998951
# epoch :  77
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0557251413958
# train_cumulative_accuracy :  0.980480025411
# duree :  9516.32220101
# lost =  0.479235732704
# test_cumulative_accuracy :  0.875400003791
# epoch :  78
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0519723647251
# train_cumulative_accuracy :  0.982880020738
# duree :  9637.24183702
# lost =  0.452616833746
# test_cumulative_accuracy :  0.878500004411
# epoch :  79
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0405095986289
# train_cumulative_accuracy :  0.987600015253
# duree :  9759.54582119
# lost =  0.481985401958
# test_cumulative_accuracy :  0.877200003266
# epoch :  80
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0473913766886
# train_cumulative_accuracy :  0.983760019839
# duree :  9879.51810503
# lost =  0.480091998577
# test_cumulative_accuracy :  0.877700002789
# epoch :  81
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0444724935177
# train_cumulative_accuracy :  0.985620018393
# duree :  10001.4660902
# lost =  0.484526342303
# test_cumulative_accuracy :  0.87319999814
# epoch :  82
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0515195407253
# train_cumulative_accuracy :  0.982400022
# duree :  10122.23682
# lost =  0.486264755875
# test_cumulative_accuracy :  0.86849999845
# epoch :  83
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0447376926919
# train_cumulative_accuracy :  0.986380018741
# duree :  10244.1085172
# lost =  0.515346411765
# test_cumulative_accuracy :  0.87009999752
# epoch :  84
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0386090473027
# train_cumulative_accuracy :  0.987680014968
# duree :  10364.9099271
# lost =  0.44325941354
# test_cumulative_accuracy :  0.879500009418
# epoch :  85
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0412933865527
# train_cumulative_accuracy :  0.987440015823
# duree :  10486.116662
# lost =  0.487250318974
# test_cumulative_accuracy :  0.871499999762
# epoch :  86
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.037339556946
# train_cumulative_accuracy :  0.988420013934
# duree :  10608.28248
# lost =  0.536494893134
# test_cumulative_accuracy :  0.864399992824
# epoch :  87
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0435564283049
# train_cumulative_accuracy :  0.986200014651
# duree :  10731.7954142
# lost =  0.47421334222
# test_cumulative_accuracy :  0.879200006723
# epoch :  88
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0325121583615
# train_cumulative_accuracy :  0.989980011433
# duree :  10852.5508862
# lost =  0.456497271508
# test_cumulative_accuracy :  0.882800012827
# epoch :  89
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0327716247586
# train_cumulative_accuracy :  0.990160008073
# duree :  10973.3111501
# lost =  0.48126428768
# test_cumulative_accuracy :  0.874799998403
# epoch :  90
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0348539489333
# train_cumulative_accuracy :  0.989600010067
# duree :  11094.5023551
# lost =  0.524179482758
# test_cumulative_accuracy :  0.867199998498
# epoch :  91
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0367901743099
# train_cumulative_accuracy :  0.988600011021
# duree :  11214.8187361
# lost =  0.479556533545
# test_cumulative_accuracy :  0.876500002742
# epoch :  92
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0340449294611
# train_cumulative_accuracy :  0.989240012765
# duree :  11336.4428072
# lost =  0.548799628466
# test_cumulative_accuracy :  0.867299999595
# epoch :  93
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.044355039135
# train_cumulative_accuracy :  0.984760019332
# duree :  11459.101258
# lost =  0.516699861437
# test_cumulative_accuracy :  0.869900000691
# epoch :  94
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0357434228749
# train_cumulative_accuracy :  0.988860013336
# duree :  11584.020638
# lost =  0.504055994898
# test_cumulative_accuracy :  0.872400001884
# epoch :  95
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0357519631414
# train_cumulative_accuracy :  0.988600011319
# duree :  11707.5900781
# lost =  0.467308493406
# test_cumulative_accuracy :  0.878500008583
# epoch :  96
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0302179212659
# train_cumulative_accuracy :  0.991180009693
# duree :  11832.6728232
# lost =  0.464909891933
# test_cumulative_accuracy :  0.88030000627
# epoch :  97
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0292478170956
# train_cumulative_accuracy :  0.990880008638
# duree :  11956.0024161
# lost =  0.509418296516
# test_cumulative_accuracy :  0.875999997258
# epoch :  98
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0263313121244
# train_cumulative_accuracy :  0.991920008212
# duree :  12078.9586301
# lost =  0.537378141284
# test_cumulative_accuracy :  0.869899998903
# epoch :  99
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0267301882396
# train_cumulative_accuracy :  0.991860006899
# duree :  12200.0909882
# lost =  0.464216028601
# test_cumulative_accuracy :  0.88360000968
# epoch :  100
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0341940029943
# train_cumulative_accuracy :  0.988680011928
# duree :  12320.7959192
# lost =  0.518611153811
# test_cumulative_accuracy :  0.871699994802
# epoch :  101
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0316319247044
# train_cumulative_accuracy :  0.990240010172
# duree :  12441.2156961
# lost =  0.517656204849
# test_cumulative_accuracy :  0.872499998212
# epoch :  102
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0436375444126
# train_cumulative_accuracy :  0.984420021027
# duree :  12564.3191571
# lost =  0.487162086219
# test_cumulative_accuracy :  0.876700008512
# epoch :  103
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0303810887737
# train_cumulative_accuracy :  0.989920009524
# duree :  12685.6584201
# lost =  0.543567924947
# test_cumulative_accuracy :  0.873400003314
# epoch :  104
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0246370588191
# train_cumulative_accuracy :  0.992200006694
# duree :  12807.2057102
# lost =  0.477445415407
# test_cumulative_accuracy :  0.878200001121
# epoch :  105
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.025401879804
# train_cumulative_accuracy :  0.993080005199
# duree :  12930.3825212
# lost =  0.552719467878
# test_cumulative_accuracy :  0.87009999752
# epoch :  106
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0263618592796
# train_cumulative_accuracy :  0.992200008333
# duree :  13053.4075661
# lost =  0.494988372773
# test_cumulative_accuracy :  0.877600003481
# epoch :  107
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.026266688063
# train_cumulative_accuracy :  0.991880009025
# duree :  13174.701529
# lost =  0.480587991327
# test_cumulative_accuracy :  0.880300003886
# epoch :  108
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0263477449422
# train_cumulative_accuracy :  0.991980006546
# duree :  13295.217936
# lost =  0.513129746318
# test_cumulative_accuracy :  0.872600001097
# epoch :  109
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0305683338374
# train_cumulative_accuracy :  0.9901800102
# duree :  13416.4419012
# lost =  0.498698754907
# test_cumulative_accuracy :  0.879600005746
# epoch :  110
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.022529974464
# train_cumulative_accuracy :  0.993500004113
# duree :  13536.4455991
# lost =  0.471586009115
# test_cumulative_accuracy :  0.880700010061
# epoch :  111
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0207604343648
# train_cumulative_accuracy :  0.994060004801
# duree :  13656.1836772
# lost =  0.491396496445
# test_cumulative_accuracy :  0.882500001788
# epoch :  112
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0200924738368
# train_cumulative_accuracy :  0.994200003147
# duree :  13775.8816631
# lost =  0.561619548053
# test_cumulative_accuracy :  0.8725
# epoch :  113
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0213048109983
# train_cumulative_accuracy :  0.994100004882
# duree :  13895.7014611
# lost =  0.479743700773
# test_cumulative_accuracy :  0.883100007772
# epoch :  114
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0212800136855
# train_cumulative_accuracy :  0.9939600043
# duree :  14015.4730952
# lost =  0.518630103618
# test_cumulative_accuracy :  0.876099998355
# epoch :  115
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0216801118711
# train_cumulative_accuracy :  0.994180003405
# duree :  14135.26986
# lost =  0.497138445973
# test_cumulative_accuracy :  0.878600003719
# epoch :  116
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0222771705635
# train_cumulative_accuracy :  0.993420006484
# duree :  14255.0515471
# lost =  0.526135380268
# test_cumulative_accuracy :  0.879000002742
# epoch :  117
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0219236588635
# train_cumulative_accuracy :  0.993680004925
# duree :  14374.9174161
# lost =  0.495819200724
# test_cumulative_accuracy :  0.879500001669
# epoch :  118
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0166743550508
# train_cumulative_accuracy :  0.995780002922
# duree :  14494.6973381
# lost =  0.512906252146
# test_cumulative_accuracy :  0.879800007939
# epoch :  119
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.017405506979
# train_cumulative_accuracy :  0.995300002992
# duree :  14614.4883032
# lost =  0.501741121188
# test_cumulative_accuracy :  0.880500009656
# epoch :  120
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0248878252314
# train_cumulative_accuracy :  0.992620007098
# duree :  14734.2545362
# lost =  0.465970083773
# test_cumulative_accuracy :  0.884400011897
# epoch :  121
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0247227770498
# train_cumulative_accuracy :  0.992740006149
# duree :  14854.1010001
# lost =  0.472529611886
# test_cumulative_accuracy :  0.880600008965
# epoch :  122
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0195967200957
# train_cumulative_accuracy :  0.995160004795
# duree :  14973.8579462
# lost =  0.546849312782
# test_cumulative_accuracy :  0.874600006342
# epoch :  123
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0243680777412
# train_cumulative_accuracy :  0.992620006353
# duree :  15093.6540802
# lost =  0.498425951153
# test_cumulative_accuracy :  0.877900000811
# epoch :  124
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0204927833326
# train_cumulative_accuracy :  0.994040006101
# duree :  15213.4532721
# lost =  0.508925215751
# test_cumulative_accuracy :  0.875200000405
# epoch :  125
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0198653799447
# train_cumulative_accuracy :  0.994300004095
# duree :  15333.3156042
# lost =  0.595013431162
# test_cumulative_accuracy :  0.867199996114
# epoch :  126
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0228016278584
# train_cumulative_accuracy :  0.992980006337
# duree :  15453.098139
# lost =  0.537451574057
# test_cumulative_accuracy :  0.875100006461
# epoch :  127
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0194698137164
# train_cumulative_accuracy :  0.994140005559
# duree :  15572.889611
# lost =  0.51585771054
# test_cumulative_accuracy :  0.877600006461
# epoch :  128
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.025612747767
# train_cumulative_accuracy :  0.992540005744
# duree :  15692.646425
# lost =  0.530647081137
# test_cumulative_accuracy :  0.87620000124
# ...
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00443915235068
# train_cumulative_accuracy :  0.998880000859
# duree :  36945.8432522
# lost =  0.566878310144
# test_cumulative_accuracy :  0.886500012279
# epoch :  305
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00275594224149
# train_cumulative_accuracy :  0.99942000106
# duree :  37067.5804021
# lost =  0.573020587564
# test_cumulative_accuracy :  0.887600010037
# epoch :  306
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0036578198041
# train_cumulative_accuracy :  0.999160000384
# duree :  37188.6079991
# lost =  0.642837893665
# test_cumulative_accuracy :  0.873300001025
# epoch :  307
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00333079787648
# train_cumulative_accuracy :  0.999260000139
# duree :  37308.574739
# lost =  0.613551534563
# test_cumulative_accuracy :  0.882000011802
# epoch :  308
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0035446186075
# train_cumulative_accuracy :  0.999140000641
# duree :  37428.4194112
# lost =  0.588511900008
# test_cumulative_accuracy :  0.885900007486
# epoch :  309
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00177612091691
# train_cumulative_accuracy :  0.999739999771
# duree :  37548.302397
# lost =  0.568693487942
# test_cumulative_accuracy :  0.886000005007
# epoch :  310
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00249587422453
# train_cumulative_accuracy :  0.99950000003
# duree :  37668.128603
# lost =  0.542459113002
# test_cumulative_accuracy :  0.889800011516
# epoch :  311
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00233127166639
# train_cumulative_accuracy :  0.999579999596
# duree :  37788.071306
# lost =  0.583214917034
# test_cumulative_accuracy :  0.881400002241
# epoch :  312
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00563901610276
# train_cumulative_accuracy :  0.99854000181
# duree :  37907.930429
# lost =  0.516014561206
# test_cumulative_accuracy :  0.892700009942
# epoch :  313
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00467883220306
# train_cumulative_accuracy :  0.998480000794
# duree :  38031.3167622
# lost =  0.576472608745
# test_cumulative_accuracy :  0.886600011587
# epoch :  314
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00368249633064
# train_cumulative_accuracy :  0.99910000056
# duree :  38153.9785681
# lost =  0.587752738595
# test_cumulative_accuracy :  0.887700006962
# epoch :  315
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00206786982882
# train_cumulative_accuracy :  0.999599999934
# duree :  38276.6674411
# lost =  0.608678828776
# test_cumulative_accuracy :  0.881300007105
# epoch :  316
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0042040704136
# train_cumulative_accuracy :  0.998879999369
# duree :  38401.2314231
# lost =  0.669148815721
# test_cumulative_accuracy :  0.87590000093
# epoch :  317
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0033687629841
# train_cumulative_accuracy :  0.999259999692
# duree :  38524.8748891
# lost =  0.576917423755
# test_cumulative_accuracy :  0.890300014019
# epoch :  318
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00427503398432
# train_cumulative_accuracy :  0.999040000737
# duree :  38649.067641
# lost =  0.603843821287
# test_cumulative_accuracy :  0.880500008464
# epoch :  319
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00320413506528
# train_cumulative_accuracy :  0.9993400006
# duree :  38771.5408051
# lost =  0.581088171452
# test_cumulative_accuracy :  0.886600005627
# epoch :  320
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00412220481483
# train_cumulative_accuracy :  0.999000000209
# duree :  38892.7885962
# lost =  0.559325276017
# test_cumulative_accuracy :  0.886300006509
# epoch :  321
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00234423761207
# train_cumulative_accuracy :  0.999559999704
# duree :  39014.2471611
# lost =  0.507910175025
# test_cumulative_accuracy :  0.8924000144
# epoch :  322
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0021360055241
# train_cumulative_accuracy :  0.999679999948
# duree :  39136.2361581
# lost =  0.577422406077
# test_cumulative_accuracy :  0.880400004387
# epoch :  323
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00330010072088
# train_cumulative_accuracy :  0.999139999896
# duree :  39257.5219421
# lost =  0.610872441828
# test_cumulative_accuracy :  0.881800004244
# epoch :  324
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00446736393718
# train_cumulative_accuracy :  0.99864000082
# duree :  39378.7080441
# lost =  0.595453217626
# test_cumulative_accuracy :  0.889100008607
# epoch :  325
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00227598073159
# train_cumulative_accuracy :  0.999619999677
# duree :  39499.33535
# lost =  0.591246629357
# test_cumulative_accuracy :  0.884700012207
# epoch :  326
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00238265766478
# train_cumulative_accuracy :  0.999419999868
# duree :  39620.6418462
# lost =  0.563350747675
# test_cumulative_accuracy :  0.885000008941
# epoch :  327
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00201793316595
# train_cumulative_accuracy :  0.999679999948
# duree :  39741.2291241
# lost =  0.578619880974
# test_cumulative_accuracy :  0.881700006723
# epoch :  328
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0015736927549
# train_cumulative_accuracy :  0.999779999852
# duree :  39862.334686
# lost =  0.510389901847
# test_cumulative_accuracy :  0.89510001421
# epoch :  329
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00218890121834
# train_cumulative_accuracy :  0.999539999813
# duree :  39983.7014341
# lost =  0.649724039882
# test_cumulative_accuracy :  0.878100003004
# epoch :  330
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00420972357431
# train_cumulative_accuracy :  0.998760001659
# duree :  40104.6370912
# lost =  0.694097627252
# test_cumulative_accuracy :  0.865399992466
# epoch :  331
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00374305093224
# train_cumulative_accuracy :  0.99888000071
# duree :  40224.9218071
# lost =  0.572902123779
# test_cumulative_accuracy :  0.879700004458
# epoch :  332
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00276469731492
# train_cumulative_accuracy :  0.99941999957
# duree :  40346.1143961
# lost =  0.554934171587
# test_cumulative_accuracy :  0.884600008726
# epoch :  333
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00257022816659
# train_cumulative_accuracy :  0.99939999938
# duree :  40467.807389
# lost =  0.556293853521
# test_cumulative_accuracy :  0.889600008726
# epoch :  334
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00536378752433
# train_cumulative_accuracy :  0.998320001513
# duree :  40588.136508
# lost =  0.565402914137
# test_cumulative_accuracy :  0.889500007033
# epoch :  335
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00354686460758
# train_cumulative_accuracy :  0.999019999802
# duree :  40708.8439012
# lost =  0.595704455078
# test_cumulative_accuracy :  0.883100004196
# epoch :  336
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00277736966471
# train_cumulative_accuracy :  0.999319999814
# duree :  40831.760149
# lost =  0.608534902781
# test_cumulative_accuracy :  0.883400004506
# epoch :  337
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00331429639795
# train_cumulative_accuracy :  0.999260000139
# duree :  40952.600944
# lost =  0.576743905991
# test_cumulative_accuracy :  0.886400009394
# epoch :  338
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00404143367219
# train_cumulative_accuracy :  0.998940000087
# duree :  41074.1100171
# lost =  0.632054683864
# test_cumulative_accuracy :  0.881300006509
# epoch :  339
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00384620164317
# train_cumulative_accuracy :  0.998839999884
# duree :  41195.736855
# lost =  0.555462589115
# test_cumulative_accuracy :  0.884600005746
# epoch :  340
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00244878109395
# train_cumulative_accuracy :  0.999440000057
# duree :  41316.034018
# lost =  0.488621076941
# test_cumulative_accuracy :  0.893800011873
# epoch :  341
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00248071952432
# train_cumulative_accuracy :  0.999439999461
# duree :  41436.8575652
# lost =  0.628716568053
# test_cumulative_accuracy :  0.882900007367
# epoch :  342
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00344247762538
# train_cumulative_accuracy :  0.999079999775
# duree :  41559.668622
# lost =  0.554556455016
# test_cumulative_accuracy :  0.889500012398
# epoch :  343
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0018715317474
# train_cumulative_accuracy :  0.999619999826
# duree :  41682.8455081
# lost =  0.603525200635
# test_cumulative_accuracy :  0.882400007844
# epoch :  344
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00181482910442
# train_cumulative_accuracy :  0.999720000774
# duree :  41804.7458241
# lost =  0.545638531372
# test_cumulative_accuracy :  0.889400013089
# epoch :  345
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00215092236725
# train_cumulative_accuracy :  0.999579999894
# duree :  41926.9505231
# lost =  0.60464423269
# test_cumulative_accuracy :  0.880400003195
# epoch :  346
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00709210585208
# train_cumulative_accuracy :  0.99760000065
# duree :  42048.153476
# lost =  0.555213703215
# test_cumulative_accuracy :  0.890000011921
# epoch :  347
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00182252691904
# train_cumulative_accuracy :  0.999679999799
# duree :  42169.518429
# lost =  0.568285327703
# test_cumulative_accuracy :  0.886900004745
# epoch :  348
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00194928235791
# train_cumulative_accuracy :  0.999499999583
# duree :  42289.9326901
# lost =  0.585033720732
# test_cumulative_accuracy :  0.886500011683
# epoch :  349
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
sess = tf.InteractiveSession()

    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [1, 1, 192, 10], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),   
    'bc8': tf.Variable(tf.constant(0.1, shape=[10]), name = "b8"),
}

'''
'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_bn, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_2)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_2)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
#hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.nn.conv2d(hidden_7_do, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

gap = tf.nn.avg_pool(hidden_8_relu, ksize=[1, 4, 4, 1], strides=[1, 4, 4, 1], padding="VALID")
print(gap.get_shape())

out_y = tf.reshape(gap, (-1,10))
print(out_y.get_shape())

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

gen_batch = create_batches(150, isTrain=True)
gen_batch2 = create_batches(100, isTrain =False)

saver = tf.train.Saver()
sess.run(init, {phase_train: False})
saver.restore(sess, "./328_model.ckpt")
test_accuracy = 0.0   
for j in range(100):
    img, lbl = gen_batch2.next()
    test_accuracy += sess.run(accuracy, feed_dict={x:img, y: lbl, prob_1: 1.0, prob_2: 1.0, phase_train:False})
test_cumulative_accuracy = test_accuracy/100
print("test_cumulative_accuracy : ", test_cumulative_accuracy)

layers = [hidden_1, hidden_1_relu, hidden_2, hidden_2_relu, pool_1,
          hidden_3, hidden_3_relu, hidden_4, hidden_4_relu, pool_2,
          hidden_5, hidden_5_relu,  hidden_6, hidden_6_relu, pool_3, 
          hidden_7, hidden_7_relu, hidden_8, hidden_8_relu, gap]
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (1, 1, 192, 10)
# 4
# 1
# 1
# 192
# 10
# 1920
# (192,)
# 1
# 192
# 192
# (10,)
# 1
# 10
# 10
# total_parameters :  683098
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 10)
# (?, 1, 1, 10)
# (?, 10)
# test_cumulative_accuracy :  0.89510001421
