# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def batch_norm(x, n_out, phase_train, convolutional = False, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if convolutional:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        
        else:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
        
        ema = tf.train.ExponentialMovingAverage(decay=0.999)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/gap/test_5/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [1, 1, 192, 10], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),   
    'bc8': tf.Variable(tf.constant(0.1, shape=[10]), name = "b8"),
}

'''
'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)

hidden_1 = tf.nn.conv2d(x_bn, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_2)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_2)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_2)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc7']
#hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.nn.conv2d(hidden_7_do, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

gap = tf.nn.avg_pool(hidden_8_relu, ksize=[1, 4, 4, 1], strides=[1, 4, 4, 1], padding="VALID")
print(gap.get_shape())

out_y = tf.reshape(gap, (-1,10))
print(out_y.get_shape())
    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init, {phase_train: True})
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, phase_train: True})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (1, 1, 192, 10)
# 4
# 1
# 1
# 192
# 10
# 1920
# (192,)
# 1
# 192
# 192
# (10,)
# 1
# 10
# 10
# total_parameters :  683098
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 10)
# (?, 1, 1, 10)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-11-5c287aa2a3c6>:159 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-5c287aa2a3c6>:160 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-5c287aa2a3c6>:167 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.288
# j =  160
# batch_train_accuracy =  0.424
# j =  240
# batch_train_accuracy =  0.416
# j =  320
# batch_train_accuracy =  0.536
# lost =  2.03091043174
# train_cumulative_accuracy :  0.40513999857
# duree :  104.726700068
# lost =  1.80694931149
# test_cumulative_accuracy :  0.495899980068
# epoch :  1
# j =  0
# batch_train_accuracy =  0.496
# j =  80
# batch_train_accuracy =  0.448
# j =  160
# batch_train_accuracy =  0.536
# j =  240
# batch_train_accuracy =  0.544
# j =  320
# batch_train_accuracy =  0.656
# lost =  1.68079132468
# train_cumulative_accuracy :  0.52659999609
# duree :  224.696243048
# lost =  1.94548082829
# test_cumulative_accuracy :  0.490299982429
# epoch :  2
# j =  0
# batch_train_accuracy =  0.52
# j =  80
# batch_train_accuracy =  0.512
# j =  160
# batch_train_accuracy =  0.584
# j =  240
# batch_train_accuracy =  0.664
# j =  320
# batch_train_accuracy =  0.624
# lost =  1.54224483564
# train_cumulative_accuracy :  0.560559996516
# duree :  344.26920414
# lost =  1.27005177975
# test_cumulative_accuracy :  0.601499962807
# epoch :  3
# j =  0
# batch_train_accuracy =  0.6
# j =  80
# batch_train_accuracy =  0.592
# j =  160
# batch_train_accuracy =  0.696
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.712
# lost =  1.17309970841
# train_cumulative_accuracy :  0.636639995798
# duree :  464.061100006
# lost =  1.05918907285
# test_cumulative_accuracy :  0.658899970651
# epoch :  4
# j =  0
# batch_train_accuracy =  0.648
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.736
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.72
# lost =  0.980814549625
# train_cumulative_accuracy :  0.684120000303
# duree :  583.613587141
# lost =  0.895945970416
# test_cumulative_accuracy :  0.701099967957
# epoch :  5
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.736
# lost =  0.873316985592
# train_cumulative_accuracy :  0.717080001682
# duree :  706.252092123
# lost =  0.846479327679
# test_cumulative_accuracy :  0.72229996562
# epoch :  6
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.76
# lost =  0.828759337068
# train_cumulative_accuracy :  0.731740005165
# duree :  826.92493701
# lost =  0.821421259344
# test_cumulative_accuracy :  0.73809997499
# epoch :  7
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.8
# lost =  0.743624142036
# train_cumulative_accuracy :  0.756920006126
# duree :  946.918910027
# lost =  0.721196409464
# test_cumulative_accuracy :  0.762799978852
# epoch :  8
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.832
# lost =  0.681200856119
# train_cumulative_accuracy :  0.77280000791
# duree :  1066.80930305
# lost =  0.714058284163
# test_cumulative_accuracy :  0.764899982214
# epoch :  9
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.864
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.824
# lost =  0.661289371476
# train_cumulative_accuracy :  0.780860012919
# duree :  1186.6406281
# lost =  0.731656370163
# test_cumulative_accuracy :  0.768999977708
# epoch :  10
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.856
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.848
# lost =  0.603659668788
# train_cumulative_accuracy :  0.797980013192
# duree :  1306.44344997
# lost =  0.67751206845
# test_cumulative_accuracy :  0.782699972391
# epoch :  11
# j =  0
# batch_train_accuracy =  0.88
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.824
# lost =  0.558373417333
# train_cumulative_accuracy :  0.811800012887
# duree :  1426.438802
# lost =  0.637555921972
# test_cumulative_accuracy :  0.790899977684
# epoch :  12
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.848
# lost =  0.524980518445
# train_cumulative_accuracy :  0.82198001802
# duree :  1546.46901703
# lost =  0.623776403666
# test_cumulative_accuracy :  0.796199976206
# epoch :  13
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.832
# lost =  0.49505903177
# train_cumulative_accuracy :  0.831260018796
# duree :  1666.50725913
# lost =  0.611482308805
# test_cumulative_accuracy :  0.801799980402
# epoch :  14
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.864
# lost =  0.467868130356
# train_cumulative_accuracy :  0.838980020881
# duree :  1786.63751793
# lost =  0.565504947305
# test_cumulative_accuracy :  0.814499980807
# epoch :  15
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.824
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.460625596792
# train_cumulative_accuracy :  0.841400017589
# duree :  1906.73412514
# lost =  0.583431614339
# test_cumulative_accuracy :  0.811699974537
# epoch :  16
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.43599953942
# train_cumulative_accuracy :  0.84964001894
# duree :  2026.73911905
# lost =  0.546094777882
# test_cumulative_accuracy :  0.818999981284
# epoch :  17
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.856
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.417186024077
# train_cumulative_accuracy :  0.856440020502
# duree :  2146.81327701
# lost =  0.54483454138
# test_cumulative_accuracy :  0.820599980354
# epoch :  18
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.406268186197
# train_cumulative_accuracy :  0.860040021241
# duree :  2266.94644213
# lost =  0.547597039789
# test_cumulative_accuracy :  0.828799986243
# epoch :  19
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.856
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.386357549094
# train_cumulative_accuracy :  0.867200025022
# duree :  2386.93979907
# lost =  0.54022847414
# test_cumulative_accuracy :  0.827299986482
# epoch :  20
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.848
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.365563628189
# train_cumulative_accuracy :  0.873900028318
# duree :  2506.91695499
# lost =  0.538795892894
# test_cumulative_accuracy :  0.826499982476
# epoch :  21
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.354221705832
# train_cumulative_accuracy :  0.877560025454
# duree :  2626.97189498
# lost =  0.511820055842
# test_cumulative_accuracy :  0.833099985719
# epoch :  22
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.872
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.356964460723
# train_cumulative_accuracy :  0.876900024414
# duree :  2747.06971407
# lost =  0.498631054759
# test_cumulative_accuracy :  0.839899984002
# epoch :  23
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.912
# lost =  0.337495371066
# train_cumulative_accuracy :  0.883760025501
# duree :  2867.07796597
# lost =  0.48471054107
# test_cumulative_accuracy :  0.841799984574
# epoch :  24
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.872
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.320493717976
# train_cumulative_accuracy :  0.88822002694
# duree :  2987.11547995
# lost =  0.514668121785
# test_cumulative_accuracy :  0.832999985218
# epoch :  25
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.864
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.312828974202
# train_cumulative_accuracy :  0.890440027565
# duree :  3107.17211103
# lost =  0.481844841689
# test_cumulative_accuracy :  0.843699986339
# epoch :  26
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.872
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.306187745407
# train_cumulative_accuracy :  0.892140026838
# duree :  3227.17783904
# lost =  0.471082248539
# test_cumulative_accuracy :  0.848399986625
# epoch :  27
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.888
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.301456798799
# train_cumulative_accuracy :  0.894360025227
# duree :  3348.03477311
# lost =  0.507276358902
# test_cumulative_accuracy :  0.83849998951
# epoch :  28
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.291568559576
# train_cumulative_accuracy :  0.897680027634
# duree :  3472.73991704
# lost =  0.487842741311
# test_cumulative_accuracy :  0.846099993587
# epoch :  29
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.285288450643
# train_cumulative_accuracy :  0.901420027763
# duree :  3595.77201009
# lost =  0.482568522394
# test_cumulative_accuracy :  0.845199996829
# epoch :  30
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.277416212
# train_cumulative_accuracy :  0.903200027794
# duree :  3717.57706213
# lost =  0.504928082824
# test_cumulative_accuracy :  0.840599991083
# epoch :  31
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.266692935675
# train_cumulative_accuracy :  0.905860029459
# duree :  3839.2162261
# lost =  0.461351334155
# test_cumulative_accuracy :  0.853999989033
# epoch :  32
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.261617217343
# train_cumulative_accuracy :  0.907260026634
# duree :  3959.97334313
# lost =  0.449520491213
# test_cumulative_accuracy :  0.859200001359
# epoch :  33
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.252053397968
# train_cumulative_accuracy :  0.912460030019
# duree :  4080.657866
# lost =  0.456853619814
# test_cumulative_accuracy :  0.852699993849
# epoch :  34
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.233993967231
# train_cumulative_accuracy :  0.918360030651
# duree :  4200.78925514
# lost =  0.45928089574
# test_cumulative_accuracy :  0.852299989462
# epoch :  35
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.236567043513
# train_cumulative_accuracy :  0.917780024707
# duree :  4320.99745607
# lost =  0.444741598219
# test_cumulative_accuracy :  0.862699992657
# epoch :  36
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.22239472989
# train_cumulative_accuracy :  0.922540032268
# duree :  4440.66890907
# lost =  0.432186377794
# test_cumulative_accuracy :  0.8612999928
# epoch :  37
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.210147365611
# train_cumulative_accuracy :  0.927300030142
# duree :  4560.45717812
# lost =  0.426660785824
# test_cumulative_accuracy :  0.860599993467
# epoch :  38
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.212563130874
# train_cumulative_accuracy :  0.925840031505
# duree :  4680.56938195
# lost =  0.477045617253
# test_cumulative_accuracy :  0.851499991417
# epoch :  39
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.213617516886
# train_cumulative_accuracy :  0.925860030204
# duree :  4800.62735701
# lost =  0.443736696392
# test_cumulative_accuracy :  0.859399989247
# epoch :  40
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.222381014992
# train_cumulative_accuracy :  0.921620031148
# duree :  4920.47916913
# lost =  0.440836709887
# test_cumulative_accuracy :  0.860899996161
# epoch :  41
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.198618436661
# train_cumulative_accuracy :  0.93134003222
# duree :  5041.81964707
# lost =  0.437699520886
# test_cumulative_accuracy :  0.861299990416
# epoch :  42
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.194944453035
# train_cumulative_accuracy :  0.931920032352
# duree :  5163.32799602
# lost =  0.421758336872
# test_cumulative_accuracy :  0.867699998617
# epoch :  43
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.182724948414
# train_cumulative_accuracy :  0.935920033902
# duree :  5285.972368
# lost =  0.414790166765
# test_cumulative_accuracy :  0.868599995971
# epoch :  44
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.184108086843
# train_cumulative_accuracy :  0.936400032789
# duree :  5410.69823194
# lost =  0.41862293303
# test_cumulative_accuracy :  0.86870000124
# epoch :  45
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.1796932818
# train_cumulative_accuracy :  0.937720034122
# duree :  5535.77628016
# lost =  0.455440447181
# test_cumulative_accuracy :  0.861199995279
# epoch :  46
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.174204245526
# train_cumulative_accuracy :  0.939640033096
# duree :  5660.59442616
# lost =  0.473973800689
# test_cumulative_accuracy :  0.853099998236
# epoch :  47
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.169325420205
# train_cumulative_accuracy :  0.941440033615
# duree :  5785.35617399
# lost =  0.445190449059
# test_cumulative_accuracy :  0.857399999499
# epoch :  48
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.173257686645
# train_cumulative_accuracy :  0.939240033627
# duree :  5910.42792702
# lost =  0.423925403059
# test_cumulative_accuracy :  0.866200000048
# epoch :  49
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.163068532068
# train_cumulative_accuracy :  0.944040034562
# duree :  6031.68110704
# lost =  0.403217544854
# test_cumulative_accuracy :  0.868199998736
# epoch :  50
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.158686507568
# train_cumulative_accuracy :  0.945560034364
# duree :  6153.07405305
# lost =  0.434576725811
# test_cumulative_accuracy :  0.864699988961
# epoch :  51
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.161294264514
# train_cumulative_accuracy :  0.943420034051
# duree :  6280.80111408
# lost =  0.404163500369
# test_cumulative_accuracy :  0.872899999619
# epoch :  52
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.147548083384
# train_cumulative_accuracy :  0.949620034397
# duree :  6400.87197399
# lost =  0.428832650334
# test_cumulative_accuracy :  0.86869999826
# epoch :  53
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.155339371115
# train_cumulative_accuracy :  0.945000035316
# duree :  6520.94660497
# lost =  0.417691450715
# test_cumulative_accuracy :  0.870200000405
# epoch :  54
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.92
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.143519792426
# train_cumulative_accuracy :  0.950140036047
# duree :  6640.8745091
# lost =  0.427777144909
# test_cumulative_accuracy :  0.871999995708
# epoch :  55
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.149368907493
# train_cumulative_accuracy :  0.947540034652
# duree :  6760.88984513
# lost =  0.454373404086
# test_cumulative_accuracy :  0.86619999826
# epoch :  56
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.149273060206
# train_cumulative_accuracy :  0.946800034642
# duree :  6880.92249298
# lost =  0.470597038418
# test_cumulative_accuracy :  0.866199995279
# epoch :  57
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.146592788314
# train_cumulative_accuracy :  0.949180036783
# duree :  7000.94013596
# lost =  0.472396033108
# test_cumulative_accuracy :  0.862099990249
# epoch :  58
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.135401366353
# train_cumulative_accuracy :  0.953560034782
# duree :  7120.99698305
# lost =  0.439747142047
# test_cumulative_accuracy :  0.871400000453
# epoch :  59
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.147049010452
# train_cumulative_accuracy :  0.948400036991
# duree :  7240.98422408
# lost =  0.495120205581
# test_cumulative_accuracy :  0.858799987435
# epoch :  60
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.12881697326
# train_cumulative_accuracy :  0.955160036236
# duree :  7361.07919812
# lost =  0.436864300966
# test_cumulative_accuracy :  0.866400001049
# epoch :  61
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.131680303067
# train_cumulative_accuracy :  0.953940035999
# duree :  7481.06422997
# lost =  0.417883829921
# test_cumulative_accuracy :  0.874300003052
# epoch :  62
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.118572814772
# train_cumulative_accuracy :  0.959900034964
# duree :  7601.0576241
# lost =  0.416445852816
# test_cumulative_accuracy :  0.874800006151
# epoch :  63
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.111671413146
# train_cumulative_accuracy :  0.962480037212
# duree :  7721.03126311
# lost =  0.445830812603
# test_cumulative_accuracy :  0.869799998403
# epoch :  64
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.124593020091
# train_cumulative_accuracy :  0.957200037539
# duree :  7842.00407314
# lost =  0.460406134129
# test_cumulative_accuracy :  0.867899998426
# epoch :  65
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.130165559482
# train_cumulative_accuracy :  0.954920036644
# duree :  7962.92288709
# lost =  0.424739688635
# test_cumulative_accuracy :  0.873499994874
# epoch :  66
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.127900974061
# train_cumulative_accuracy :  0.955280035436
# duree :  8084.56210303
# lost =  0.433052781969
# test_cumulative_accuracy :  0.87460000217
# epoch :  67
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.111800683523
# train_cumulative_accuracy :  0.961540036052
# duree :  8205.82298398
# lost =  0.486974669546
# test_cumulative_accuracy :  0.866199995875
# epoch :  68
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.112515448891
# train_cumulative_accuracy :  0.961500035971
# duree :  8326.75774407
# lost =  0.422759333104
# test_cumulative_accuracy :  0.877500004768
# epoch :  69
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.108290642044
# train_cumulative_accuracy :  0.963440037221
# duree :  8447.66226602
# lost =  0.453281426728
# test_cumulative_accuracy :  0.870299999118
# epoch :  70
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.105626391899
# train_cumulative_accuracy :  0.963240036219
# duree :  8568.03589702
# lost =  0.417901626229
# test_cumulative_accuracy :  0.877400006652
# epoch :  71
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0993469253462
# train_cumulative_accuracy :  0.96712003693
# duree :  8687.76117206
# lost =  0.417473149896
# test_cumulative_accuracy :  0.875800002813
# epoch :  72
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.113055164637
# train_cumulative_accuracy :  0.961500035226
# duree :  8809.78783202
# lost =  0.479397417903
# test_cumulative_accuracy :  0.865100001693
# epoch :  73
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0991012055613
# train_cumulative_accuracy :  0.966240035295
# duree :  8931.45907497
# lost =  0.41635724768
# test_cumulative_accuracy :  0.877200000882
# epoch :  74
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.106844656048
# train_cumulative_accuracy :  0.962760037184
# duree :  9052.21697712
# lost =  0.421383561492
# test_cumulative_accuracy :  0.875700007081
# epoch :  75
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.105548928571
# train_cumulative_accuracy :  0.963040036857
# duree :  9172.86645603
# lost =  0.442771145999
# test_cumulative_accuracy :  0.87690000236
# epoch :  76
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0910099331196
# train_cumulative_accuracy :  0.968500036448
# duree :  9292.97111607
# lost =  0.460051160008
# test_cumulative_accuracy :  0.870100007653
# epoch :  77
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.086886488637
# train_cumulative_accuracy :  0.971820035428
# duree :  9413.97333193
# lost =  0.409386453778
# test_cumulative_accuracy :  0.884200009108
# epoch :  78
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.086486740387
# train_cumulative_accuracy :  0.971040033251
# duree :  9535.85169506
# lost =  0.457001817673
# test_cumulative_accuracy :  0.868200001121
# epoch :  79
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0839214237966
# train_cumulative_accuracy :  0.971300036609
# duree :  9656.22837806
# lost =  0.438283079416
# test_cumulative_accuracy :  0.877900004387
# epoch :  80
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0960824808106
# train_cumulative_accuracy :  0.967100037038
# duree :  9776.8593111
# lost =  0.419694699943
# test_cumulative_accuracy :  0.879800007343
# epoch :  81
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0950428123213
# train_cumulative_accuracy :  0.966940032542
# duree :  9898.75233698
# lost =  0.423843988851
# test_cumulative_accuracy :  0.876300004125
# epoch :  82
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0867519708164
# train_cumulative_accuracy :  0.970560034513
# duree :  10019.783468
# lost =  0.441001283228
# test_cumulative_accuracy :  0.872600001693
# epoch :  83
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0787598418212
# train_cumulative_accuracy :  0.973700032979
# duree :  10139.9828951
# lost =  0.450327572078
# test_cumulative_accuracy :  0.873200000525
# epoch :  84
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.0818124320917
# train_cumulative_accuracy :  0.972280032337
# duree :  10260.416162
# lost =  0.435405726656
# test_cumulative_accuracy :  0.881000007987
# epoch :  85
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0783636016864
# train_cumulative_accuracy :  0.973160033226
# duree :  10381.0428681
# lost =  0.415351884067
# test_cumulative_accuracy :  0.882300003767
# epoch :  86
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0774290270498
# train_cumulative_accuracy :  0.97386003077
# duree :  10502.1179721
# lost =  0.470708688051
# test_cumulative_accuracy :  0.869500000477
# epoch :  87
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0813811433641
# train_cumulative_accuracy :  0.972140033543
# duree :  10623.0401812
# lost =  0.453075507432
# test_cumulative_accuracy :  0.871700003147
# epoch :  88
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0823969146097
# train_cumulative_accuracy :  0.973240032345
# duree :  10744.1150169
# lost =  0.448594049811
# test_cumulative_accuracy :  0.874400004745
# epoch :  89
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0940331291407
# train_cumulative_accuracy :  0.967820036262
# duree :  10864.9871831
# lost =  0.487508131415
# test_cumulative_accuracy :  0.867499998808
# epoch :  90
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0894441054063
# train_cumulative_accuracy :  0.968240032941
# duree :  10986.058573
# lost =  0.47035304293
# test_cumulative_accuracy :  0.873099999428
# epoch :  91
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0696517951461
# train_cumulative_accuracy :  0.97678003028
# duree :  11106.1781909
# lost =  0.452318917364
# test_cumulative_accuracy :  0.868700003028
# epoch :  92
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0772426490067
# train_cumulative_accuracy :  0.973540030271
# duree :  11227.51261
# lost =  0.482949891537
# test_cumulative_accuracy :  0.870100002885
# epoch :  93
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0687604587898
# train_cumulative_accuracy :  0.977120029181
# duree :  11348.625107
# lost =  0.416423006728
# test_cumulative_accuracy :  0.882300015092
# epoch :  94
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0665662958217
# train_cumulative_accuracy :  0.977600026429
# duree :  11469.2129261
# lost =  0.37808260873
# test_cumulative_accuracy :  0.889200018048
# epoch :  95
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0768216536939
# train_cumulative_accuracy :  0.973520029336
# duree :  11589.962863
# lost =  0.40158118546
# test_cumulative_accuracy :  0.886900008917
# epoch :  96
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.06684398151
# train_cumulative_accuracy :  0.977760026902
# duree :  11710.1871161
# lost =  0.468683512807
# test_cumulative_accuracy :  0.874799997807
# epoch :  97
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0754496118706
# train_cumulative_accuracy :  0.973140031397
# duree :  11830.2697849
# lost =  0.427877024859
# test_cumulative_accuracy :  0.880000011325
# epoch :  98
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.0750796017819
# train_cumulative_accuracy :  0.973280032724
# duree :  11950.9120309
# lost =  0.422937987894
# test_cumulative_accuracy :  0.881400006413
# epoch :  99
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.064599641941
# train_cumulative_accuracy :  0.977320029885
# duree :  12071.4121439
# lost =  0.428989975452
# test_cumulative_accuracy :  0.882200003266
# epoch :  100
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0625285643805
# train_cumulative_accuracy :  0.979660026729
# duree :  12192.18208
# lost =  0.470993878543
# test_cumulative_accuracy :  0.8731000036
# epoch :  101
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0576012918074
# train_cumulative_accuracy :  0.981380022615
# duree :  12314.0975912
# lost =  0.445354776978
# test_cumulative_accuracy :  0.873000000715
# epoch :  102
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0639820118016
# train_cumulative_accuracy :  0.979040025622
# duree :  12434.4257231
# lost =  0.475699858218
# test_cumulative_accuracy :  0.87460000515
# epoch :  103
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0665227373317
# train_cumulative_accuracy :  0.977760029137
# duree :  12555.466023
# lost =  0.425041293055
# test_cumulative_accuracy :  0.881300009489
# epoch :  104
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0537304579187
# train_cumulative_accuracy :  0.982720022351
# duree :  12675.5398941
# lost =  0.446229229122
# test_cumulative_accuracy :  0.87340000391
# epoch :  105
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0557088865992
# train_cumulative_accuracy :  0.983740020841
# duree :  12795.719131
# lost =  0.474441193044
# test_cumulative_accuracy :  0.874200006723
# epoch :  106
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0596467766003
# train_cumulative_accuracy :  0.981160022765
# duree :  12916.447247
# lost =  0.446644701064
# test_cumulative_accuracy :  0.879200002551
# epoch :  107
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0537854843121
# train_cumulative_accuracy :  0.983040021211
# duree :  13037.3064179
# lost =  0.434507856667
# test_cumulative_accuracy :  0.882300007343
# epoch :  108
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0511059098528
# train_cumulative_accuracy :  0.983620019108
# duree :  13158.5222991
# lost =  0.430884064883
# test_cumulative_accuracy :  0.880800005198
# epoch :  109
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0570967734186
# train_cumulative_accuracy :  0.981460022777
# duree :  13279.0582809
# lost =  0.451624846309
# test_cumulative_accuracy :  0.876100009084
# epoch :  110
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0601783747994
# train_cumulative_accuracy :  0.980100023746
# duree :  13400.0476451
# lost =  0.413867869079
# test_cumulative_accuracy :  0.888900008798
# epoch :  111
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0557624775986
# train_cumulative_accuracy :  0.981380021572
# duree :  13520.4536421
# lost =  0.438493024707
# test_cumulative_accuracy :  0.882600003481
# epoch :  112
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0567458625534
# train_cumulative_accuracy :  0.980180021673
# duree :  13641.257051
# lost =  0.497463630885
# test_cumulative_accuracy :  0.866699997187
# epoch :  113
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0532825087989
# train_cumulative_accuracy :  0.982260022461
# duree :  13761.8745041
# lost =  0.462359375954
# test_cumulative_accuracy :  0.87129999876
# epoch :  114
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.05835138825
# train_cumulative_accuracy :  0.98118002668
# duree :  13881.4847519
# lost =  0.454097876549
# test_cumulative_accuracy :  0.880500007868
# epoch :  115
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0563984824531
# train_cumulative_accuracy :  0.982240021527
# duree :  14001.4730821
# lost =  0.486038673818
# test_cumulative_accuracy :  0.868100004196
# epoch :  116
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0489479749952
# train_cumulative_accuracy :  0.984400020093
# duree :  14122.1641641
# lost =  0.436271416694
# test_cumulative_accuracy :  0.879000011086
# epoch :  117
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.0509810083942
# train_cumulative_accuracy :  0.984200020432
# duree :  14242.846256
# lost =  0.413755425513
# test_cumulative_accuracy :  0.887600010633
# epoch :  118
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.04646011075
# train_cumulative_accuracy :  0.985140017569
# duree :  14363.687067
# lost =  0.440673852712
# test_cumulative_accuracy :  0.879800004959
# epoch :  119
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0481315358961
# train_cumulative_accuracy :  0.984260019809
# duree :  14484.217617
# lost =  0.407256574109
# test_cumulative_accuracy :  0.889900010824
# epoch :  120
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0482341262372
# train_cumulative_accuracy :  0.98440001905
# duree :  14605.8933291
# lost =  0.411826530248
# test_cumulative_accuracy :  0.88770001173
# epoch :  121
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0396527033136
# train_cumulative_accuracy :  0.988480009437
# duree :  14725.8874969
# lost =  0.404789345264
# test_cumulative_accuracy :  0.888400011063
# epoch :  122
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0429520711163
# train_cumulative_accuracy :  0.986160016656
# duree :  14845.917547
# lost =  0.425810195357
# test_cumulative_accuracy :  0.883200008869
# epoch :  123
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0456171527063
# train_cumulative_accuracy :  0.985780016184
# duree :  14965.90975
# lost =  0.39089114666
# test_cumulative_accuracy :  0.891600006819
# epoch :  124
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0418065922055
# train_cumulative_accuracy :  0.987020013779
# duree :  15085.943928
# lost =  0.424220272899
# test_cumulative_accuracy :  0.887300007939
# epoch :  125
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.040207742895
# train_cumulative_accuracy :  0.987780014575
# duree :  15206.01302
# lost =  0.43600656718
# test_cumulative_accuracy :  0.881900004148
# epoch :  126
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0403988176351
# train_cumulative_accuracy :  0.987540013045
# duree :  15326.0282791
# lost =  0.457969952226
# test_cumulative_accuracy :  0.880600011349
# epoch :  127
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0412951415812
# train_cumulative_accuracy :  0.986900015622
# duree :  15446.0816991
# lost =  0.51092004478
# test_cumulative_accuracy :  0.86960000217
# epoch :  128
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# ...
# train_cumulative_accuracy :  0.997480002344
# duree :  39750.1383121
# lost =  0.512915692925
# test_cumulative_accuracy :  0.884200011492
# epoch :  330
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00765976623865
# train_cumulative_accuracy :  0.99808000043
# duree :  39873.80527
# lost =  0.504674705863
# test_cumulative_accuracy :  0.885400011539
# epoch :  331
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00800361421294
# train_cumulative_accuracy :  0.997800002098
# duree :  39993.815423
# lost =  0.460555952787
# test_cumulative_accuracy :  0.893600013852
# epoch :  332
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0058985968215
# train_cumulative_accuracy :  0.998979999125
# duree :  40114.3364031
# lost =  0.434531423748
# test_cumulative_accuracy :  0.896400017142
# epoch :  333
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00725099584452
# train_cumulative_accuracy :  0.998380000144
# duree :  40234.5808601
# lost =  0.439159061462
# test_cumulative_accuracy :  0.897900019884
# epoch :  334
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00547885704189
# train_cumulative_accuracy :  0.998940000087
# duree :  40354.9110081
# lost =  0.453512401134
# test_cumulative_accuracy :  0.892100014091
# epoch :  335
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00907121210301
# train_cumulative_accuracy :  0.997700001299
# duree :  40474.809031
# lost =  0.446960916072
# test_cumulative_accuracy :  0.893900014162
# epoch :  336
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0118773897976
# train_cumulative_accuracy :  0.997060000896
# duree :  40595.297385
# lost =  0.497123475596
# test_cumulative_accuracy :  0.888400015831
# epoch :  337
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00879597560663
# train_cumulative_accuracy :  0.997900001258
# duree :  40715.493444
# lost =  0.474290940315
# test_cumulative_accuracy :  0.893000011444
# epoch :  338
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00626870503955
# train_cumulative_accuracy :  0.998580000401
# duree :  40836.4347501
# lost =  0.458750090301
# test_cumulative_accuracy :  0.896400019526
# epoch :  339
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00612853745988
# train_cumulative_accuracy :  0.998860000372
# duree :  40958.338531
# lost =  0.469419605434
# test_cumulative_accuracy :  0.896100018024
# epoch :  340
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00562826212539
# train_cumulative_accuracy :  0.998979999572
# duree :  41079.5874441
# lost =  0.461862867028
# test_cumulative_accuracy :  0.893600015044
# epoch :  341
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0063822272906
# train_cumulative_accuracy :  0.998580000848
# duree :  41200.0486
# lost =  0.448568630666
# test_cumulative_accuracy :  0.893300016522
# epoch :  342
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00663660512851
# train_cumulative_accuracy :  0.998720000684
# duree :  41320.3225172
# lost =  0.421543042362
# test_cumulative_accuracy :  0.897200014591
# epoch :  343
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0083420763383
# train_cumulative_accuracy :  0.997840000242
# duree :  41440.07512
# lost =  0.505018783212
# test_cumulative_accuracy :  0.890100016594
# epoch :  344
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00725125309444
# train_cumulative_accuracy :  0.998380001932
# duree :  41560.0449851
# lost =  0.459934880584
# test_cumulative_accuracy :  0.895200023651
# epoch :  345
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00549451246217
# train_cumulative_accuracy :  0.99906000033
# duree :  41683.047678
# lost =  0.469317215085
# test_cumulative_accuracy :  0.894600021243
# epoch :  346
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0067013388902
# train_cumulative_accuracy :  0.998480000496
# duree :  41807.232239
# lost =  0.451755567342
# test_cumulative_accuracy :  0.895000015497
# epoch :  347
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00686846711302
# train_cumulative_accuracy :  0.998379999995
# duree :  41931.598002
# lost =  0.486727810502
# test_cumulative_accuracy :  0.892000014186
# epoch :  348
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00782602895182
# train_cumulative_accuracy :  0.998060001284
# duree :  42052.6712351
# lost =  0.49817210868
# test_cumulative_accuracy :  0.88860001862
# epoch :  349
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00771490690386
# train_cumulative_accuracy :  0.998200000077
# duree :  42172.537297
# lost =  0.48592994675
# test_cumulative_accuracy :  0.889000013471
# epoch :  350
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00760695756748
# train_cumulative_accuracy :  0.998120000064
# duree :  42292.1193449
# lost =  0.512496129721
# test_cumulative_accuracy :  0.884000015855
# epoch :  351
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00617086971521
# train_cumulative_accuracy :  0.998679999858
# duree :  42411.846714
# lost =  0.471557277292
# test_cumulative_accuracy :  0.888400016427
# epoch :  352
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00866477445357
# train_cumulative_accuracy :  0.997840000689
# duree :  42531.7231331
# lost =  0.511722531617
# test_cumulative_accuracy :  0.883200013638
# epoch :  353
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00977047781082
# train_cumulative_accuracy :  0.997620001733
# duree :  42652.2313499
# lost =  0.398992238939
# test_cumulative_accuracy :  0.899200018048
# epoch :  354
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00596528085327
# train_cumulative_accuracy :  0.998980000317
# duree :  42771.946089
# lost =  0.455800043494
# test_cumulative_accuracy :  0.894000019431
# epoch :  355
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0062970947304
# train_cumulative_accuracy :  0.998779999763
# duree :  42893.1454921
# lost =  0.486348157674
# test_cumulative_accuracy :  0.890900018811
# epoch :  356
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00927073882209
# train_cumulative_accuracy :  0.997380001843
# duree :  43015.887017
# lost =  0.488504118472
# test_cumulative_accuracy :  0.892900019288
# epoch :  357
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00684439612123
# train_cumulative_accuracy :  0.998499999791
# duree :  43135.5688322
# lost =  0.462403963208
# test_cumulative_accuracy :  0.893200013041
# epoch :  358
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00571644357442
# train_cumulative_accuracy :  0.998780000806
# duree :  43256.3685219
# lost =  0.55457124263
# test_cumulative_accuracy :  0.883300011158
# epoch :  359
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00939314803109
# train_cumulative_accuracy :  0.997500001043
# duree :  43377.163054
# lost =  0.464616682082
# test_cumulative_accuracy :  0.894600018859
# epoch :  360
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00753043940626
# train_cumulative_accuracy :  0.998160000592
# duree :  43497.027024
# lost =  0.509987314492
# test_cumulative_accuracy :  0.883700013161
# epoch :  361
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00670063532056
# train_cumulative_accuracy :  0.998560000658
# duree :  43618.0577819
# lost =  0.457083260641
# test_cumulative_accuracy :  0.894600020647
# epoch :  362
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00893328825856
# train_cumulative_accuracy :  0.997780001611
# duree :  43737.9373071
# lost =  0.557420915067
# test_cumulative_accuracy :  0.87740000248
# epoch :  363
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00646581306057
# train_cumulative_accuracy :  0.998460000753
# duree :  43858.9816921
# lost =  0.453561825156
# test_cumulative_accuracy :  0.895700018406
# epoch :  364
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00382834673655
# train_cumulative_accuracy :  0.999400000423
# duree :  43980.724093
# lost =  0.466710544974
# test_cumulative_accuracy :  0.894600018263
# epoch :  365
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00648910776828
# train_cumulative_accuracy :  0.998960000873
# duree :  44101.947093
# lost =  0.475135436207
# test_cumulative_accuracy :  0.891100017428
# epoch :  366
# j =  0
# batch_train_accuracy =  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5c287aa2a3c6> in <module>()
#     189                     #print("j = ",j)
#     190                     img, lbl = gen_batch.next()
# --> 191                     optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, phase_train: True})
#     192                     c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
#     193
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1447         none, the default session will be used.
#    1448     """
# -> 1449     _run_using_default_session(self, feed_dict, self.graph, session)
#    1450
#    1451
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3666                        "the operation's graph is different from the session's "
#    3667                        "graph.")
# -> 3668   session.run(operation, feed_dict)
#    3669
#    3670
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
