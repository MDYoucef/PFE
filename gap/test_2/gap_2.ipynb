# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def batch_norm(x, n_out, phase_train, convolutional = False, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if convolutional:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        
        else:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
        
        ema = tf.train.ExponentialMovingAverage(decay=0.999)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3/gap/test_2/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    #prob_2=tf.placeholder(tf.float32)
    #prob_3=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc7': tf.get_variable(name = "w7",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    
    'wc8': tf.get_variable(name = "w8",shape = [1, 1, 192, 10], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc10': tf.get_variable(name = "w10",shape = [1, 1, 192, 10], initializer=tf.contrib.layers.xavier_initializer()),
}
    

with tf.name_scope("biases"):
    
    biases = {
    
    'bc9': tf.Variable(tf.constant(0.1, shape=[10]), name = "b9"),
        
        }

''' 

'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)
#x_image_do=tf.nn.dropout(x_image, keep_prob=prob_3)

hidden_1 = tf.nn.conv2d(x_bn, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_1)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_1)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

'''
hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='SAME')
hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7_bn)
#hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())
'''

hidden_8 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID')
hidden_8_bn = batch_norm(hidden_8, 192, phase_train, convolutional = True)
hidden_8_relu = tf.nn.elu(hidden_8_bn)
#hidden_8_do=tf.nn.dropout(hidden_8_relu, keep_prob=prob_1)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
#hidden_9_bn = batch_norm(hidden_9, 10, phase_train, convolutional = True)
hidden_9_relu = tf.nn.elu(hidden_9)
#hidden_9_do=tf.nn.dropout(hidden_9_relu, keep_prob=prob_1)
print(hidden_9_relu.get_shape())

'''
hidden_10 = tf.nn.conv2d(hidden_9_do, weights['wc10'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_10_bn = batch_norm(hidden_10, 10, phase_train, convolutional = True)
hidden_10_relu = tf.nn.elu(hidden_10_bn)
#hidden_10_do=tf.nn.dropout(hidden_10_relu, keep_prob=prob_1)
print(hidden_10_relu.get_shape())
'''

gap = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 4, 4, 1], strides=[1, 4, 4, 1], padding="VALID")
print(gap.get_shape())

out_y = tf.reshape(gap,(-1,10))
print(out_y.get_shape())


'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init, {phase_train: True})
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, phase_train: True})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., phase_train: False})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., phase_train: False})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., phase_train: False})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., phase_train: False})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., phase_train: False})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., phase_train: False})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (1, 1, 192, 10)
# 4
# 1
# 1
# 192
# 10
# 1920
# (10,)
# 1
# 10
# 10
# total_parameters :  682906
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 10)
# (?, 1, 1, 10)
# (?, 10)
# WARNING:tensorflow:From <ipython-input-12-1b943a4e3e3a>:199 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-12-1b943a4e3e3a>:200 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-12-1b943a4e3e3a>:207 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.36
# j =  160
# batch_train_accuracy =  0.384
# j =  240
# batch_train_accuracy =  0.392
# j =  320
# batch_train_accuracy =  0.488
# lost =  2.39820938945
# train_cumulative_accuracy :  0.395219996944
# duree :  103.937032938
# lost =  2.19044791937
# test_cumulative_accuracy :  0.434799986482
# epoch :  1
# j =  0
# batch_train_accuracy =  0.448
# j =  80
# batch_train_accuracy =  0.416
# j =  160
# batch_train_accuracy =  0.544
# j =  240
# batch_train_accuracy =  0.56
# j =  320
# batch_train_accuracy =  0.552
# lost =  2.30213809401
# train_cumulative_accuracy :  0.476419997364
# duree :  224.126106977
# lost =  2.20987105012
# test_cumulative_accuracy :  0.474899984598
# epoch :  2
# j =  0
# batch_train_accuracy =  0.504
# j =  80
# batch_train_accuracy =  0.464
# j =  160
# batch_train_accuracy =  0.552
# j =  240
# batch_train_accuracy =  0.608
# j =  320
# batch_train_accuracy =  0.544
# lost =  2.37043423086
# train_cumulative_accuracy :  0.488739996254
# duree :  344.356511831
# lost =  2.30635264397
# test_cumulative_accuracy :  0.488099980652
# epoch :  3
# j =  0
# batch_train_accuracy =  0.512
# j =  80
# batch_train_accuracy =  0.544
# j =  160
# batch_train_accuracy =  0.608
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.6
# lost =  1.90418186456
# train_cumulative_accuracy :  0.554859995171
# duree :  464.711117983
# lost =  1.60202540278
# test_cumulative_accuracy :  0.604899968505
# epoch :  4
# j =  0
# batch_train_accuracy =  0.608
# j =  80
# batch_train_accuracy =  0.648
# j =  160
# batch_train_accuracy =  0.624
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.4239487642
# train_cumulative_accuracy :  0.63967999585
# duree :  585.132385969
# lost =  1.21829216599
# test_cumulative_accuracy :  0.667099967003
# epoch :  5
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.704
# j =  160
# batch_train_accuracy =  0.664
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.792
# lost =  1.04424768031
# train_cumulative_accuracy :  0.706080000401
# duree :  705.660101891
# lost =  0.88357975781
# test_cumulative_accuracy :  0.735299970508
# epoch :  6
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.72
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.877117574215
# train_cumulative_accuracy :  0.744320004582
# duree :  825.960662842
# lost =  0.763368010819
# test_cumulative_accuracy :  0.769899981618
# epoch :  7
# j =  0
# batch_train_accuracy =  0.864
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.735076158047
# train_cumulative_accuracy :  0.776700009555
# duree :  946.163714886
# lost =  0.823675799072
# test_cumulative_accuracy :  0.757199980021
# epoch :  8
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.589040921777
# train_cumulative_accuracy :  0.813340016752
# duree :  1066.27865195
# lost =  0.663375062346
# test_cumulative_accuracy :  0.798099981546
# epoch :  9
# j =  0
# batch_train_accuracy =  0.904
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.496655651033
# train_cumulative_accuracy :  0.836540016532
# duree :  1186.35632086
# lost =  0.61897108376
# test_cumulative_accuracy :  0.808199986219
# epoch :  10
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.88
# j =  240
# batch_train_accuracy =  0.848
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.461293336414
# train_cumulative_accuracy :  0.846760020554
# duree :  1306.4221189
# lost =  0.703460778296
# test_cumulative_accuracy :  0.788199977875
# epoch :  11
# j =  0
# batch_train_accuracy =  0.872
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.816
# j =  320
# batch_train_accuracy =  0.904
# lost =  0.433546407707
# train_cumulative_accuracy :  0.855040020347
# duree :  1426.648803
# lost =  0.622698569596
# test_cumulative_accuracy :  0.809699984193
# epoch :  12
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.355945076086
# train_cumulative_accuracy :  0.878020025939
# duree :  1546.795789
# lost =  0.583194614053
# test_cumulative_accuracy :  0.820899979472
# epoch :  13
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.864
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.328841100372
# train_cumulative_accuracy :  0.887200025916
# duree :  1666.95052981
# lost =  0.595427388847
# test_cumulative_accuracy :  0.822599980831
# epoch :  14
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.888
# j =  240
# batch_train_accuracy =  0.896
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.306340814903
# train_cumulative_accuracy :  0.895320029408
# duree :  1787.13012385
# lost =  0.614504404664
# test_cumulative_accuracy :  0.822799985409
# epoch :  15
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.92
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.305916385204
# train_cumulative_accuracy :  0.896400028765
# duree :  1907.39547586
# lost =  0.635536399186
# test_cumulative_accuracy :  0.821799986959
# epoch :  16
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.257137757707
# train_cumulative_accuracy :  0.909880026728
# duree :  2027.63899899
# lost =  0.569576341212
# test_cumulative_accuracy :  0.834399991035
# epoch :  17
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.24469120929
# train_cumulative_accuracy :  0.914820032418
# duree :  2147.62379599
# lost =  0.610844836533
# test_cumulative_accuracy :  0.832499982715
# epoch :  18
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.936
# j =  240
# batch_train_accuracy =  0.912
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.212458829619
# train_cumulative_accuracy :  0.926600032598
# duree :  2267.71562982
# lost =  0.570302262306
# test_cumulative_accuracy :  0.836399980783
# epoch :  19
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.176726500811
# train_cumulative_accuracy :  0.939260033667
# duree :  2387.60699677
# lost =  0.549943240583
# test_cumulative_accuracy :  0.847499995232
# epoch :  20
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.944
# lost =  0.170189921828
# train_cumulative_accuracy :  0.939660035074
# duree :  2507.63623381
# lost =  0.572372629941
# test_cumulative_accuracy :  0.841399997473
# epoch :  21
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.168341003796
# train_cumulative_accuracy :  0.939080034047
# duree :  2627.65214396
# lost =  0.647362720072
# test_cumulative_accuracy :  0.827799983621
# epoch :  22
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.161850685477
# train_cumulative_accuracy :  0.942120034695
# duree :  2747.88270998
# lost =  0.615955502391
# test_cumulative_accuracy :  0.835299986601
# epoch :  23
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.158922625957
# train_cumulative_accuracy :  0.944860036373
# duree :  2867.93152094
# lost =  0.637927051783
# test_cumulative_accuracy :  0.832299979925
# epoch :  24
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.134459795109
# train_cumulative_accuracy :  0.951320036799
# duree :  2987.94278097
# lost =  0.617617879808
# test_cumulative_accuracy :  0.840699984431
# epoch :  25
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.13286388508
# train_cumulative_accuracy :  0.95128003493
# duree :  3108.0433979
# lost =  0.661371925026
# test_cumulative_accuracy :  0.834299981594
# epoch :  26
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.131879817317
# train_cumulative_accuracy :  0.951600035429
# duree :  3228.13253593
# lost =  0.622956292629
# test_cumulative_accuracy :  0.849199991226
# epoch :  27
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.928
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.117842091429
# train_cumulative_accuracy :  0.95784003675
# duree :  3348.21524
# lost =  0.660287153423
# test_cumulative_accuracy :  0.837199989557
# epoch :  28
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.113024387299
# train_cumulative_accuracy :  0.95816003561
# duree :  3468.15797782
# lost =  0.659426193833
# test_cumulative_accuracy :  0.841399984956
# epoch :  29
# j =  0
# batch_train_accuracy =  0.928
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0834680258902
# train_cumulative_accuracy :  0.969220034033
# duree :  3588.25718784
# lost =  0.674402084351
# test_cumulative_accuracy :  0.840599982738
# epoch :  30
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.952
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.091252016779
# train_cumulative_accuracy :  0.967520034164
# duree :  3708.43712378
# lost =  0.652648820281
# test_cumulative_accuracy :  0.847899992466
# epoch :  31
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.081020111423
# train_cumulative_accuracy :  0.970500032902
# duree :  3828.61736679
# lost =  0.626670843363
# test_cumulative_accuracy :  0.850399990082
# epoch :  32
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0661820760719
# train_cumulative_accuracy :  0.976580026299
# duree :  3948.60808086
# lost =  0.674859508574
# test_cumulative_accuracy :  0.848199983239
# epoch :  33
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0809922946524
# train_cumulative_accuracy :  0.970860030204
# duree :  4068.76131988
# lost =  0.628920956254
# test_cumulative_accuracy :  0.848199985027
# epoch :  34
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0571252039494
# train_cumulative_accuracy :  0.979880026728
# duree :  4188.92012787
# lost =  0.660363792181
# test_cumulative_accuracy :  0.848299985528
# epoch :  35
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0618191660335
# train_cumulative_accuracy :  0.978120026439
# duree :  4309.07620883
# lost =  0.64822743386
# test_cumulative_accuracy :  0.856299993992
# epoch :  36
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0676072230202
# train_cumulative_accuracy :  0.976400026381
# duree :  4429.184865
# lost =  0.630498580039
# test_cumulative_accuracy :  0.859799997807
# epoch :  37
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0551066358841
# train_cumulative_accuracy :  0.980540024042
# duree :  4549.21685886
# lost =  0.712273130119
# test_cumulative_accuracy :  0.846799987555
# epoch :  38
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0890501558012
# train_cumulative_accuracy :  0.968020032495
# duree :  4669.23820996
# lost =  0.686525646746
# test_cumulative_accuracy :  0.851799991727
# epoch :  39
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0608376056713
# train_cumulative_accuracy :  0.978620026112
# duree :  4792.30882597
# lost =  0.653665477633
# test_cumulative_accuracy :  0.852499989867
# epoch :  40
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0547852409759
# train_cumulative_accuracy :  0.981000022292
# duree :  4914.09435892
# lost =  0.687940877676
# test_cumulative_accuracy :  0.845199989676
# epoch :  41
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0427350852778
# train_cumulative_accuracy :  0.985180017054
# duree :  5036.50259995
# lost =  0.684506455958
# test_cumulative_accuracy :  0.852299990058
# epoch :  42
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0379903393507
# train_cumulative_accuracy :  0.986980017573
# duree :  5157.1313529
# lost =  0.646737133563
# test_cumulative_accuracy :  0.858099984527
# epoch :  43
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0537618615292
# train_cumulative_accuracy :  0.98076001972
# duree :  5276.70728278
# lost =  0.642962605953
# test_cumulative_accuracy :  0.861599997878
# epoch :  44
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0383904161199
# train_cumulative_accuracy :  0.986860015392
# duree :  5396.31013489
# lost =  0.699805787206
# test_cumulative_accuracy :  0.856699993014
# epoch :  45
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.054071761024
# train_cumulative_accuracy :  0.98010002315
# duree :  5515.81517887
# lost =  0.65428515166
# test_cumulative_accuracy :  0.855499994159
# epoch :  46
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0435258388158
# train_cumulative_accuracy :  0.984080019742
# duree :  5635.35342598
# lost =  0.705622008294
# test_cumulative_accuracy :  0.849999989867
# epoch :  47
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0567363689208
# train_cumulative_accuracy :  0.979240022898
# duree :  5754.89052677
# lost =  0.702341843694
# test_cumulative_accuracy :  0.852799996138
# epoch :  48
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0390379213577
# train_cumulative_accuracy :  0.986700016111
# duree :  5874.5052309
# lost =  0.654686282128
# test_cumulative_accuracy :  0.857600001693
# epoch :  49
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.944
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0501736312191
# train_cumulative_accuracy :  0.982080020905
# duree :  5994.03039289
# lost =  0.688763125092
# test_cumulative_accuracy :  0.850099987388
# epoch :  50
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0471549691714
# train_cumulative_accuracy :  0.983600021452
# duree :  6113.77603698
# lost =  0.695950054228
# test_cumulative_accuracy :  0.855799996257
# epoch :  51
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0317266362743
# train_cumulative_accuracy :  0.988620011955
# duree :  6233.48238897
# lost =  0.74970937252
# test_cumulative_accuracy :  0.853299991488
# epoch :  52
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0362606096113
# train_cumulative_accuracy :  0.987060014755
# duree :  6353.16198087
# lost =  0.654206511527
# test_cumulative_accuracy :  0.859699993134
# epoch :  53
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0307045161228
# train_cumulative_accuracy :  0.988940015435
# duree :  6472.92526698
# lost =  0.670785980523
# test_cumulative_accuracy :  0.865300000906
# epoch :  54
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0283308683382
# train_cumulative_accuracy :  0.989940007776
# duree :  6592.5710938
# lost =  0.618173038512
# test_cumulative_accuracy :  0.864600001574
# epoch :  55
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0328706415242
# train_cumulative_accuracy :  0.988600013256
# duree :  6712.32862496
# lost =  0.718346720785
# test_cumulative_accuracy :  0.854299999475
# epoch :  56
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0211813752711
# train_cumulative_accuracy :  0.992800007313
# duree :  6832.43039894
# lost =  0.675010910332
# test_cumulative_accuracy :  0.863899999261
# epoch :  57
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0273219750439
# train_cumulative_accuracy :  0.991040008813
# duree :  6952.65175486
# lost =  0.673872016221
# test_cumulative_accuracy :  0.863299995661
# epoch :  58
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0215028767729
# train_cumulative_accuracy :  0.992700005174
# duree :  7072.631917
# lost =  0.698852878511
# test_cumulative_accuracy :  0.86169999063
# epoch :  59
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0333401292498
# train_cumulative_accuracy :  0.988120013326
# duree :  7192.7176249
# lost =  0.67176194489
# test_cumulative_accuracy :  0.863099996448
# epoch :  60
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.03280007978
# train_cumulative_accuracy :  0.988240012974
# duree :  7312.71208692
# lost =  0.72491951853
# test_cumulative_accuracy :  0.851899983287
# epoch :  61
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0410761966361
# train_cumulative_accuracy :  0.985520017594
# duree :  7432.8244319
# lost =  0.711892427355
# test_cumulative_accuracy :  0.855199990273
# epoch :  62
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0304101525486
# train_cumulative_accuracy :  0.988940012604
# duree :  7552.88764
# lost =  0.788337038457
# test_cumulative_accuracy :  0.845099996924
# epoch :  63
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0233848653673
# train_cumulative_accuracy :  0.991940006614
# duree :  7672.86020494
# lost =  0.653411178142
# test_cumulative_accuracy :  0.870800004005
# epoch :  64
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0203818438196
# train_cumulative_accuracy :  0.993320006728
# duree :  7792.81944299
# lost =  0.662130934745
# test_cumulative_accuracy :  0.865499997139
# epoch :  65
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0256799931763
# train_cumulative_accuracy :  0.991280008256
# duree :  7913.06924987
# lost =  0.666735036671
# test_cumulative_accuracy :  0.865800000429
# epoch :  66
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0220585328065
# train_cumulative_accuracy :  0.992060006857
# duree :  8033.03638387
# lost =  0.778392398953
# test_cumulative_accuracy :  0.854699997306
# epoch :  67
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0249510973203
# train_cumulative_accuracy :  0.991280009747
# duree :  8153.03494477
# lost =  0.707191815078
# test_cumulative_accuracy :  0.859199999571
# epoch :  68
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0170935779366
# train_cumulative_accuracy :  0.994160004705
# duree :  8273.02694082
# lost =  0.693961827457
# test_cumulative_accuracy :  0.863799996972
# epoch :  69
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0156611512204
# train_cumulative_accuracy :  0.994720004648
# duree :  8393.01275277
# lost =  0.783030281067
# test_cumulative_accuracy :  0.849399990439
# epoch :  70
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0198096950259
# train_cumulative_accuracy :  0.993160005808
# duree :  8513.20281291
# lost =  0.644704841673
# test_cumulative_accuracy :  0.868200004101
# epoch :  71
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0145733189358
# train_cumulative_accuracy :  0.99494000569
# duree :  8633.34417582
# lost =  0.76195240885
# test_cumulative_accuracy :  0.858399997354
# epoch :  72
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0142285854567
# train_cumulative_accuracy :  0.995520004928
# duree :  8753.54398489
# lost =  0.697931737304
# test_cumulative_accuracy :  0.861599999666
# epoch :  73
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0154791289824
# train_cumulative_accuracy :  0.994840004593
# duree :  8873.58068395
# lost =  0.717626099139
# test_cumulative_accuracy :  0.863499996662
# epoch :  74
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0338985244476
# train_cumulative_accuracy :  0.987660012543
# duree :  8993.74419689
# lost =  0.774766336381
# test_cumulative_accuracy :  0.852700002193
# epoch :  75
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.023339321699
# train_cumulative_accuracy :  0.991720007658
# duree :  9113.8205688
# lost =  0.751521638036
# test_cumulative_accuracy :  0.855299993157
# epoch :  76
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0155341910988
# train_cumulative_accuracy :  0.99484000355
# duree :  9233.97395897
# lost =  0.710934204608
# test_cumulative_accuracy :  0.8593999964
# epoch :  77
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0263077284514
# train_cumulative_accuracy :  0.990260010809
# duree :  9354.07451296
# lost =  0.684455189705
# test_cumulative_accuracy :  0.865500002503
# epoch :  78
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0164553773196
# train_cumulative_accuracy :  0.994220006019
# duree :  9474.06765985
# lost =  0.842669428289
# test_cumulative_accuracy :  0.852799991965
# epoch :  79
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0191014703708
# train_cumulative_accuracy :  0.99314000994
# duree :  9594.08319592
# lost =  0.720349601805
# test_cumulative_accuracy :  0.865099998713
# epoch :  80
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.944
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0336546658232
# train_cumulative_accuracy :  0.987660014182
# duree :  9714.14468193
# lost =  0.757523824573
# test_cumulative_accuracy :  0.86219999671
# epoch :  81
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0111004423462
# train_cumulative_accuracy :  0.996480002254
# duree :  9834.13705397
# lost =  0.682013197094
# test_cumulative_accuracy :  0.866500002742
# epoch :  82
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0103106248257
# train_cumulative_accuracy :  0.996960002929
# duree :  9954.2261548
# lost =  0.758751428723
# test_cumulative_accuracy :  0.854200001955
# epoch :  83
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0191991535461
# train_cumulative_accuracy :  0.993500005305
# duree :  10074.3608868
# lost =  0.646528245211
# test_cumulative_accuracy :  0.87030000031
# epoch :  84
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0136458895107
# train_cumulative_accuracy :  0.995420003533
# duree :  10194.567209
# lost =  0.737591169178
# test_cumulative_accuracy :  0.858699995279
# epoch :  85
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0101702626846
# train_cumulative_accuracy :  0.996560003161
# duree :  10314.5558128
# lost =  0.746218007952
# test_cumulative_accuracy :  0.862199993134
# epoch :  86
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0170551562829
# train_cumulative_accuracy :  0.994120004922
# duree :  10434.6250789
# lost =  0.674353653938
# test_cumulative_accuracy :  0.86630000174
# epoch :  87
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0159793221844
# train_cumulative_accuracy :  0.99458000496
# duree :  10554.83846
# lost =  0.904918604791
# test_cumulative_accuracy :  0.842399988174
# epoch :  88
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0171370706236
# train_cumulative_accuracy :  0.994500005692
# duree :  10674.9562018
# lost =  0.707120160013
# test_cumulative_accuracy :  0.865700001121
# epoch :  89
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0138180124937
# train_cumulative_accuracy :  0.995480005443
# duree :  10794.9830918
# lost =  0.758482886255
# test_cumulative_accuracy :  0.856399993896
# epoch :  90
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0123831654796
# train_cumulative_accuracy :  0.995740004778
# duree :  10915.1092219
# lost =  0.76712614134
# test_cumulative_accuracy :  0.862300000191
# epoch :  91
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0255245788347
# train_cumulative_accuracy :  0.99108000949
# duree :  11035.2096889
# lost =  0.940272676051
# test_cumulative_accuracy :  0.837699990273
# epoch :  92
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0125944746255
# train_cumulative_accuracy :  0.995760003775
# duree :  11155.2976918
# lost =  0.780884435326
# test_cumulative_accuracy :  0.862600001097
# epoch :  93
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0175077359082
# train_cumulative_accuracy :  0.994500004351
# duree :  11275.304379
# lost =  0.805851607919
# test_cumulative_accuracy :  0.857799991369
# epoch :  94
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0138002245414
# train_cumulative_accuracy :  0.995180004835
# duree :  11395.2389979
# lost =  0.735368499458
# test_cumulative_accuracy :  0.866699997187
# epoch :  95
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00682594952123
# train_cumulative_accuracy :  0.99784000203
# duree :  11516.5651059
# lost =  0.703182492852
# test_cumulative_accuracy :  0.868500002027
# epoch :  96
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1b943a4e3e3a> in <module>()
#     240
#     241                     train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary],
# --> 242                                                                feed_dict={x: img, y: lbl, prob_1: 1., phase_train: False})
#     243                     writer.add_summary(train_acc_summ,epoch * 400 + j)
#     244                     writer.add_summary(train_lost_summ,epoch * 400 + j)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
