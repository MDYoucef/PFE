# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def batch_norm(x, n_out, phase_train, convolutional = False, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if convolutional:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        
        else:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
        
        ema = tf.train.ExponentialMovingAverage(decay=0.999)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3//batch_norm/test_3/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    prob_3=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [3072, 512], initializer=tf.contrib.layers.xavier_initializer()),
    'wc9': tf.get_variable(name = "w9",shape = [512, 256], initializer=tf.contrib.layers.xavier_initializer()),
    'wc10': tf.get_variable(name = "w10",shape = [256, 10], initializer=tf.contrib.layers.xavier_initializer()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc10': tf.Variable(tf.constant(0.1, shape=[10]), name = "b10"),
}

'''
'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)
x_image_do=tf.nn.dropout(x_bn, keep_prob=prob_3)

hidden_1 = tf.nn.conv2d(x_image_do, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_1)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_1)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID')
hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7_bn)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_do), weights['wc8'])
hidden_8_bn = batch_norm(hidden_8, 512, phase_train, convolutional = False)
hidden_8_relu = tf.nn.elu(hidden_8_bn)
hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_do, weights['wc9'])
hidden_9_bn = batch_norm(hidden_9, 256, phase_train, convolutional = False)
hidden_9_relu = tf.nn.elu(hidden_9_bn)
hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_do, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init, {phase_train: True})
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, prob_3:0.9, phase_train: True})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (3072, 512)
# 2
# 3072
# 512
# 1572864
# (512, 256)
# 2
# 512
# 256
# 131072
# (256, 10)
# 2
# 256
# 10
# 2560
# (10,)
# 1
# 10
# 10
# total_parameters :  2387482
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 512)
# (?, 256)
# WARNING:tensorflow:From <ipython-input-11-fd8a9ec36b0a>:182 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-fd8a9ec36b0a>:183 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-fd8a9ec36b0a>:190 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.424
# j =  160
# batch_train_accuracy =  0.344
# j =  240
# batch_train_accuracy =  0.36
# j =  320
# batch_train_accuracy =  0.344
# lost =  2.50715557903
# train_cumulative_accuracy :  0.342719998434
# duree :  112.671185017
# lost =  2.12469082594
# test_cumulative_accuracy :  0.405499990582
# epoch :  1
# j =  0
# batch_train_accuracy =  0.368
# j =  80
# batch_train_accuracy =  0.424
# j =  160
# batch_train_accuracy =  0.432
# j =  240
# batch_train_accuracy =  0.504
# j =  320
# batch_train_accuracy =  0.456
# lost =  2.52364528835
# train_cumulative_accuracy :  0.40756000042
# duree :  238.242466927
# lost =  2.38358234286
# test_cumulative_accuracy :  0.419099988639
# epoch :  2
# j =  0
# batch_train_accuracy =  0.416
# j =  80
# batch_train_accuracy =  0.4
# j =  160
# batch_train_accuracy =  0.496
# j =  240
# batch_train_accuracy =  0.616
# j =  320
# batch_train_accuracy =  0.448
# lost =  2.55814403564
# train_cumulative_accuracy :  0.424879999608
# duree :  362.732146978
# lost =  2.54103549242
# test_cumulative_accuracy :  0.426799987555
# epoch :  3
# j =  0
# batch_train_accuracy =  0.44
# j =  80
# batch_train_accuracy =  0.488
# j =  160
# batch_train_accuracy =  0.48
# j =  240
# batch_train_accuracy =  0.568
# j =  320
# batch_train_accuracy =  0.448
# lost =  2.59740339041
# train_cumulative_accuracy :  0.434199996442
# duree :  487.592740059
# lost =  2.39016532421
# test_cumulative_accuracy :  0.450299987793
# epoch :  4
# j =  0
# batch_train_accuracy =  0.464
# j =  80
# batch_train_accuracy =  0.456
# j =  160
# batch_train_accuracy =  0.488
# j =  240
# batch_train_accuracy =  0.488
# j =  320
# batch_train_accuracy =  0.432
# lost =  2.50699700177
# train_cumulative_accuracy :  0.452219996974
# duree :  611.596834898
# lost =  2.37889989734
# test_cumulative_accuracy :  0.456899985969
# epoch :  5
# j =  0
# batch_train_accuracy =  0.464
# j =  80
# batch_train_accuracy =  0.408
# j =  160
# batch_train_accuracy =  0.464
# j =  240
# batch_train_accuracy =  0.576
# j =  320
# batch_train_accuracy =  0.416
# lost =  2.41887246519
# train_cumulative_accuracy :  0.469859996438
# duree :  736.270705938
# lost =  2.23344999194
# test_cumulative_accuracy :  0.491299981773
# epoch :  6
# j =  0
# batch_train_accuracy =  0.488
# j =  80
# batch_train_accuracy =  0.496
# j =  160
# batch_train_accuracy =  0.448
# j =  240
# batch_train_accuracy =  0.504
# j =  320
# batch_train_accuracy =  0.448
# lost =  2.4976047188
# train_cumulative_accuracy :  0.471239996627
# duree :  860.315821886
# lost =  2.19867631435
# test_cumulative_accuracy :  0.504899976552
# epoch :  7
# j =  0
# batch_train_accuracy =  0.536
# j =  80
# batch_train_accuracy =  0.472
# j =  160
# batch_train_accuracy =  0.464
# j =  240
# batch_train_accuracy =  0.544
# j =  320
# batch_train_accuracy =  0.48
# lost =  2.36350016534
# train_cumulative_accuracy :  0.48501999855
# duree :  984.219208956
# lost =  2.24198485494
# test_cumulative_accuracy :  0.50839997679
# epoch :  8
# j =  0
# batch_train_accuracy =  0.536
# j =  80
# batch_train_accuracy =  0.544
# j =  160
# batch_train_accuracy =  0.44
# j =  240
# batch_train_accuracy =  0.592
# j =  320
# batch_train_accuracy =  0.432
# lost =  2.15770527154
# train_cumulative_accuracy :  0.512939995825
# duree :  1108.23417997
# lost =  2.17954292417
# test_cumulative_accuracy :  0.495699982345
# epoch :  9
# j =  0
# batch_train_accuracy =  0.536
# j =  80
# batch_train_accuracy =  0.536
# j =  160
# batch_train_accuracy =  0.456
# j =  240
# batch_train_accuracy =  0.552
# j =  320
# batch_train_accuracy =  0.536
# lost =  2.00813390553
# train_cumulative_accuracy :  0.528239995614
# duree :  1232.50265694
# lost =  2.14118254066
# test_cumulative_accuracy :  0.50929997623
# epoch :  10
# j =  0
# batch_train_accuracy =  0.544
# j =  80
# batch_train_accuracy =  0.632
# j =  160
# batch_train_accuracy =  0.568
# j =  240
# batch_train_accuracy =  0.632
# j =  320
# batch_train_accuracy =  0.528
# lost =  1.78007949769
# train_cumulative_accuracy :  0.557879994735
# duree :  1356.725595
# lost =  2.17808883548
# test_cumulative_accuracy :  0.507499978244
# epoch :  11
# j =  0
# batch_train_accuracy =  0.552
# j =  80
# batch_train_accuracy =  0.632
# j =  160
# batch_train_accuracy =  0.544
# j =  240
# batch_train_accuracy =  0.56
# j =  320
# batch_train_accuracy =  0.536
# lost =  1.82129141718
# train_cumulative_accuracy :  0.555619994104
# duree :  1480.83377504
# lost =  2.04310729265
# test_cumulative_accuracy :  0.514199977517
# epoch :  12
# j =  0
# batch_train_accuracy =  0.56
# j =  80
# batch_train_accuracy =  0.584
# j =  160
# batch_train_accuracy =  0.672
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.544
# lost =  1.67022631973
# train_cumulative_accuracy :  0.574339996055
# duree :  1604.69550991
# lost =  2.05488123059
# test_cumulative_accuracy :  0.503299974203
# epoch :  13
# j =  0
# batch_train_accuracy =  0.544
# j =  80
# batch_train_accuracy =  0.616
# j =  160
# batch_train_accuracy =  0.632
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.56
# lost =  1.60834718138
# train_cumulative_accuracy :  0.589519995153
# duree :  1728.7370069
# lost =  1.67139098525
# test_cumulative_accuracy :  0.58039997071
# epoch :  14
# j =  0
# batch_train_accuracy =  0.664
# j =  80
# batch_train_accuracy =  0.608
# j =  160
# batch_train_accuracy =  0.584
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.576
# lost =  1.57392912045
# train_cumulative_accuracy :  0.599859993756
# duree :  1852.77823186
# lost =  2.02057839394
# test_cumulative_accuracy :  0.51629997462
# epoch :  15
# j =  0
# batch_train_accuracy =  0.576
# j =  80
# batch_train_accuracy =  0.592
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.672
# lost =  1.49532799065
# train_cumulative_accuracy :  0.60991999492
# duree :  1976.74172497
# lost =  1.91959608555
# test_cumulative_accuracy :  0.553999965191
# epoch :  16
# j =  0
# batch_train_accuracy =  0.584
# j =  80
# batch_train_accuracy =  0.656
# j =  160
# batch_train_accuracy =  0.592
# j =  240
# batch_train_accuracy =  0.624
# j =  320
# batch_train_accuracy =  0.616
# lost =  1.55730978698
# train_cumulative_accuracy :  0.604699994922
# duree :  2100.78022289
# lost =  1.83178432822
# test_cumulative_accuracy :  0.566099966168
# epoch :  17
# j =  0
# batch_train_accuracy =  0.6
# j =  80
# batch_train_accuracy =  0.632
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.656
# j =  320
# batch_train_accuracy =  0.624
# lost =  1.42360907003
# train_cumulative_accuracy :  0.626719997227
# duree :  2225.18362594
# lost =  1.99304329991
# test_cumulative_accuracy :  0.545999966264
# epoch :  18
# j =  0
# batch_train_accuracy =  0.592
# j =  80
# batch_train_accuracy =  0.64
# j =  160
# batch_train_accuracy =  0.656
# j =  240
# batch_train_accuracy =  0.608
# j =  320
# batch_train_accuracy =  0.64
# lost =  1.39760874525
# train_cumulative_accuracy :  0.62961999692
# duree :  2349.13972187
# lost =  1.5933658874
# test_cumulative_accuracy :  0.597499967217
# epoch :  19
# j =  0
# batch_train_accuracy =  0.656
# j =  80
# batch_train_accuracy =  0.672
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.64
# j =  320
# batch_train_accuracy =  0.656
# lost =  1.34562599853
# train_cumulative_accuracy :  0.641459998786
# duree :  2473.64872599
# lost =  1.72432233334
# test_cumulative_accuracy :  0.57879996419
# epoch :  20
# j =  0
# batch_train_accuracy =  0.64
# j =  80
# batch_train_accuracy =  0.68
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.592
# lost =  1.34891224638
# train_cumulative_accuracy :  0.639799996465
# duree :  2597.5722549
# lost =  1.90951249957
# test_cumulative_accuracy :  0.559199968278
# epoch :  21
# j =  0
# batch_train_accuracy =  0.608
# j =  80
# batch_train_accuracy =  0.624
# j =  160
# batch_train_accuracy =  0.704
# j =  240
# batch_train_accuracy =  0.624
# j =  320
# batch_train_accuracy =  0.56
# lost =  1.41575844914
# train_cumulative_accuracy :  0.627779994458
# duree :  2721.459764
# lost =  1.65304971457
# test_cumulative_accuracy :  0.595299967229
# epoch :  22
# j =  0
# batch_train_accuracy =  0.648
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.704
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.36553996354
# train_cumulative_accuracy :  0.637139996737
# duree :  2846.11447096
# lost =  1.75077017426
# test_cumulative_accuracy :  0.581599971056
# epoch :  23
# j =  0
# batch_train_accuracy =  0.616
# j =  80
# batch_train_accuracy =  0.632
# j =  160
# batch_train_accuracy =  0.744
# j =  240
# batch_train_accuracy =  0.656
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.43028632507
# train_cumulative_accuracy :  0.62759999454
# duree :  2969.95784903
# lost =  1.85492030859
# test_cumulative_accuracy :  0.565299969614
# epoch :  24
# j =  0
# batch_train_accuracy =  0.616
# j =  80
# batch_train_accuracy =  0.6
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.664
# j =  320
# batch_train_accuracy =  0.608
# lost =  1.4537414594
# train_cumulative_accuracy :  0.626919996366
# duree :  3093.95867705
# lost =  2.14038210154
# test_cumulative_accuracy :  0.54719996959
# epoch :  25
# j =  0
# batch_train_accuracy =  0.632
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.64
# j =  320
# batch_train_accuracy =  0.624
# lost =  1.37207843572
# train_cumulative_accuracy :  0.63927999571
# duree :  3218.15905285
# lost =  1.78019536495
# test_cumulative_accuracy :  0.583599966764
# epoch :  26
# j =  0
# batch_train_accuracy =  0.664
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.656
# j =  240
# batch_train_accuracy =  0.64
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.38790913686
# train_cumulative_accuracy :  0.64587999776
# duree :  3342.13587308
# lost =  1.77005652308
# test_cumulative_accuracy :  0.582199962437
# epoch :  27
# j =  0
# batch_train_accuracy =  0.656
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.656
# j =  240
# batch_train_accuracy =  0.592
# j =  320
# batch_train_accuracy =  0.624
# lost =  1.40471281737
# train_cumulative_accuracy :  0.641499994844
# duree :  3466.12127399
# lost =  1.64668337584
# test_cumulative_accuracy :  0.60819997102
# epoch :  28
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.704
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.672
# lost =  1.2535420087
# train_cumulative_accuracy :  0.667599998415
# duree :  3590.13332891
# lost =  2.0180147326
# test_cumulative_accuracy :  0.55939996779
# epoch :  29
# j =  0
# batch_train_accuracy =  0.632
# j =  80
# batch_train_accuracy =  0.672
# j =  160
# batch_train_accuracy =  0.696
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.4001647906
# train_cumulative_accuracy :  0.641439995468
# duree :  3714.06312895
# lost =  1.92685297132
# test_cumulative_accuracy :  0.578499968648
# epoch :  30
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.6
# j =  160
# batch_train_accuracy =  0.744
# j =  240
# batch_train_accuracy =  0.664
# j =  320
# batch_train_accuracy =  0.696
# lost =  1.39238583207
# train_cumulative_accuracy :  0.64839999795
# duree :  3838.19932294
# lost =  1.85147716045
# test_cumulative_accuracy :  0.576899962425
# epoch :  31
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.672
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.576
# lost =  1.44855394259
# train_cumulative_accuracy :  0.637039995268
# duree :  3962.06669807
# lost =  2.1340725255
# test_cumulative_accuracy :  0.552799964845
# epoch :  32
# j =  0
# batch_train_accuracy =  0.624
# j =  80
# batch_train_accuracy =  0.68
# j =  160
# batch_train_accuracy =  0.664
# j =  240
# batch_train_accuracy =  0.64
# j =  320
# batch_train_accuracy =  0.64
# lost =  1.4119411464
# train_cumulative_accuracy :  0.645799996853
# duree :  4086.10060096
# lost =  1.91579277396
# test_cumulative_accuracy :  0.577399969697
# epoch :  33
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.712
# j =  240
# batch_train_accuracy =  0.664
# j =  320
# batch_train_accuracy =  0.656
# lost =  1.36522855952
# train_cumulative_accuracy :  0.658299997896
# duree :  4210.12258387
# lost =  1.46965896726
# test_cumulative_accuracy :  0.645299969316
# epoch :  34
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.648
# j =  240
# batch_train_accuracy =  0.656
# j =  320
# batch_train_accuracy =  0.688
# lost =  1.2307803908
# train_cumulative_accuracy :  0.673799999058
# duree :  4334.00492406
# lost =  1.94653760076
# test_cumulative_accuracy :  0.563299971223
# epoch :  35
# j =  0
# batch_train_accuracy =  0.616
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.688
# j =  240
# batch_train_accuracy =  0.608
# j =  320
# batch_train_accuracy =  0.672
# lost =  1.2591425091
# train_cumulative_accuracy :  0.668779997081
# duree :  4458.062217
# lost =  1.82050110102
# test_cumulative_accuracy :  0.588999966383
# epoch :  36
# j =  0
# batch_train_accuracy =  0.64
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.656
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.25085206687
# train_cumulative_accuracy :  0.675999998599
# duree :  4582.019871
# lost =  1.57942330241
# test_cumulative_accuracy :  0.621399961114
# epoch :  37
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.672
# j =  160
# batch_train_accuracy =  0.736
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.704
# lost =  1.43106223926
# train_cumulative_accuracy :  0.644519994333
# duree :  4705.85270596
# lost =  1.85978443384
# test_cumulative_accuracy :  0.595799966455
# epoch :  38
# j =  0
# batch_train_accuracy =  0.664
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.712
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.64
# lost =  1.40944848806
# train_cumulative_accuracy :  0.655659996867
# duree :  4829.78293085
# lost =  2.2382545495
# test_cumulative_accuracy :  0.558399965763
# epoch :  39
# j =  0
# batch_train_accuracy =  0.592
# j =  80
# batch_train_accuracy =  0.616
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.576
# lost =  1.62392694563
# train_cumulative_accuracy :  0.623239994794
# duree :  4953.78277588
# lost =  1.78764017582
# test_cumulative_accuracy :  0.606899966598
# epoch :  40
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.664
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.536
# lost =  1.51128800929
# train_cumulative_accuracy :  0.638499999866
# duree :  5077.64602304
# lost =  1.79718507886
# test_cumulative_accuracy :  0.604899971783
# epoch :  41
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.656
# j =  320
# batch_train_accuracy =  0.576
# lost =  1.57401702359
# train_cumulative_accuracy :  0.636399993747
# duree :  5201.6617229
# lost =  2.13016692519
# test_cumulative_accuracy :  0.575499966741
# epoch :  42
# j =  0
# batch_train_accuracy =  0.648
# j =  80
# batch_train_accuracy =  0.664
# j =  160
# batch_train_accuracy =  0.712
# j =  240
# batch_train_accuracy =  0.632
# j =  320
# batch_train_accuracy =  0.688
# lost =  1.37393773988
# train_cumulative_accuracy :  0.670739998966
# duree :  5325.45271587
# lost =  2.1748903966
# test_cumulative_accuracy :  0.56199996978
# epoch :  43
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.704
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.584
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.4509960404
# train_cumulative_accuracy :  0.666939998418
# duree :  5449.40725899
# lost =  2.26562269568
# test_cumulative_accuracy :  0.574199966788
# epoch :  44
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.632
# j =  160
# batch_train_accuracy =  0.712
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.44339735746
# train_cumulative_accuracy :  0.665919996649
# duree :  5573.42395401
# lost =  1.79868170381
# test_cumulative_accuracy :  0.614699966013
# epoch :  45
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.688
# j =  160
# batch_train_accuracy =  0.736
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.42330333263
# train_cumulative_accuracy :  0.663479997143
# duree :  5697.49584889
# lost =  2.13722021818
# test_cumulative_accuracy :  0.568099966943
# epoch :  46
# j =  0
# batch_train_accuracy =  0.632
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.72
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.624
# lost =  1.49334849119
# train_cumulative_accuracy :  0.651959996894
# duree :  5821.46769285
# lost =  2.17606367826
# test_cumulative_accuracy :  0.57099996835
# epoch :  47
# j =  0
# batch_train_accuracy =  0.648
# j =  80
# batch_train_accuracy =  0.68
# j =  160
# batch_train_accuracy =  0.664
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.68
# lost =  1.48641501933
# train_cumulative_accuracy :  0.654339995906
# duree :  5945.50880599
# lost =  1.91057809949
# test_cumulative_accuracy :  0.617799962759
# epoch :  48
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.19553262785
# train_cumulative_accuracy :  0.7048800008
# duree :  6069.54428291
# lost =  1.68517229378
# test_cumulative_accuracy :  0.645399971604
# epoch :  49
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.712
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.592
# lost =  1.26005282447
# train_cumulative_accuracy :  0.697180002779
# duree :  6193.4887979
# lost =  2.11693410277
# test_cumulative_accuracy :  0.589299970865
# epoch :  50
# j =  0
# batch_train_accuracy =  0.656
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.768
# lost =  1.12036528237
# train_cumulative_accuracy :  0.720200003535
# duree :  6317.54891086
# lost =  1.99569804192
# test_cumulative_accuracy :  0.61599996835
# epoch :  51
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.1269884482
# train_cumulative_accuracy :  0.720620002598
# duree :  6441.67202091
# lost =  1.5748874706
# test_cumulative_accuracy :  0.656199967861
# epoch :  52
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.72
# lost =  1.21389542222
# train_cumulative_accuracy :  0.699739998579
# duree :  6565.53072095
# lost =  2.13480417609
# test_cumulative_accuracy :  0.591099967957
# epoch :  53
# j =  0
# batch_train_accuracy =  0.632
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.19660724282
# train_cumulative_accuracy :  0.709599999338
# duree :  6689.46280098
# lost =  1.67081319988
# test_cumulative_accuracy :  0.655699968934
# epoch :  54
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.744
# lost =  1.17188196041
# train_cumulative_accuracy :  0.71648000285
# duree :  6813.54744387
# lost =  1.54308222473
# test_cumulative_accuracy :  0.663799967766
# epoch :  55
# j =  0
# batch_train_accuracy =  0.776
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.64
# lost =  1.18408632681
# train_cumulative_accuracy :  0.710119999796
# duree :  6937.36364603
# lost =  2.18887768269
# test_cumulative_accuracy :  0.579599969685
# epoch :  56
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.656
# lost =  1.2630205632
# train_cumulative_accuracy :  0.693220002204
# duree :  7061.35222101
# lost =  2.35755835056
# test_cumulative_accuracy :  0.562299965024
# epoch :  57
# j =  0
# batch_train_accuracy =  0.64
# j =  80
# batch_train_accuracy =  0.744
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.26316318415
# train_cumulative_accuracy :  0.698899999112
# duree :  7185.22782397
# lost =  1.59530887246
# test_cumulative_accuracy :  0.653299969435
# epoch :  58
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.648
# lost =  1.22223208532
# train_cumulative_accuracy :  0.707820001245
# duree :  7309.35545087
# lost =  2.00410721302
# test_cumulative_accuracy :  0.614299967289
# epoch :  59
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.688
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.34828360349
# train_cumulative_accuracy :  0.687420001924
# duree :  7433.47349501
# lost =  2.09653595328
# test_cumulative_accuracy :  0.596699969471
# epoch :  60
# j =  0
# batch_train_accuracy =  0.648
# j =  80
# batch_train_accuracy =  0.704
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.23595587909
# train_cumulative_accuracy :  0.706600002646
# duree :  7557.46412992
# lost =  1.9654155767
# test_cumulative_accuracy :  0.615399969518
# epoch :  61
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.696
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.72
# lost =  1.41506416842
# train_cumulative_accuracy :  0.679659996331
# duree :  7681.31795502
# lost =  1.98479062438
# test_cumulative_accuracy :  0.607799968123
# epoch :  62
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.712
# lost =  1.22554270916
# train_cumulative_accuracy :  0.707920000106
# duree :  7805.20015693
# lost =  1.89002966404
# test_cumulative_accuracy :  0.623299967945
# epoch :  63
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.08148498073
# train_cumulative_accuracy :  0.738780006021
# duree :  7929.17453599
# lost =  1.9023536098
# test_cumulative_accuracy :  0.622099971175
# epoch :  64
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.72
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.29755726203
# train_cumulative_accuracy :  0.69980000034
# duree :  8053.05228496
# lost =  1.85245466709
# test_cumulative_accuracy :  0.631099966764
# epoch :  65
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.712
# lost =  1.25955017209
# train_cumulative_accuracy :  0.704459999055
# duree :  8176.94047904
# lost =  1.79130812049
# test_cumulative_accuracy :  0.645099970698
# epoch :  66
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.744
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.00695485547
# train_cumulative_accuracy :  0.744800008237
# duree :  8301.05151796
# lost =  1.62216708601
# test_cumulative_accuracy :  0.662399972677
# epoch :  67
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.744
# lost =  1.05581611529
# train_cumulative_accuracy :  0.739700005949
# duree :  8424.95218897
# lost =  1.67896482289
# test_cumulative_accuracy :  0.662399970293
# epoch :  68
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.608
# lost =  1.20744598411
# train_cumulative_accuracy :  0.719620000869
# duree :  8549.02158499
# lost =  1.72743733525
# test_cumulative_accuracy :  0.647499969006
# epoch :  69
# j =  0
# batch_train_accuracy =  0.776
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.784
# lost =  1.09978653967
# train_cumulative_accuracy :  0.73676000461
# duree :  8673.10518003
# lost =  1.77584431887
# test_cumulative_accuracy :  0.648899968863
# epoch :  70
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.08823423512
# train_cumulative_accuracy :  0.735900003165
# duree :  8796.9137969
# lost =  2.02340321779
# test_cumulative_accuracy :  0.618999968469
# epoch :  71
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.736
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.776
# lost =  1.13887094229
# train_cumulative_accuracy :  0.733080004454
# duree :  8920.84712005
# lost =  1.95763725281
# test_cumulative_accuracy :  0.62909996748
# epoch :  72
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.856
# lost =  1.11127368271
# train_cumulative_accuracy :  0.735860003978
# duree :  9044.99287295
# lost =  1.52766744018
# test_cumulative_accuracy :  0.670999961495
# epoch :  73
# j =  0
# batch_train_accuracy =  0.816
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.872
# lost =  0.864437169358
# train_cumulative_accuracy :  0.77764000982
# duree :  9168.95496202
# lost =  1.89691991329
# test_cumulative_accuracy :  0.632899968624
# epoch :  74
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.736
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.776
# lost =  1.00863757223
# train_cumulative_accuracy :  0.753680005372
# duree :  9292.89973998
# lost =  1.57896823168
# test_cumulative_accuracy :  0.67499996841
# epoch :  75
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.72
# lost =  1.0718633198
# train_cumulative_accuracy :  0.7463200064
# duree :  9416.89910102
# lost =  1.73643832922
# test_cumulative_accuracy :  0.656499968469
# epoch :  76
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.21730318218
# train_cumulative_accuracy :  0.721360003203
# duree :  9541.06323385
# lost =  2.0179086411
# test_cumulative_accuracy :  0.622399968803
# epoch :  77
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.12362579167
# train_cumulative_accuracy :  0.736040003151
# duree :  9664.98149586
# lost =  1.84297045588
# test_cumulative_accuracy :  0.649199969172
# epoch :  78
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.744
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.792
# lost =  1.0511563766
# train_cumulative_accuracy :  0.744320006967
# duree :  9788.99503899
# lost =  1.68757326841
# test_cumulative_accuracy :  0.662699969411
# epoch :  79
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.776
# lost =  1.06299058408
# train_cumulative_accuracy :  0.743840007782
# duree :  9913.15720201
# lost =  1.8992404151
# test_cumulative_accuracy :  0.643199970722
# epoch :  80
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.09278106675
# train_cumulative_accuracy :  0.738060005307
# duree :  10037.0642619
# lost =  1.72319427967
# test_cumulative_accuracy :  0.666799969077
# epoch :  81
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.784
# lost =  0.990317706838
# train_cumulative_accuracy :  0.762520009279
# duree :  10160.9477761
# lost =  1.74754317045
# test_cumulative_accuracy :  0.666899965405
# epoch :  82
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.784
# lost =  1.0071443291
# train_cumulative_accuracy :  0.754600008875
# duree :  10284.9192009
# lost =  1.70856674552
# test_cumulative_accuracy :  0.662399967909
# epoch :  83
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.856
# lost =  1.24447850868
# train_cumulative_accuracy :  0.718760002702
# duree :  10408.843091
# lost =  2.06350059152
# test_cumulative_accuracy :  0.624499967396
# epoch :  84
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.792
# lost =  1.06327460308
# train_cumulative_accuracy :  0.751060006171
# duree :  10532.827795
# lost =  1.77871357441
# test_cumulative_accuracy :  0.659299971461
# epoch :  85
# j =  0
# batch_train_accuracy =  0.776
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.16205412209
# train_cumulative_accuracy :  0.735780003667
# duree :  10656.818867
# lost =  2.03168254137
# test_cumulative_accuracy :  0.636799969375
# epoch :  86
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.768
# lost =  1.14995186988
# train_cumulative_accuracy :  0.740540006012
# duree :  10780.8270669
# lost =  1.71825734973
# test_cumulative_accuracy :  0.665599970818
# epoch :  87
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.03474543422
# train_cumulative_accuracy :  0.758380004764
# duree :  10904.744041
# lost =  2.04734797359
# test_cumulative_accuracy :  0.627199970484
# epoch :  88
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.712
# lost =  1.19281551063
# train_cumulative_accuracy :  0.731100005805
# duree :  11028.7564149
# lost =  2.2794972229
# test_cumulative_accuracy :  0.605699968934
# epoch :  89
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.744
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.744
# lost =  1.23409194142
# train_cumulative_accuracy :  0.72778000325
# duree :  11152.6692169
# lost =  1.72062326074
# test_cumulative_accuracy :  0.66319996655
# epoch :  90
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.72
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.8
# lost =  1.30639985561
# train_cumulative_accuracy :  0.708960002065
# duree :  11276.625232
# lost =  2.02535657763
# test_cumulative_accuracy :  0.614699968696
# epoch :  91
# j =  0
# batch_train_accuracy =  0.664
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.1116416458
# train_cumulative_accuracy :  0.740240005702
# duree :  11400.5729201
# lost =  2.07107001543
# test_cumulative_accuracy :  0.62389996767
# epoch :  92
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.07768202782
# train_cumulative_accuracy :  0.741060004234
# duree :  11524.671984
# lost =  1.74056719542
# test_cumulative_accuracy :  0.659599967003
# epoch :  93
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.8
# lost =  0.956324029341
# train_cumulative_accuracy :  0.765060008466
# duree :  11648.6979411
# lost =  1.78770956397
# test_cumulative_accuracy :  0.661099969149
# epoch :  94
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.03835015418
# train_cumulative_accuracy :  0.757880007625
# duree :  11772.671838
# lost =  1.99949674964
# test_cumulative_accuracy :  0.634299971461
# epoch :  95
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.8
# lost =  0.886651573032
# train_cumulative_accuracy :  0.781160008162
# duree :  11896.54776
# lost =  1.68285673618
# test_cumulative_accuracy :  0.669599969983
# epoch :  96
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.728
# lost =  1.11646170542
# train_cumulative_accuracy :  0.746280005127
# duree :  12020.504776
# lost =  1.98130016208
# test_cumulative_accuracy :  0.628599970937
# epoch :  97
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.672
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.19404376246
# train_cumulative_accuracy :  0.728340006024
# duree :  12144.37095
# lost =  1.94940543771
# test_cumulative_accuracy :  0.637099970877
# epoch :  98
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.2008308176
# train_cumulative_accuracy :  0.73304000482
# duree :  12268.2419879
# lost =  2.29572944164
# test_cumulative_accuracy :  0.599899967909
# epoch :  99
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.28002295963
# train_cumulative_accuracy :  0.720280000865
# duree :  12392.1558449
# lost =  2.28266368866
# test_cumulative_accuracy :  0.604899966717
# epoch :  100
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.72
# lost =  1.42959982246
# train_cumulative_accuracy :  0.69964000091
# duree :  12515.9768801
# lost =  2.29493732214
# test_cumulative_accuracy :  0.591199971139
# epoch :  101
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.704
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.736
# lost =  1.28830345616
# train_cumulative_accuracy :  0.710440003723
# duree :  12639.9633899
# lost =  2.11046725392
# test_cumulative_accuracy :  0.612999969125
# epoch :  102
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.744
# j =  160
# batch_train_accuracy =  0.744
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.776
# lost =  1.27985597938
# train_cumulative_accuracy :  0.717100000978
# duree :  12763.9003029
# lost =  1.93415950775
# test_cumulative_accuracy :  0.645499970913
# epoch :  103
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.84
# lost =  1.15658589259
# train_cumulative_accuracy :  0.737860005051
# duree :  12887.690011
# lost =  1.86706879616
# test_cumulative_accuracy :  0.65129997015
# epoch :  104
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.84
# lost =  1.00394223116
# train_cumulative_accuracy :  0.765420009643
# duree :  13011.7095819
# lost =  1.91216309071
# test_cumulative_accuracy :  0.662399967909
# epoch :  105
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.17775593299
# train_cumulative_accuracy :  0.739840003401
# duree :  13135.451798
# lost =  2.16232841253
# test_cumulative_accuracy :  0.610799968541
# epoch :  106
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.20117022641
# train_cumulative_accuracy :  0.731640003994
# duree :  13259.387243
# lost =  1.7404566294
# test_cumulative_accuracy :  0.665499964356
# epoch :  107
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.856
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.8
# lost =  1.0184944582
# train_cumulative_accuracy :  0.761820007861
# duree :  13383.2603979
# lost =  1.84670087099
# test_cumulative_accuracy :  0.660899967551
# epoch :  108
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.704
# lost =  1.07551287573
# train_cumulative_accuracy :  0.754080007225
# duree :  13507.153419
# lost =  1.92355562449
# test_cumulative_accuracy :  0.659299968481
# epoch :  109
# j =  0
# batch_train_accuracy =  0.792
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.856
# lost =  1.03550000682
# train_cumulative_accuracy :  0.759500007629
# duree :  13631.021419
# lost =  1.71012889862
# test_cumulative_accuracy :  0.672599967718
# epoch :  110
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.736
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.824
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.91373618301
# train_cumulative_accuracy :  0.781500012428
# duree :  13754.8596129
# lost =  1.82711983323
# test_cumulative_accuracy :  0.669299966097
# epoch :  111
# j =  0
# batch_train_accuracy =  0.8
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.792
# j =  320
# batch_train_accuracy =  0.664
# lost =  1.11367428854
# train_cumulative_accuracy :  0.747720007151
# duree :  13878.7514019
# lost =  1.66866384983
# test_cumulative_accuracy :  0.666699968576
# epoch :  112
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.8
# j =  320
# batch_train_accuracy =  0.824
# lost =  1.07452279679
# train_cumulative_accuracy :  0.749100004733
# duree :  14002.6514111
# lost =  2.02120891571
# test_cumulative_accuracy :  0.634399968982
# epoch :  113
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.808
# lost =  0.958760817163
# train_cumulative_accuracy :  0.769520007372
# duree :  14126.5624928
# lost =  1.8934823072
# test_cumulative_accuracy :  0.630599965453
# epoch :  114
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.736
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.8
# lost =  1.24348916292
# train_cumulative_accuracy :  0.720500003844
# duree :  14250.5291529
# lost =  1.98668581128
# test_cumulative_accuracy :  0.639299968481
# epoch :  115
# j =  0
# batch_train_accuracy =  0.712
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.768
# lost =  1.21640950412
# train_cumulative_accuracy :  0.730220002532
# duree :  14374.3564739
# lost =  2.27061891198
# test_cumulative_accuracy :  0.609399968386
# epoch :  116
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.744
# lost =  1.1050632444
# train_cumulative_accuracy :  0.746820004582
# duree :  14498.3081489
# lost =  1.76768900275
# test_cumulative_accuracy :  0.660299965143
# epoch :  117
# j =  0
# batch_train_accuracy =  0.768
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.848
# lost =  1.03420013398
# train_cumulative_accuracy :  0.758720004708
# duree :  14622.201154
# lost =  1.97346190929
# test_cumulative_accuracy :  0.649599969983
# epoch :  118
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.752
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.18942209341
# train_cumulative_accuracy :  0.740260006189
# duree :  14746.072134
# lost =  2.39781742334
# test_cumulative_accuracy :  0.603099968731
# epoch :  119
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.736
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.19395433284
# train_cumulative_accuracy :  0.73678000316
# duree :  14869.9970689
# lost =  1.92292658329
# test_cumulative_accuracy :  0.641499971151
# epoch :  120
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.84
# lost =  1.06120022491
# train_cumulative_accuracy :  0.756680005938
# duree :  14993.822237
# lost =  2.05631507516
# test_cumulative_accuracy :  0.632799966931
# epoch :  121
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.736
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.856
# lost =  1.096305364
# train_cumulative_accuracy :  0.752820009738
# duree :  15117.7200351
# lost =  1.58234254062
# test_cumulative_accuracy :  0.682499963045
# epoch :  122
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.848
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.752
# lost =  0.97995706141
# train_cumulative_accuracy :  0.772480009049
# duree :  15241.7480519
# lost =  1.84292726398
# test_cumulative_accuracy :  0.656999968886
# epoch :  123
# j =  0
# batch_train_accuracy =  0.776
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.14586532608
# train_cumulative_accuracy :  0.746460006982
# duree :  15365.6875529
# lost =  2.14690876484
# test_cumulative_accuracy :  0.635499968827
# epoch :  124
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.696
# j =  320
# batch_train_accuracy =  0.752
# lost =  1.2826189924
# train_cumulative_accuracy :  0.728940003216
# duree :  15489.556128
# lost =  2.18960539937
# test_cumulative_accuracy :  0.614699968994
# epoch :  125
# j =  0
# batch_train_accuracy =  0.664
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.8
# lost =  1.22895872757
# train_cumulative_accuracy :  0.734940005988
# duree :  15613.811414
# lost =  2.09067664742
# test_cumulative_accuracy :  0.63109996736
# epoch :  126
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.728
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.736
# j =  320
# batch_train_accuracy =  0.704
# lost =  1.37476930305
# train_cumulative_accuracy :  0.710220001787
# duree :  15737.7328799
# lost =  2.24177899003
# test_cumulative_accuracy :  0.614499970973
# epoch :  127
# j =  0
# batch_train_accuracy =  0.704
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.832
# lost =  1.15806366935
# train_cumulative_accuracy :  0.748740009815
# duree :  15861.7040839
# lost =  1.98867480755
# test_cumulative_accuracy :  0.656499965191
# epoch :  128
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.704
# j =  320
# batch_train_accuracy =  0.824
# lost =  1.078122233
# train_cumulative_accuracy :  0.759820007235
# duree :  15985.6719959
# lost =  2.08285613537
# test_cumulative_accuracy :  0.640299966931
# epoch :  129
# j =  0
# batch_train_accuracy =  0.736
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.872
# lost =  1.0683273612
# train_cumulative_accuracy :  0.757340008169
# duree :  16109.7233
# lost =  1.84889971852
# test_cumulative_accuracy :  0.652799969316
# epoch :  130
# j =  0
# batch_train_accuracy =  0.752
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.752
# j =  240
# batch_train_accuracy =  0.76
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.26254765838
# train_cumulative_accuracy :  0.724800001085
# duree :  16233.6221769
# lost =  2.27590095639
# test_cumulative_accuracy :  0.618799968362
# epoch :  131
# j =  0
# batch_train_accuracy =  0.696
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.8
# j =  320
# batch_train_accuracy =  0.816
# lost =  1.02452734262
# train_cumulative_accuracy :  0.766880008131
# duree :  16357.3809941
# lost =  2.23323123336
# test_cumulative_accuracy :  0.625399970114
# epoch :  132
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.776
# lost =  0.996775674149
# train_cumulative_accuracy :  0.766940009296
# duree :  16481.6287339
# lost =  1.94561990857
# test_cumulative_accuracy :  0.641199965477
# epoch :  133
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.848
# lost =  1.16545635648
# train_cumulative_accuracy :  0.740000005811
# duree :  16605.528806
# lost =  1.93486990809
# test_cumulative_accuracy :  0.649699964225
# epoch :  134
# j =  0
# batch_train_accuracy =  0.72
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.824
# lost =  1.04877297822
# train_cumulative_accuracy :  0.758180009127
# duree :  16729.4735188
# lost =  1.86634726644
# test_cumulative_accuracy :  0.655599971414
# epoch :  135
# j =  0
# batch_train_accuracy =  0.76
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.792
# j =  320
# batch_train_accuracy =  0.824
# lost =  0.976218653545
# train_cumulative_accuracy :  0.768480008841
# duree :  16853.44766
# lost =  1.85731457472
# test_cumulative_accuracy :  0.659299967587
# epoch :  136
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.776
# j =  160
# batch_train_accuracy =  0.84
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.84
# lost =  0.980274495482
# train_cumulative_accuracy :  0.769560009092
# duree :  16977.3274019
# lost =  1.73649052143
# test_cumulative_accuracy :  0.679299967885
# epoch :  137
# j =  0
# batch_train_accuracy =  0.832
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.768
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.832
# lost =  0.973456976935
# train_cumulative_accuracy :  0.773460009247
# duree :  17101.3507121
# lost =  1.58143008113
# test_cumulative_accuracy :  0.699699967504
# epoch :  138
# j =  0
# batch_train_accuracy =  0.84
# j =  80
# batch_train_accuracy =  0.832
# j =  160
# batch_train_accuracy =  0.816
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.848
# lost =  0.980454694703
# train_cumulative_accuracy :  0.774640009105
# duree :  17225.2991269
# lost =  2.02043073177
# test_cumulative_accuracy :  0.649699969888
# epoch :  139
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.784
# j =  240
# batch_train_accuracy =  0.792
# j =  320
# batch_train_accuracy =  0.84
# lost =  1.07466345504
# train_cumulative_accuracy :  0.755060006678
# duree :  17349.3010199
# lost =  1.97036538363
# test_cumulative_accuracy :  0.656599969864
# epoch :  140
# j =  0
# batch_train_accuracy =  0.8
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.68
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.18109411642
# train_cumulative_accuracy :  0.746820005476
# duree :  17473.270416
# lost =  1.80406184196
# test_cumulative_accuracy :  0.666999966502
# epoch :  141
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.792
# j =  160
# batch_train_accuracy =  0.808
# j =  240
# batch_train_accuracy =  0.808
# j =  320
# batch_train_accuracy =  0.84
# lost =  1.10409333533
# train_cumulative_accuracy :  0.754500006437
# duree :  17597.196924
# lost =  1.94272891998
# test_cumulative_accuracy :  0.648599964976
# epoch :  142
# j =  0
# batch_train_accuracy =  0.792
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.696
# lost =  1.28654254474
# train_cumulative_accuracy :  0.735060003698
# duree :  17721.167289
# lost =  2.31767717719
# test_cumulative_accuracy :  0.622799968123
# epoch :  143
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.784
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.776
# lost =  1.29412663773
# train_cumulative_accuracy :  0.732920004874
# duree :  17845.0060289
# lost =  2.14404122114
# test_cumulative_accuracy :  0.646199967861
# epoch :  144
# j =  0
# batch_train_accuracy =  0.744
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.784
# j =  320
# batch_train_accuracy =  0.856
# lost =  1.06135430977
# train_cumulative_accuracy :  0.769640009552
# duree :  17968.932924
# lost =  2.29330409169
# test_cumulative_accuracy :  0.616399967372
# epoch :  145
# j =  0
# batch_train_accuracy =  0.68
# j =  80
# batch_train_accuracy =  0.76
# j =  160
# batch_train_accuracy =  0.776
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.832
# lost =  1.18157375984
# train_cumulative_accuracy :  0.746260002702
# duree :  18092.8935959
# lost =  1.68687169492
# test_cumulative_accuracy :  0.675799967647
# epoch :  146
# j =  0
# batch_train_accuracy =  0.784
# j =  80
# batch_train_accuracy =  0.816
# j =  160
# batch_train_accuracy =  0.728
# j =  240
# batch_train_accuracy =  0.744
# j =  320
# batch_train_accuracy =  0.736
# lost =  1.22671475306
# train_cumulative_accuracy :  0.732120005935
# duree :  18216.8170569
# lost =  1.93638943672
# test_cumulative_accuracy :  0.651099972129
# epoch :  147
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.8
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.2154810065
# train_cumulative_accuracy :  0.736320004463
# duree :  18340.7761199
# lost =  2.15610770822
# test_cumulative_accuracy :  0.612399973571
# epoch :  148
# j =  0
# batch_train_accuracy =  0.688
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.864
# lost =  1.12693945825
# train_cumulative_accuracy :  0.742600005716
# duree :  18464.8054149
# lost =  1.64712148726
# test_cumulative_accuracy :  0.676999967694
# epoch :  149
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.768
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.768
# j =  320
# batch_train_accuracy =  0.824
# lost =  1.01162696943
# train_cumulative_accuracy :  0.766560009867
# duree :  18588.759933
# lost =  1.94380249381
# test_cumulative_accuracy :  0.650599967241
# epoch :  150
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.72
# j =  320
# batch_train_accuracy =  0.744
# lost =  1.22008052327
# train_cumulative_accuracy :  0.732940002531
# duree :  18712.5762849
# lost =  1.97333700061
# test_cumulative_accuracy :  0.659999966621
# epoch :  151
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.824
# j =  160
# batch_train_accuracy =  0.832
# j =  240
# batch_train_accuracy =  0.728
# j =  320
# batch_train_accuracy =  0.76
# lost =  1.10364856541
# train_cumulative_accuracy :  0.754720005542
# duree :  18836.6422698
# lost =  1.72922065139
# test_cumulative_accuracy :  0.683599969745
# epoch :  152
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.792
# j =  240
# batch_train_accuracy =  0.712
# j =  320
# batch_train_accuracy =  0.808
# lost =  1.07377791647
# train_cumulative_accuracy :  0.760200008303
# duree :  18960.7273901
# lost =  1.80315870404
# test_cumulative_accuracy :  0.673899970651
# epoch :  153
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.898517531715
# train_cumulative_accuracy :  0.790880012214
# duree :  19084.86129
# lost =  1.80922640324
# test_cumulative_accuracy :  0.669599964023
# epoch :  154
# j =  0
# batch_train_accuracy =  0.816
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fd8a9ec36b0a> in <module>()
#     213                     img, lbl = gen_batch.next()
#     214                     optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, prob_3:0.9, phase_train: True})
# --> 215                     c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
#     216
#     217                     batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., prob_3:1., phase_train: False})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
