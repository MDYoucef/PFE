# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow.contrib.slim as slim
import numpy as np
import tensorflow as tf
import time
import scipy.misc
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools
import cPickle
import collections
import Image, ImageDraw
import PIL
from PIL import ImageFont
import os
import glob
# %matplotlib inline

# %%
def batch_norm(x, n_out, phase_train, convolutional = False, scope='bn'):
    """
    Batch normalization on convolutional maps.
    Args:
        x:           Tensor, 4D BHWD input maps
        n_out:       integer, depth of input maps
        phase_train: boolean tf.Varialbe, true indicates training phase
        scope:       string, variable scope
    Return:
        normed:      batch-normalized maps
    """
    with tf.variable_scope(scope):
        beta = tf.Variable(tf.constant(0.0, shape=[n_out]),
                                     name='beta', trainable=True)
        gamma = tf.Variable(tf.constant(1.0, shape=[n_out]),
                                      name='gamma', trainable=True)
        if convolutional:
            batch_mean, batch_var = tf.nn.moments(x, [0,1,2], name='moments')
        
        else:
            batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
        
        ema = tf.train.ExponentialMovingAverage(decay=0.999)

        def mean_var_with_update():
            ema_apply_op = ema.apply([batch_mean, batch_var])
            with tf.control_dependencies([ema_apply_op]):
                return tf.identity(batch_mean), tf.identity(batch_var)

        mean, var = tf.cond(phase_train,
                            mean_var_with_update,
                            lambda: (ema.average(batch_mean), ema.average(batch_var)))
        normed = tf.nn.batch_normalization(x, mean, var, beta, gamma, 1e-3)
    return normed

# %%
def cifar10_concatenate():
    
    img = np.zeros([50000,3072])
    lbl = np.zeros([50000])
    for i in range(5):
        with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/data_batch_'+str(i+1),'rb') as f:
            data = cPickle.load(f)
        for j in range(10000):
            img[j+10000*i] = data['data'][j]
            lbl[j+10000*i] = data['labels'][j]
        
        #print(lbl)
        #print("//////////////////////////////////////////////")
        
    return img, lbl

# %%
with open('/home/skyolia/tensorflow_project/cifar-10/cifar-10-batches-py/test_batch','rb') as f:
    data2 = cPickle.load(f)
    test_labels = np.asarray(data2['labels'])
    test_data = np.asarray(data2['data'])

# %%
train_data, train_labels = cifar10_concatenate()
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
def cifar10_reshape(data):
    
    size = data.shape[0]
    img = np.zeros([size,3072])
    
    for i in range(size):
        imageToUse = data[i]
        
        image = imageToUse.reshape(3,32,32).transpose(1,2,0)
        elmn = image.flatten()
        
        img[i] = elmn
        
    return img

# %%
def normalisation(array):
    
    array = array.astype('float32')
    array_nomalized = array / 255.0       
    return array_nomalized

# %%
def cifar10_preparation():
    
    train_reshape = cifar10_reshape(train_data)
    test_reshape = cifar10_reshape(test_data)
    print("reshape done")
    
    norm_train_data = normalisation(train_reshape)
    norm_test_data = normalisation(test_reshape)
    print("normalisation done")
    
    #flip_train = flip_cifar10(norm_train_data)
    #print("flip done")
    
    #data_train_set = np.concatenate((norm_train_data, flip_train), axis=0)
    #label_train_set = np.concatenate((train_labels, train_labels), axis = 0)
    
    return norm_train_data, norm_test_data

# %%
a,b = cifar10_preparation()
print(a.shape)
print(b.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# reshape done
# normalisation done
# (50000, 3072)
# (10000, 3072)
# (50000,)
# (10000,)

# %%
def create_batches(batch_size, isTrain):
    
    while (True):
        if isTrain:
            for i in xrange(0, len(train_labels), batch_size):
                yield(a[i:i+batch_size],train_labels[i:i+batch_size])
        else:
            for i in xrange(0, len(test_labels), batch_size):
                yield(b[i:i+batch_size],test_labels[i:i+batch_size])

# %%
tf.reset_default_graph()
embedding_size = 1024
learning_rate = 1e-3
batch_size = 100
display_step = 1
logs_path = "/home/skyolia/tensorflow_project/cifar-10/CNN/chap3//batch_norm/test_1/"
    
    #mnist = tf.contrib.learn.datasets.mnist.read_data_sets(train_dir=logs_path + 'data', one_hot=True)
    
    # Network Parameters
n_input = 3072  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)
strides=1
k=2    
    # tf Graph input
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, n_input], name="x_input")
    y = tf.placeholder(tf.int64, shape=[None], name="y_input")
    prob_1=tf.placeholder(tf.float32)
    prob_2=tf.placeholder(tf.float32)
    #prob_3=tf.placeholder(tf.float32)
    phase_train = tf.placeholder(tf.bool)

    
    # Store layers weight & bias
with tf.name_scope("weights"):
        
    weights = {

    'wc1': tf.get_variable(name = "w1",shape = [3, 3, 3, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable(name = "w2",shape = [3, 3, 48, 48], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'wc3': tf.get_variable(name = "w3",shape = [3, 3, 48, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc4': tf.get_variable(name = "w4",shape = [3, 3, 96, 96], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    'wc5': tf.get_variable(name = "w5",shape = [3, 3, 96, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc6': tf.get_variable(name = "w6",shape = [3, 3, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    #'wc8': tf.Variable(tf.truncated_normal([1, 1, 128, 128], stddev=0.1), name = "w8"),
    'wc7': tf.get_variable(name = "w7",shape = [1, 1, 192, 192], initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc8': tf.get_variable(name = "w8",shape = [3072, 512], initializer=tf.contrib.layers.xavier_initializer()),
    'wc9': tf.get_variable(name = "w9",shape = [512, 256], initializer=tf.contrib.layers.xavier_initializer()),
    'wc10': tf.get_variable(name = "w10",shape = [256, 10], initializer=tf.contrib.layers.xavier_initializer()),
}
    
    
with tf.name_scope("biases"):
    
    biases = {
    
    'bc10': tf.Variable(tf.constant(0.1, shape=[10]), name = "b10"),
}

'''
'bc1': tf.Variable(tf.constant(0.1, shape=[48]), name='b1'),
    'bc2': tf.Variable(tf.constant(0.1, shape=[48]), name = "b2"),
    #'wc3': tf.Variable(tf.truncated_normal([3, 3, 32, 32], stddev=0.1), name = "w3"),
    'bc3': tf.Variable(tf.constant(0.1, shape=[96]), name = "b3"),
    'bc4': tf.Variable(tf.constant(0.1, shape=[96]), name = "b4"),
    #'wc6': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w6"),
    #'wc7': tf.Variable(tf.truncated_normal([3, 3, 64, 64], stddev=0.1), name = "w7"),
    'bc5': tf.Variable(tf.constant(0.1, shape=[192]), name = "b5"),
    'bc6': tf.Variable(tf.constant(0.1, shape=[192]), name = "b6"),
    'bc7': tf.Variable(tf.constant(0.1, shape=[192]), name = "b7"),
    'bc8': tf.Variable(tf.constant(0.1, shape=[512]), name = "b8"),
    'bc9': tf.Variable(tf.constant(0.1, shape=[256]), name = "b9"),
'''

total_parameters = 0
for variable in tf.trainable_variables():
    # shape is an array of tf.Dimension
    shape = variable.get_shape()
    print(shape)
    print(len(shape))
    variable_parametes = 1
    for dim in shape:
        print(dim)
        variable_parametes *= dim.value
    print(variable_parametes)
    total_parameters += variable_parametes
print("total_parameters : ",total_parameters)
    
x_image = tf.reshape(x,[-1,32,32,3])
x_bn = batch_norm(x_image, 3, phase_train, convolutional = True)
#x_image_do=tf.nn.dropout(x_image, keep_prob=prob_3)

hidden_1 = tf.nn.conv2d(x_bn, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
hidden_1_bn = batch_norm(hidden_1, 48, phase_train, convolutional = True)
hidden_1_relu = tf.nn.elu(hidden_1_bn)
print(hidden_1_relu.get_shape())

hidden_2 = tf.nn.conv2d(hidden_1_relu, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
hidden_2_bn = batch_norm(hidden_2, 48, phase_train, convolutional = True)
hidden_2_relu = tf.nn.elu(hidden_2_bn)
print(hidden_2_relu.get_shape())

pool_1 = tf.nn.max_pool(hidden_2_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_1_do=tf.nn.dropout(pool_1, keep_prob=prob_1)
print(pool_1.get_shape())

hidden_3 = tf.nn.conv2d(pool_1_do, weights['wc3'], strides=[1, 1, 1, 1], padding='SAME')
hidden_3_bn = batch_norm(hidden_3, 96, phase_train, convolutional = True)
hidden_3_relu = tf.nn.elu(hidden_3_bn)
print(hidden_3_relu.get_shape())

hidden_4 = tf.nn.conv2d(hidden_3_relu, weights['wc4'], strides=[1, 1, 1, 1], padding='SAME')
hidden_4_bn = batch_norm(hidden_4, 96, phase_train, convolutional = True)
hidden_4_relu = tf.nn.elu(hidden_4_bn)
print(hidden_4_relu.get_shape())

pool_2 = tf.nn.max_pool(hidden_4_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_2_do=tf.nn.dropout(pool_2, keep_prob=prob_1)
print(pool_2.get_shape())

hidden_5 = tf.nn.conv2d(pool_2_do, weights['wc5'], strides=[1, 1, 1, 1], padding='SAME')
hidden_5_bn = batch_norm(hidden_5, 192, phase_train, convolutional = True)
hidden_5_relu = tf.nn.elu(hidden_5_bn)
print(hidden_5_relu.get_shape())

hidden_6 = tf.nn.conv2d(hidden_5_relu, weights['wc6'], strides=[1, 1, 1, 1], padding='SAME')
hidden_6_bn = batch_norm(hidden_6, 192, phase_train, convolutional = True)
hidden_6_relu = tf.nn.elu(hidden_6_bn)
print(hidden_6_relu.get_shape())

pool_3 = tf.nn.max_pool(hidden_6_relu, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='VALID')
pool_3_do=tf.nn.dropout(pool_3, keep_prob=prob_1)
print(pool_3.get_shape())

hidden_7 = tf.nn.conv2d(pool_3_do, weights['wc7'], strides=[1, 1, 1, 1], padding='VALID')
hidden_7_bn = batch_norm(hidden_7, 192, phase_train, convolutional = True)
hidden_7_relu = tf.nn.elu(hidden_7_bn)
hidden_7_do=tf.nn.dropout(hidden_7_relu, keep_prob=prob_1)
print(hidden_7_relu.get_shape())

hidden_8 = tf.matmul(slim.flatten(hidden_7_do), weights['wc8'])
hidden_8_bn = batch_norm(hidden_8, 512, phase_train, convolutional = False)
hidden_8_relu = tf.nn.elu(hidden_8_bn)
hidden_8_do = tf.nn.dropout(hidden_8_relu, prob_2)
print(hidden_8_relu.get_shape())

hidden_9 = tf.matmul(hidden_8_do, weights['wc9'])
hidden_9_bn = batch_norm(hidden_9, 256, phase_train, convolutional = False)
hidden_9_relu = tf.nn.elu(hidden_9_bn)
hidden_9_do = tf.nn.dropout(hidden_9_relu, prob_2)
print(hidden_9_relu.get_shape())
    
out_y = tf.matmul(hidden_9_do, weights['wc10']) + biases['bc10']

'''
hidden_8 = tf.nn.conv2d(hidden_7_relu, weights['wc8'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc8']
hidden_8_relu = tf.nn.elu(hidden_8)
print(hidden_8_relu.get_shape())

hidden_9 = tf.nn.conv2d(hidden_8_relu, weights['wc9'], strides=[1, 1, 1, 1], padding='VALID') + biases['bc9']
hidden_9_relu = tf.nn.elu(hidden_9)
print(hidden_9_relu.get_shape())

out_x = tf.nn.avg_pool(hidden_9_relu, ksize=[1, 8, 8, 1], strides=[1, 8, 8, 1], padding="VALID")
print(out_x.get_shape())
out_y = tf.reshape(out_x,(-1,10))
print(out_y.get_shape())
'''

    
    # Define loss and optimizer
with tf.name_scope('cross_entropy'):
    
    cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(out_y, y))
        
with tf.name_scope('learning_rate'):
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    
    # Evaluate model
with tf.name_scope('Accuracy'):
    
    correct_pred = tf.equal(tf.argmax(out_y, 1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

acc_training_summary = tf.summary.scalar("training_accuracy", accuracy)
acc_test_summary = tf.summary.scalar("test_accuracy", accuracy)

lost_training_summary = tf.scalar_summary("training_lost", cost)
lost_test_summary = tf.scalar_summary("test_lost", cost)



#summary_op = tf.merge_all_summaries()    


writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
saver = tf.train.Saver(max_to_keep=300)

epoch = 0

start = time.time()

test_cumulative_accuracy = 0.0
train_cumulative_accuracy = 0.0

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init, {phase_train: True})
    while(True):
            gen_batch = create_batches(125,True)
            test_accuracy = 0.0
            train_accuracy = 0.0
            c = 0.0
            c2 = 0.0
            print("epoch : ", epoch)
            for j in range(400):
                    #print("j = ",j)
                    img, lbl = gen_batch.next()
                    optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, phase_train: True})
                    c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    batch_train_accuracy = sess.run(accuracy, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    
                    train_accuracy += batch_train_accuracy
                    if (j%80 == 0):
                        print("j = ",j)
                        print("batch_train_accuracy = ",batch_train_accuracy)
                        
                    train_acc_summ, train_lost_summ = sess.run([acc_training_summary, lost_training_summary], 
                                                               feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
                    writer.add_summary(train_acc_summ,epoch * 400 + j)
                    writer.add_summary(train_lost_summ,epoch * 400 + j)
                        
                #summary = sess.run(summary_op, feed_dict={x: img, y: lbl})
            
            
            
            #print("train accuracy = ",train_accuracy)
            train_cost = c/400
            print("lost = ", train_cost)
            train_cumulative_accuracy = train_accuracy/400
            
            end = time.time()
            duree = end-start
            print("train_cumulative_accuracy : ", train_cumulative_accuracy)
            print("duree : ", duree)
            
            gen_batch2 = create_batches(100,False)
            for j in range(100):
                img2, lbl2 = gen_batch2.next()
                
                batch_test_accuracy = sess.run(accuracy, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                c2 += sess.run(cost, feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
                    
                test_accuracy += batch_test_accuracy
                test_acc_summ, test_lost_summ = sess.run([acc_test_summary, lost_test_summary], 
                                                         feed_dict={x: img2, y: lbl2, prob_1: 1., prob_2:1., phase_train: False})
            
                writer.add_summary(test_acc_summ,epoch * 100 + j)
                writer.add_summary(test_lost_summ,epoch * 100 + j)
            
            test_cost = c2/100
            print("lost = ", test_cost)
            test_cumulative_accuracy = test_accuracy/100
            print("test_cumulative_accuracy : ", test_cumulative_accuracy)
            
            file_name = "./"+str(epoch)+"_model.ckpt"
            saver.save(sess, file_name)
            
            epoch += 1 
    
print("model saved")
# Out:
# (3, 3, 3, 48)
# 4
# 3
# 3
# 3
# 48
# 1296
# (3, 3, 48, 48)
# 4
# 3
# 3
# 48
# 48
# 20736
# (3, 3, 48, 96)
# 4
# 3
# 3
# 48
# 96
# 41472
# (3, 3, 96, 96)
# 4
# 3
# 3
# 96
# 96
# 82944
# (3, 3, 96, 192)
# 4
# 3
# 3
# 96
# 192
# 165888
# (3, 3, 192, 192)
# 4
# 3
# 3
# 192
# 192
# 331776
# (1, 1, 192, 192)
# 4
# 1
# 1
# 192
# 192
# 36864
# (3072, 512)
# 2
# 3072
# 512
# 1572864
# (512, 256)
# 2
# 512
# 256
# 131072
# (256, 10)
# 2
# 256
# 10
# 2560
# (10,)
# 1
# 10
# 10
# total_parameters :  2387482
# (?, 32, 32, 48)
# (?, 32, 32, 48)
# (?, 16, 16, 48)
# (?, 16, 16, 96)
# (?, 16, 16, 96)
# (?, 8, 8, 96)
# (?, 8, 8, 192)
# (?, 8, 8, 192)
# (?, 4, 4, 192)
# (?, 4, 4, 192)
# (?, 512)
# (?, 256)
# WARNING:tensorflow:From <ipython-input-11-2fbaf06f8553>:182 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-2fbaf06f8553>:183 in <module>.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From <ipython-input-11-2fbaf06f8553>:190 in <module>.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# epoch :  0
# j =  0
# batch_train_accuracy =  0.152
# j =  80
# batch_train_accuracy =  0.496
# j =  160
# batch_train_accuracy =  0.52
# j =  240
# batch_train_accuracy =  0.496
# j =  320
# batch_train_accuracy =  0.552
# lost =  1.84326143086
# train_cumulative_accuracy :  0.480479996875
# duree :  106.408459902
# lost =  1.82573372483
# test_cumulative_accuracy :  0.512099977434
# epoch :  1
# j =  0
# batch_train_accuracy =  0.512
# j =  80
# batch_train_accuracy =  0.496
# j =  160
# batch_train_accuracy =  0.64
# j =  240
# batch_train_accuracy =  0.64
# j =  320
# batch_train_accuracy =  0.592
# lost =  1.55960370198
# train_cumulative_accuracy :  0.564339996055
# duree :  228.775970936
# lost =  1.44743525147
# test_cumulative_accuracy :  0.602199965715
# epoch :  2
# j =  0
# batch_train_accuracy =  0.576
# j =  80
# batch_train_accuracy =  0.568
# j =  160
# batch_train_accuracy =  0.656
# j =  240
# batch_train_accuracy =  0.688
# j =  320
# batch_train_accuracy =  0.64
# lost =  1.57914333791
# train_cumulative_accuracy :  0.589259994105
# duree :  352.648344994
# lost =  1.50099074662
# test_cumulative_accuracy :  0.616599971354
# epoch :  3
# j =  0
# batch_train_accuracy =  0.608
# j =  80
# batch_train_accuracy =  0.56
# j =  160
# batch_train_accuracy =  0.64
# j =  240
# batch_train_accuracy =  0.648
# j =  320
# batch_train_accuracy =  0.672
# lost =  1.51440517962
# train_cumulative_accuracy :  0.612159993947
# duree :  476.349620104
# lost =  1.28479379654
# test_cumulative_accuracy :  0.663999963403
# epoch :  4
# j =  0
# batch_train_accuracy =  0.672
# j =  80
# batch_train_accuracy =  0.704
# j =  160
# batch_train_accuracy =  0.672
# j =  240
# batch_train_accuracy =  0.752
# j =  320
# batch_train_accuracy =  0.696
# lost =  1.17687005594
# train_cumulative_accuracy :  0.681800000966
# duree :  600.14736104
# lost =  1.18634684086
# test_cumulative_accuracy :  0.690899968147
# epoch :  5
# j =  0
# batch_train_accuracy =  0.728
# j =  80
# batch_train_accuracy =  0.64
# j =  160
# batch_train_accuracy =  0.68
# j =  240
# batch_train_accuracy =  0.776
# j =  320
# batch_train_accuracy =  0.792
# lost =  1.07305399723
# train_cumulative_accuracy :  0.707940003574
# duree :  723.798803091
# lost =  0.96721265614
# test_cumulative_accuracy :  0.736899968982
# epoch :  6
# j =  0
# batch_train_accuracy =  0.808
# j =  80
# batch_train_accuracy =  0.696
# j =  160
# batch_train_accuracy =  0.76
# j =  240
# batch_train_accuracy =  0.84
# j =  320
# batch_train_accuracy =  0.816
# lost =  0.874424234629
# train_cumulative_accuracy :  0.749840005934
# duree :  847.369131088
# lost =  0.811728377044
# test_cumulative_accuracy :  0.77129997313
# epoch :  7
# j =  0
# batch_train_accuracy =  0.848
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.824
# j =  240
# batch_train_accuracy =  0.816
# j =  320
# batch_train_accuracy =  0.856
# lost =  0.702615452111
# train_cumulative_accuracy :  0.789540012479
# duree :  971.041775942
# lost =  0.836013891101
# test_cumulative_accuracy :  0.766999975443
# epoch :  8
# j =  0
# batch_train_accuracy =  0.824
# j =  80
# batch_train_accuracy =  0.8
# j =  160
# batch_train_accuracy =  0.848
# j =  240
# batch_train_accuracy =  0.832
# j =  320
# batch_train_accuracy =  0.864
# lost =  0.551750454232
# train_cumulative_accuracy :  0.826560017318
# duree :  1094.69828105
# lost =  0.719706003964
# test_cumulative_accuracy :  0.796099982262
# epoch :  9
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.84
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.848
# lost =  0.479276086874
# train_cumulative_accuracy :  0.846600020081
# duree :  1218.34776211
# lost =  0.701680746377
# test_cumulative_accuracy :  0.796599979997
# epoch :  10
# j =  0
# batch_train_accuracy =  0.88
# j =  80
# batch_train_accuracy =  0.808
# j =  160
# batch_train_accuracy =  0.872
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.88
# lost =  0.461991545558
# train_cumulative_accuracy :  0.85206002295
# duree :  1341.9259479
# lost =  0.678852202892
# test_cumulative_accuracy :  0.80519998014
# epoch :  11
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.888
# j =  320
# batch_train_accuracy =  0.888
# lost =  0.357621137053
# train_cumulative_accuracy :  0.879880026877
# duree :  1465.48722506
# lost =  0.562365944088
# test_cumulative_accuracy :  0.831599984765
# epoch :  12
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.88
# j =  160
# batch_train_accuracy =  0.904
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.896
# lost =  0.324679800235
# train_cumulative_accuracy :  0.889100026637
# duree :  1589.00643897
# lost =  0.597800552249
# test_cumulative_accuracy :  0.824699986577
# epoch :  13
# j =  0
# batch_train_accuracy =  0.896
# j =  80
# batch_train_accuracy =  0.872
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.88
# j =  320
# batch_train_accuracy =  0.92
# lost =  0.31178281663
# train_cumulative_accuracy :  0.896380029321
# duree :  1712.61595392
# lost =  0.611944088638
# test_cumulative_accuracy :  0.8251999861
# epoch :  14
# j =  0
# batch_train_accuracy =  0.88
# j =  80
# batch_train_accuracy =  0.904
# j =  160
# batch_train_accuracy =  0.896
# j =  240
# batch_train_accuracy =  0.904
# j =  320
# batch_train_accuracy =  0.928
# lost =  0.28133548962
# train_cumulative_accuracy :  0.904480031431
# duree :  1836.15528393
# lost =  0.56172573477
# test_cumulative_accuracy :  0.83549998343
# epoch :  15
# j =  0
# batch_train_accuracy =  0.912
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.912
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.241198303401
# train_cumulative_accuracy :  0.916020030826
# duree :  1959.81599808
# lost =  0.58317966789
# test_cumulative_accuracy :  0.832399984598
# epoch :  16
# j =  0
# batch_train_accuracy =  0.888
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.928
# j =  320
# batch_train_accuracy =  0.936
# lost =  0.22317453241
# train_cumulative_accuracy :  0.924120032191
# duree :  2083.30357504
# lost =  0.609048474431
# test_cumulative_accuracy :  0.827199989557
# epoch :  17
# j =  0
# batch_train_accuracy =  0.92
# j =  80
# batch_train_accuracy =  0.896
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.201339245625
# train_cumulative_accuracy :  0.929840032756
# duree :  2206.78403091
# lost =  0.54403053835
# test_cumulative_accuracy :  0.844699990749
# epoch :  18
# j =  0
# batch_train_accuracy =  0.944
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.952
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.179875206044
# train_cumulative_accuracy :  0.936760034561
# duree :  2330.30774093
# lost =  0.542766321003
# test_cumulative_accuracy :  0.847899988294
# epoch :  19
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.164057397572
# train_cumulative_accuracy :  0.943160033375
# duree :  2453.78268504
# lost =  0.560590627342
# test_cumulative_accuracy :  0.844599991441
# epoch :  20
# j =  0
# batch_train_accuracy =  0.952
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.944
# j =  240
# batch_train_accuracy =  0.936
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.157562887557
# train_cumulative_accuracy :  0.944760032892
# duree :  2577.28202605
# lost =  0.58253747955
# test_cumulative_accuracy :  0.840199989676
# epoch :  21
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.132912391992
# train_cumulative_accuracy :  0.953360036165
# duree :  2700.94945598
# lost =  0.524541003257
# test_cumulative_accuracy :  0.850199990869
# epoch :  22
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.928
# j =  240
# batch_train_accuracy =  0.952
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.125324618416
# train_cumulative_accuracy :  0.955280036479
# duree :  2824.36870098
# lost =  0.543676847667
# test_cumulative_accuracy :  0.852999988198
# epoch :  23
# j =  0
# batch_train_accuracy =  0.936
# j =  80
# batch_train_accuracy =  0.936
# j =  160
# batch_train_accuracy =  0.96
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.125523509225
# train_cumulative_accuracy :  0.95620003745
# duree :  2947.93069792
# lost =  0.570014863014
# test_cumulative_accuracy :  0.849599990845
# epoch :  24
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.912
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.11615985522
# train_cumulative_accuracy :  0.960100034773
# duree :  3071.3133471
# lost =  0.556190004945
# test_cumulative_accuracy :  0.84959997952
# epoch :  25
# j =  0
# batch_train_accuracy =  0.96
# j =  80
# batch_train_accuracy =  0.92
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.111900417311
# train_cumulative_accuracy :  0.960420036763
# duree :  3194.80896592
# lost =  0.57808181271
# test_cumulative_accuracy :  0.846499986053
# epoch :  26
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.952
# lost =  0.100489461441
# train_cumulative_accuracy :  0.96496003598
# duree :  3318.29812407
# lost =  0.643173754811
# test_cumulative_accuracy :  0.839499983191
# epoch :  27
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0837924258155
# train_cumulative_accuracy :  0.970820031613
# duree :  3441.82817793
# lost =  0.568393088728
# test_cumulative_accuracy :  0.858199992776
# epoch :  28
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0743762381887
# train_cumulative_accuracy :  0.974600030631
# duree :  3565.29404402
# lost =  0.569121197611
# test_cumulative_accuracy :  0.855999993682
# epoch :  29
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0689784386719
# train_cumulative_accuracy :  0.975840028822
# duree :  3688.72568011
# lost =  0.584560983032
# test_cumulative_accuracy :  0.854399994016
# epoch :  30
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.96
# lost =  0.0689312244044
# train_cumulative_accuracy :  0.976040028632
# duree :  3812.1458981
# lost =  0.555775295794
# test_cumulative_accuracy :  0.858599989414
# epoch :  31
# j =  0
# batch_train_accuracy =  0.968
# j =  80
# batch_train_accuracy =  0.96
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0652674857446
# train_cumulative_accuracy :  0.977640029043
# duree :  3935.43878102
# lost =  0.600344765186
# test_cumulative_accuracy :  0.856499995589
# epoch :  32
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0539041783311
# train_cumulative_accuracy :  0.981940022856
# duree :  4058.84276009
# lost =  0.565348245203
# test_cumulative_accuracy :  0.860699989796
# epoch :  33
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0463472887466
# train_cumulative_accuracy :  0.983580020666
# duree :  4182.43982697
# lost =  0.55850959599
# test_cumulative_accuracy :  0.86109999001
# epoch :  34
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.043141247374
# train_cumulative_accuracy :  0.98556001544
# duree :  4305.75383496
# lost =  0.560773073733
# test_cumulative_accuracy :  0.863499999046
# epoch :  35
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0405760678509
# train_cumulative_accuracy :  0.986520015895
# duree :  4429.20940709
# lost =  0.543653355986
# test_cumulative_accuracy :  0.867400001287
# epoch :  36
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.968
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.040386967028
# train_cumulative_accuracy :  0.98632001698
# duree :  4552.71231604
# lost =  0.646024398804
# test_cumulative_accuracy :  0.852799988985
# epoch :  37
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.96
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0397494892398
# train_cumulative_accuracy :  0.986340015531
# duree :  4676.10174203
# lost =  0.583679473251
# test_cumulative_accuracy :  0.863099992871
# epoch :  38
# j =  0
# batch_train_accuracy =  0.984
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.976
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0326309280866
# train_cumulative_accuracy :  0.98936001271
# duree :  4799.53043389
# lost =  0.588866436183
# test_cumulative_accuracy :  0.864899998307
# epoch :  39
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0307975065487
# train_cumulative_accuracy :  0.989520011693
# duree :  4923.053967
# lost =  0.641343237758
# test_cumulative_accuracy :  0.849799992442
# epoch :  40
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0295934220066
# train_cumulative_accuracy :  0.990280012637
# duree :  5046.51836896
# lost =  0.600750741661
# test_cumulative_accuracy :  0.857999992371
# epoch :  41
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0239932787977
# train_cumulative_accuracy :  0.992360004932
# duree :  5170.0212791
# lost =  0.59567043364
# test_cumulative_accuracy :  0.863399996758
# epoch :  42
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0268378946901
# train_cumulative_accuracy :  0.990760010034
# duree :  5293.56493902
# lost =  0.620619546622
# test_cumulative_accuracy :  0.857499992847
# epoch :  43
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0226338520128
# train_cumulative_accuracy :  0.992860004008
# duree :  5417.18898392
# lost =  0.640040077865
# test_cumulative_accuracy :  0.856899995208
# epoch :  44
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0276093157637
# train_cumulative_accuracy :  0.990720009357
# duree :  5540.50110602
# lost =  0.602942222059
# test_cumulative_accuracy :  0.862299998403
# epoch :  45
# j =  0
# batch_train_accuracy =  0.976
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0219536802574
# train_cumulative_accuracy :  0.99288000837
# duree :  5664.06682205
# lost =  0.617893734276
# test_cumulative_accuracy :  0.86319999516
# epoch :  46
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  0.968
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0225730039175
# train_cumulative_accuracy :  0.992620006353
# duree :  5787.44528794
# lost =  0.607595072687
# test_cumulative_accuracy :  0.862799994349
# epoch :  47
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0241916862153
# train_cumulative_accuracy :  0.991860005558
# duree :  5910.96304989
# lost =  0.649781385511
# test_cumulative_accuracy :  0.85739998579
# epoch :  48
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.968
# lost =  0.0259546283359
# train_cumulative_accuracy :  0.991480007023
# duree :  6034.5778501
# lost =  0.587854954153
# test_cumulative_accuracy :  0.865699993372
# epoch :  49
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0142466487634
# train_cumulative_accuracy :  0.995780002028
# duree :  6158.00815296
# lost =  0.605058324635
# test_cumulative_accuracy :  0.864000002146
# epoch :  50
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.984
# lost =  0.0161608723449
# train_cumulative_accuracy :  0.995260002464
# duree :  6281.24322891
# lost =  0.60605382055
# test_cumulative_accuracy :  0.86129999578
# epoch :  51
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0139319377064
# train_cumulative_accuracy :  0.99594000414
# duree :  6404.91634893
# lost =  0.64923821032
# test_cumulative_accuracy :  0.86139999032
# epoch :  52
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0185802831347
# train_cumulative_accuracy :  0.993700006455
# duree :  6528.37768412
# lost =  0.633811128736
# test_cumulative_accuracy :  0.861399992108
# epoch :  53
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.968
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0143781851244
# train_cumulative_accuracy :  0.995860002488
# duree :  6651.74238801
# lost =  0.649072124958
# test_cumulative_accuracy :  0.860899998546
# epoch :  54
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.984
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0137763293601
# train_cumulative_accuracy :  0.996100002378
# duree :  6775.23754811
# lost =  0.609284608066
# test_cumulative_accuracy :  0.865899996758
# epoch :  55
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0132362701418
# train_cumulative_accuracy :  0.995900003612
# duree :  6898.63025904
# lost =  0.634944102764
# test_cumulative_accuracy :  0.859799997807
# epoch :  56
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0103245323693
# train_cumulative_accuracy :  0.996840001196
# duree :  7022.14125109
# lost =  0.619017966092
# test_cumulative_accuracy :  0.862799994349
# epoch :  57
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0110187621618
# train_cumulative_accuracy :  0.996680001467
# duree :  7145.74177694
# lost =  0.62277644217
# test_cumulative_accuracy :  0.866099995375
# epoch :  58
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.010142590419
# train_cumulative_accuracy :  0.9969599998
# duree :  7269.21848202
# lost =  0.61058239758
# test_cumulative_accuracy :  0.866899994612
# epoch :  59
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  0.976
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.0122712991567
# train_cumulative_accuracy :  0.996140004992
# duree :  7392.52729797
# lost =  0.680249478519
# test_cumulative_accuracy :  0.856999992728
# epoch :  60
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0147467795253
# train_cumulative_accuracy :  0.995400003642
# duree :  7516.01791
# lost =  0.662355444729
# test_cumulative_accuracy :  0.862799998522
# epoch :  61
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.976
# lost =  0.0121736500597
# train_cumulative_accuracy :  0.9961600025
# duree :  7639.52337193
# lost =  0.6819555071
# test_cumulative_accuracy :  0.856399986148
# epoch :  62
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.976
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0127956781969
# train_cumulative_accuracy :  0.995860002786
# duree :  7762.9242599
# lost =  0.632057638466
# test_cumulative_accuracy :  0.866100000739
# epoch :  63
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.984
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.011237858464
# train_cumulative_accuracy :  0.996400003135
# duree :  7886.36230206
# lost =  0.659699914753
# test_cumulative_accuracy :  0.861999992132
# epoch :  64
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00847867009208
# train_cumulative_accuracy :  0.997900000811
# duree :  8009.7013731
# lost =  0.622663826346
# test_cumulative_accuracy :  0.869800000191
# epoch :  65
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00832342899099
# train_cumulative_accuracy :  0.997580000758
# duree :  8133.12526298
# lost =  0.65509814471
# test_cumulative_accuracy :  0.861600000858
# epoch :  66
# j =  0
# batch_train_accuracy =  0.992
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00816612807532
# train_cumulative_accuracy :  0.997660001665
# duree :  8256.5937829
# lost =  0.572277895212
# test_cumulative_accuracy :  0.880100003481
# epoch :  67
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00925390747558
# train_cumulative_accuracy :  0.996980000436
# duree :  8380.14721203
# lost =  0.655514049679
# test_cumulative_accuracy :  0.866499998569
# epoch :  68
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0113342177353
# train_cumulative_accuracy :  0.996420001686
# duree :  8503.57773495
# lost =  0.63538689971
# test_cumulative_accuracy :  0.859499992132
# epoch :  69
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00682159076925
# train_cumulative_accuracy :  0.998159999102
# duree :  8627.02267194
# lost =  0.63032251358
# test_cumulative_accuracy :  0.869099997282
# epoch :  70
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  0.984
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00717386802608
# train_cumulative_accuracy :  0.997940000147
# duree :  8750.53333211
# lost =  0.656425447464
# test_cumulative_accuracy :  0.862999993563
# epoch :  71
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00608049691793
# train_cumulative_accuracy :  0.998160000294
# duree :  8873.90447593
# lost =  0.609283798933
# test_cumulative_accuracy :  0.873200003505
# epoch :  72
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  0.992
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  0.992
# lost =  0.00640805967429
# train_cumulative_accuracy :  0.998120000958
# duree :  8997.353549
# lost =  0.692274513841
# test_cumulative_accuracy :  0.863299997449
# epoch :  73
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  1.0
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  0.992
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.0075665674427
# train_cumulative_accuracy :  0.997660001516
# duree :  9120.72285008
# lost =  0.621065048128
# test_cumulative_accuracy :  0.866299997568
# epoch :  74
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00667496601942
# train_cumulative_accuracy :  0.998179999739
# duree :  9248.09841895
# lost =  0.642664060593
# test_cumulative_accuracy :  0.872400000691
# epoch :  75
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# j =  240
# batch_train_accuracy =  1.0
# j =  320
# batch_train_accuracy =  1.0
# lost =  0.00655584993143
# train_cumulative_accuracy :  0.998100000173
# duree :  9374.72632098
# lost =  0.602651768178
# test_cumulative_accuracy :  0.874500002265
# epoch :  76
# j =  0
# batch_train_accuracy =  1.0
# j =  80
# batch_train_accuracy =  0.992
# j =  160
# batch_train_accuracy =  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2fbaf06f8553> in <module>()
#     212                     #print("j = ",j)
#     213                     img, lbl = gen_batch.next()
# --> 214                     optimizer.run(feed_dict={x: img, y: lbl, prob_1: 0.75, prob_2:0.5, phase_train: True})
#     215                     c += sess.run(cost, feed_dict={x: img, y: lbl, prob_1: 1., prob_2:1., phase_train: False})
#     216
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1447         none, the default session will be used.
#    1448     """
# -> 1449     _run_using_default_session(self, feed_dict, self.graph, session)
#    1450
#    1451
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3666                        "the operation's graph is different from the session's "
#    3667                        "graph.")
# -> 3668   session.run(operation, feed_dict)
#    3669
#    3670
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
